# %%
import sys
sys.path.append('../')
import scqubits as scq
import pandas as pd
import qutip as qt
import numpy as np
from matplotlib import pyplot as plt
from qutip.qip.operations import rz, cz_gate
from tqdm import tqdm
from matplotlib.colors import LogNorm
import time, pytz, os, itertools, cmath
from datetime import datetime
import scqubits.settings as settings
settings.OVERLAP_THRESHOLD = 0.3
from joblib import Parallel, delayed
import scipy.sparse as ssp
from sympy import symbols
import scipy as sp
import utils_2Q_gate_zp as ut
from scipy.ndimage import gaussian_filter

# %%
truc_one_qubit, truc_tot, charge_pick = 300, 1000, True
truc_full = 1000

[hspace_full, eket_tot, eval_tot, n_theta0_dress, 
    n_theta1_dress, hspace_0, hspace_1, logi_state
    ] = ut.load_qubit_data_2q(truc_one_qubit, truc_full, charge_pick)

A1_bound, A2_bound, detune1_bound, detune2_bound = [
    (0.001, 0.5), (0.001, 0.5), (-0.5, 0.5), (-0.5, 0.5)    ]
tg_bound = (-0.001, 0.001) #(-1e-10, 1e-10) #

max_step_ideal, max_step_noisy = 3e-4, 1e-3 # Set max_step to 0 for parallel execution
option_ideal, option_noisy = ut.get_qutip_options(max_step_ideal, max_step_noisy) 

workers, popsize = 100, 10
recombination, tol, mutation = [0.7, 0.01, (0.5, 1.0)]
logi_state = ['0-0', '0-2', '2-0', '2-2']
# mid_state = '8-2'
# idx_0 = hspace_full.index('0-2')
# idx_1 = hspace_full.index('2-2')

mid_state = '0-8'
idx_0 = hspace_full.index('0-0')
idx_1 = hspace_full.index('0-2')

hspace_part = logi_state + [mid_state] + ['1-4', '8-0', '0-8', '2-8', ] # hspace_full[:200] # ut.truc_model['cnot_short_1000'][:200]

idx_2 = hspace_full.index(mid_state)
W_0_2 = eval_tot[idx_2] - eval_tot[idx_0]
W_1_2 = eval_tot[idx_2] - eval_tot[idx_1]
H0_full = qt.Qobj(np.diag(eval_tot))

index_part = [hspace_full.index(i) for i in hspace_part]
len_part = len(hspace_part)
H0_part = ut.truncate_2( H0_full, index_part)
n_theta0_part = ut.truncate_2(n_theta0_dress, index_part)
n_theta1_part = ut.truncate_2(n_theta1_dress, index_part)
logi_idx_part = [hspace_part.index(i) for i in logi_state]

state_full = [qt.basis(len_part, i) for i in range(len_part)]
# H_drive_part = [ H0_part,   [n_theta0_part, ut.drive_gauss_A],
#                             [n_theta0_part, ut.drive_gauss_B]  ]

H_drive_part = [ H0_part,   [n_theta1_part, ut.drive_gauss_A],
                            [n_theta1_part, ut.drive_gauss_B]  ]
c_op_list = []
num_cpus = 200
ratio = 3
[tg, drive_amp_A, drive_amp_B, detune_A, detune_B] = [49.99427378, 0.01920815, 0.02153711, 0.08851824, -0.07637073]
# [50, 0.114* ratio, 0.045* ratio, 0,0 ] 
# cnot
# [100.006167,0.053076,0.029316,-0.01188,-0.01157]
# [340.0063,0.016618,0.010608,-0.001774,-0.00169]
# x-gate
# [10.108462,0.41212,0.073451,-0.084451,-0.044706 ]
# [25.020473,0.180208,0.046132,-0.003789,0.001544 ] 
# [119.917464,0.033248,0.00908,0.000489,0.000672]
 
arg_optimize = [tg, drive_amp_A, drive_amp_B, detune_A, detune_B]
pulse_args = {'drive_amp_A': drive_amp_A ,
            'drive_freq_A': W_0_2 + 2*np.pi*detune_A,
            'drive_amp_B': drive_amp_B ,
            'drive_freq_B': W_1_2 + 2*np.pi*detune_B,
            'gate_time': tg }
tlist = np.linspace(0, tg, num=int(tg))  # total time
logi_state_one = [0,2]

# %%
# Population in select
result = {}
for idx, state_i in enumerate(logi_state_one):
    for jdx, state_j in tqdm(enumerate(logi_state_one)):
        # This simulation is just for viewing the affect of the pulse
        result[idx, jdx] = qt.mesolve(
            H_drive_part,
            qt.basis(len_part, hspace_part.index( str(state_i) +'-'+str(state_j) )),
            tlist,
            e_ops=[state * state.dag() for state in state_full],
            args=pulse_args,
            options=qt.Options(store_states=True, num_cpus=num_cpus, nsteps=10000) )
# Out:
# 2it [00:00,  3.34it/s]
# 2it [00:00,  2.50it/s]

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=2, ncols=2)
# fig.suptitle(f"CNOT (tg={tg:.0f}, $|8,2\\rangle$, logF={fidelity_full:.3f}, $N_{{\\rm state}}$={truc1})", fontsize=16, y=0.92)
for idx, state_i in enumerate(logi_state_one):
    for jdx, state_j in enumerate(logi_state_one):
        for kdx, res in zip(hspace_part, result[idx,jdx].expect):
            y_pop = gaussian_filter( np.array(res).flatten(), 3)
            # if np.max(y_pop) > 0.01:
            ax[idx][jdx].plot(tlist, gaussian_filter( np.array(res).flatten(), 3) ,  label=r"%s" %kdx)
        ax[idx][jdx].set_ylim(-0.02,1.02)
        ax[idx][jdx].grid()
    ax[1][idx].set_xlabel('Time (ns)')
    ax[idx][0].set_ylabel('Population')
ax[1][1].legend()

# %%
def optimize_population(arg_optimize, *args):
    [tg, drive_amp_A, drive_amp_B, detune_A, detune_B] = arg_optimize
    [H_drive_part, W_0_2, W_1_2, num_cpus] = args   

    pulse_args = {'drive_amp_A': drive_amp_A ,
                'drive_freq_A': W_0_2 + 2*np.pi*detune_A,
                'drive_amp_B': drive_amp_B ,
                'drive_freq_B': W_1_2 + 2*np.pi*detune_B,
                'gate_time': tg }
    tlist = np.linspace(0, tg, num=int(tg))  # total time    

    result = {}
    for idx, state_i in enumerate(logi_state_one):
        for jdx, state_j in enumerate(logi_state_one):
            # This simulation is just for viewing the affect of the pulse
            result[idx, jdx] = qt.mesolve(
                H_drive_part,
                qt.basis(len_part, hspace_part.index( str(state_i) +'-'+str(state_j) )),
                tlist,
                e_ops=[state * state.dag() for state in state_full],
                args=pulse_args,
                options=qt.Options(store_states=True, num_cpus=num_cpus, nsteps=10000) )    
            
    p00 = result[0,0].expect[1][-1] # population in |0,2>
    p02 = result[0,1].expect[0][-1]
    p20 = result[1,0].expect[3][-1]
    p22 = result[1,1].expect[2][-1]

    return  (np.log10(1- p00) + np.log10(1- p02) + np.log10(1- p20) + np.log10(1- p22))       


state_full = [qt.basis(len_part, i) for i in range(4)]
tg_bound = (-0.01, 0.01) #(-1e-10, 1e-10) #
A1_bound, A2_bound, detune1_bound, detune2_bound = [
    (0.001, 0.5), (0.001, 0.5), (-0.1, 0.1), (-0.1, 0.1)     ]

workers, popsize = 100, 10
recombination, tol, mutation = [0.7, 0.01, (0.5, 1.0)]
num_cpus = 1

arg_truc = [H_drive_part, W_0_2, W_1_2, num_cpus]

tg_bounds = (tg+tg_bound[0], tg+tg_bound[1])
bounds = (tg_bounds, A1_bound, A2_bound, detune1_bound, detune2_bound)
res = sp.optimize.differential_evolution(
    func=optimize_population,
    bounds=bounds,
    args=arg_truc,
    disp=True,
    callback=ut.print_soln,
    init="sobol",
    workers=workers,
    popsize=popsize,
    mutation=mutation,
    recombination=recombination,
    tol=tol,
    polish=False, # 'True' will make the for-loop break
    )

print(res, '\n')
# Out:
# UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#  /home/zlqed/anaconda3/envs/qutip4/lib/python3.11/site-packages/scipy/optimize/_differentialevolution.py: 387
# differential_evolution step 1: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0057
# ----------------------------
# differential_evolution step 2: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0075
# ----------------------------
# differential_evolution step 3: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0086
# ----------------------------
# differential_evolution step 4: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0097
# ----------------------------
# differential_evolution step 5: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0109
# ----------------------------
# differential_evolution step 6: f(x)= -2.36925
# Best Solution: [49.98704761, 0.32540603, 0.24773818, 0.07618416, 0.05213717]
# Convergence: 0.0111
# ----------------------------
# differential_evolution step 7: f(x)= -2.79749
# Best Solution: [49.98531384, 0.40330461, 0.19999011, 0.06975884, 0.06578284]
# Convergence: 0.012
# ----------------------------
# differential_evolution step 8: f(x)= -2.94061
# Best Solution: [49.99406617, 0.36503883, 0.26175908, 0.08621714, 0.0614692]
# Convergence: 0.0126
# ----------------------------
# differential_evolution step 9: f(x)= -2.94061
# Best Solution: [49.99406617, 0.36503883, 0.26175908, 0.08621714, 0.0614692]
# Convergence: 0.0142
# ----------------------------
# differential_evolution step 10: f(x)= -2.94061
# Best Solution: [49.99406617, 0.36503883, 0.26175908, 0.08621714, 0.0614692]
# Convergence: 0.0152
# ----------------------------
# differential_evolution step 11: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0157
# ----------------------------
# differential_evolution step 12: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0168
# ----------------------------
# differential_evolution step 13: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0171
# ----------------------------
# differential_evolution step 14: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.018
# ----------------------------
# differential_evolution step 15: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0192
# ----------------------------
# differential_evolution step 16: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.02
# ----------------------------
# differential_evolution step 17: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0202
# ----------------------------
# differential_evolution step 18: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0212
# ----------------------------
# differential_evolution step 19: f(x)= -3.54904
# Best Solution: [49.99804783, 0.3290378, 0.27578281, 0.08843676, 0.06159105]
# Convergence: 0.0226
# ----------------------------
# differential_evolution step 20: f(x)= -3.81513
# Best Solution: [49.99437344, 0.38166029, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0251
# ----------------------------
# differential_evolution step 21: f(x)= -3.81513
# Best Solution: [49.99437344, 0.38166029, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0265
# ----------------------------
# differential_evolution step 22: f(x)= -3.81513
# Best Solution: [49.99437344, 0.38166029, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0272
# ----------------------------
# differential_evolution step 23: f(x)= -3.967
# Best Solution: [50.00018529, 0.36988258, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0268
# ----------------------------
# differential_evolution step 24: f(x)= -3.967
# Best Solution: [50.00018529, 0.36988258, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0269
# ----------------------------
# differential_evolution step 25: f(x)= -3.967
# Best Solution: [50.00018529, 0.36988258, 0.26353916, 0.09536, 0.07392691]
# Convergence: 0.0275
# ----------------------------
# differential_evolution step 26: f(x)= -4.12063
# Best Solution: [49.99329382, 0.38691537, 0.25351578, 0.09502818, 0.07622152]
# Convergence: 0.0267
# ----------------------------
# differential_evolution step 27: f(x)= -4.12063
# Best Solution: [49.99329382, 0.38691537, 0.25351578, 0.09502818, 0.07622152]
# Convergence: 0.0271
# ----------------------------
# differential_evolution step 28: f(x)= -4.12063
# Best Solution: [49.99329382, 0.38691537, 0.25351578, 0.09502818, 0.07622152]
# Convergence: 0.0292
# ----------------------------
# differential_evolution step 29: f(x)= -4.12063
# Best Solution: [49.99329382, 0.38691537, 0.25351578, 0.09502818, 0.07622152]
# Convergence: 0.0301
# ----------------------------
# differential_evolution step 30: f(x)= -4.12063
# Best Solution: [49.99329382, 0.38691537, 0.25351578, 0.09502818, 0.07622152]
# Convergence: 0.0304
# ----------------------------
# differential_evolution step 31: f(x)= -4.90996
# Best Solution: [49.99539774, 0.42342194, 0.23061476, 0.08916391, 0.07844099]
# Convergence: 0.0298
# ----------------------------
# differential_evolution step 32: f(x)= -4.90996
# Best Solution: [49.99539774, 0.42342194, 0.23061476, 0.08916391, 0.07844099]
# Convergence: 0.032
# ----------------------------
# differential_evolution step 33: f(x)= -4.90996
# Best Solution: [49.99539774, 0.42342194, 0.23061476, 0.08916391, 0.07844099]
# Convergence: 0.0352
# ----------------------------
# differential_evolution step 34: f(x)= -4.90996
# Best Solution: [49.99539774, 0.42342194, 0.23061476, 0.08916391, 0.07844099]
# Convergence: 0.0434
# ----------------------------
# differential_evolution step 35: f(x)= -4.94806
# Best Solution: [49.99602933, 0.41222392, 0.23713613, 0.0897754, 0.07538767]
# Convergence: 0.0511
# ----------------------------
# differential_evolution step 36: f(x)= -5.08605
# Best Solution: [49.99509946, 0.42301829, 0.22951254, 0.08878853, 0.07693706]
# Convergence: 0.054
# ----------------------------
# differential_evolution step 37: f(x)= -5.08605
# Best Solution: [49.99509946, 0.42301829, 0.22951254, 0.08878853, 0.07693706]
# Convergence: 0.0542
# ----------------------------
# differential_evolution step 38: f(x)= -5.08605
# Best Solution: [49.99509946, 0.42301829, 0.22951254, 0.08878853, 0.07693706]
# Convergence: 0.0596
# ----------------------------
# differential_evolution step 39: f(x)= -5.50402
# Best Solution: [49.99418031, 0.43847044, 0.22848774, 0.09201883, 0.08055754]
# Convergence: 0.0575
# ----------------------------
# differential_evolution step 40: f(x)= -5.71289
# Best Solution: [50.0029842, 0.43973782, 0.22774966, 0.09194962, 0.08090312]
# Convergence: 0.0682
# ----------------------------
# differential_evolution step 41: f(x)= -5.94636
# Best Solution: [49.99413006, 0.45442576, 0.21906106, 0.09032346, 0.08227653]
# Convergence: 0.0755
# ----------------------------
# differential_evolution step 42: f(x)= -5.94636
# Best Solution: [49.99413006, 0.45442576, 0.21906106, 0.09032346, 0.08227653]
# Convergence: 0.0814
# ----------------------------
# differential_evolution step 43: f(x)= -6.40438
# Best Solution: [49.9890656, 0.45523305, 0.2195621, 0.09017731, 0.08223748]
# Convergence: 0.0856
# ----------------------------
# differential_evolution step 44: f(x)= -6.55079
# Best Solution: [49.99432186, 0.46399304, 0.21634036, 0.08952032, 0.08248595]
# Convergence: 0.082
# ----------------------------
# differential_evolution step 45: f(x)= -6.55079
# Best Solution: [49.99432186, 0.46399304, 0.21634036, 0.08952032, 0.08248595]
# Convergence: 0.0824
# ----------------------------
# differential_evolution step 46: f(x)= -6.55079
# Best Solution: [49.99432186, 0.46399304, 0.21634036, 0.08952032, 0.08248595]
# Convergence: 0.0864
# ----------------------------
# differential_evolution step 47: f(x)= -6.55079
# Best Solution: [49.99432186, 0.46399304, 0.21634036, 0.08952032, 0.08248595]
# Convergence: 0.0992
# ----------------------------
# differential_evolution step 48: f(x)= -6.55079
# Best Solution: [49.99432186, 0.46399304, 0.21634036, 0.08952032, 0.08248595]
# Convergence: 0.1036
# ----------------------------
# differential_evolution step 49: f(x)= -6.86235
# Best Solution: [49.98872134, 0.49140398, 0.20564343, 0.08790146, 0.08414672]
# Convergence: 0.0984
# ----------------------------
# differential_evolution step 50: f(x)= -6.86235
# Best Solution: [49.98872134, 0.49140398, 0.20564343, 0.08790146, 0.08414672]
# Convergence: 0.0999
# ----------------------------
# differential_evolution step 51: f(x)= -6.86235
# Best Solution: [49.98872134, 0.49140398, 0.20564343, 0.08790146, 0.08414672]
# Convergence: 0.0986
# ----------------------------
# differential_evolution step 52: f(x)= -7.29241
# Best Solution: [49.98685522, 0.48091078, 0.20996784, 0.08907279, 0.08391781]
# Convergence: 0.0994
# ----------------------------
# differential_evolution step 53: f(x)= -7.69901
# Best Solution: [49.99316502, 0.49115169, 0.20698376, 0.089043, 0.08478267]
# Convergence: 0.0954
# ----------------------------
# differential_evolution step 54: f(x)= -7.69901
# Best Solution: [49.99316502, 0.49115169, 0.20698376, 0.089043, 0.08478267]
# Convergence: 0.094
# ----------------------------
# differential_evolution step 55: f(x)= -7.69901
# Best Solution: [49.99316502, 0.49115169, 0.20698376, 0.089043, 0.08478267]
# Convergence: 0.1019
# ----------------------------
# differential_evolution step 56: f(x)= -7.69901
# Best Solution: [49.99316502, 0.49115169, 0.20698376, 0.089043, 0.08478267]
# Convergence: 0.1013
# ----------------------------
# differential_evolution step 57: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.0983
# ----------------------------
# differential_evolution step 58: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.1106
# ----------------------------
# differential_evolution step 59: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.1225
# ----------------------------
# differential_evolution step 60: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.1207
# ----------------------------
# differential_evolution step 61: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.1237
# ----------------------------
# differential_evolution step 62: f(x)= -7.7091
# Best Solution: [49.98506733, 0.49117808, 0.20702279, 0.08930067, 0.08493989]
# Convergence: 0.1224
# ----------------------------
# differential_evolution step 63: f(x)= -7.86734
# Best Solution: [49.99291138, 0.48921068, 0.20726436, 0.08893522, 0.08440731]
# Convergence: 0.1291
# ----------------------------
# differential_evolution step 64: f(x)= -7.86734
# Best Solution: [49.99291138, 0.48921068, 0.20726436, 0.08893522, 0.08440731]
# Convergence: 0.1378
# ----------------------------
# differential_evolution step 65: f(x)= -7.86734
# Best Solution: [49.99291138, 0.48921068, 0.20726436, 0.08893522, 0.08440731]
# Convergence: 0.1495
# ----------------------------
# differential_evolution step 66: f(x)= -8.03118
# Best Solution: [49.9879967, 0.49445339, 0.20560088, 0.08886914, 0.08494007]
# Convergence: 0.1469
# ----------------------------
# differential_evolution step 67: f(x)= -8.04832
# Best Solution: [49.98487218, 0.49348647, 0.20556457, 0.08869808, 0.08474115]
# Convergence: 0.1443
# ----------------------------
# differential_evolution step 68: f(x)= -8.08285
# Best Solution: [49.9893494, 0.49520193, 0.20489154, 0.08864432, 0.08485586]
# Convergence: 0.2034
# ----------------------------
# differential_evolution step 69: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2272
# ----------------------------
# differential_evolution step 70: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2261
# ----------------------------
# differential_evolution step 71: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2459
# ----------------------------
# differential_evolution step 72: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2676
# ----------------------------
# differential_evolution step 73: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2674
# ----------------------------
# differential_evolution step 74: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2655
# ----------------------------
# differential_evolution step 75: f(x)= -8.48044
# Best Solution: [49.99209323, 0.49985692, 0.20307662, 0.08822441, 0.0849351]
# Convergence: 0.2579
# ----------------------------
# differential_evolution step 76: f(x)= -8.49096
# Best Solution: [49.99135838, 0.49968412, 0.20324359, 0.08827074, 0.08496835]
# Convergence: 0.261
# ----------------------------
# differential_evolution step 77: f(x)= -8.49096
# Best Solution: [49.99135838, 0.49968412, 0.20324359, 0.08827074, 0.08496835]
# Convergence: 0.2769
# ----------------------------
# differential_evolution step 78: f(x)= -8.49096
# Best Solution: [49.99135838, 0.49968412, 0.20324359, 0.08827074, 0.08496835]
# Convergence: 0.2823
# ----------------------------
# differential_evolution step 79: f(x)= -8.49096
# Best Solution: [49.99135838, 0.49968412, 0.20324359, 0.08827074, 0.08496835]
# Convergence: 0.2901
# ----------------------------
# differential_evolution step 80: f(x)= -8.49432
# Best Solution: [49.99342408, 0.49985985, 0.20302311, 0.08816064, 0.08490334]
# Convergence: 0.3093
# ----------------------------
# differential_evolution step 81: f(x)= -8.50883
# Best Solution: [49.99045251, 0.49958385, 0.20327373, 0.08825747, 0.08493258]
# Convergence: 0.3201
# ----------------------------
# differential_evolution step 82: f(x)= -8.50883
# Best Solution: [49.99045251, 0.49958385, 0.20327373, 0.08825747, 0.08493258]
# Convergence: 0.3429
# ----------------------------
# differential_evolution step 83: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.3458
# ----------------------------
# differential_evolution step 84: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.4191
# ----------------------------
# differential_evolution step 85: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.4272
# ----------------------------
# differential_evolution step 86: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.4302
# ----------------------------
# differential_evolution step 87: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.4428
# ----------------------------
# differential_evolution step 88: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.4995
# ----------------------------
# differential_evolution step 89: f(x)= -8.514
# Best Solution: [49.99045251, 0.49973479, 0.20321084, 0.08825747, 0.08490921]
# Convergence: 0.5239
# ----------------------------
# differential_evolution step 90: f(x)= -8.52878
# Best Solution: [49.98850847, 0.4998168, 0.20313597, 0.08820181, 0.08489435]
# Convergence: 0.6723
# ----------------------------
# differential_evolution step 91: f(x)= -8.52878
# Best Solution: [49.98850847, 0.4998168, 0.20313597, 0.08820181, 0.08489435]
# Convergence: 0.683
# ----------------------------
# differential_evolution step 92: f(x)= -8.53113
# Best Solution: [49.98868078, 0.49984625, 0.20321084, 0.08825747, 0.0849191]
# Convergence: 0.6792
# ----------------------------
# differential_evolution step 93: f(x)= -8.53113
# Best Solution: [49.98868078, 0.49984625, 0.20321084, 0.08825747, 0.0849191]
# Convergence: 0.7242
# ----------------------------
# differential_evolution step 94: f(x)= -8.54454
# Best Solution: [49.99459786, 0.49989213, 0.20315128, 0.08823228, 0.08491186]
# Convergence: 0.7187
# ----------------------------
# differential_evolution step 95: f(x)= -8.54454
# Best Solution: [49.99459786, 0.49989213, 0.20315128, 0.08823228, 0.08491186]
# Convergence: 0.7251
# ----------------------------
# differential_evolution step 96: f(x)= -8.54454
# Best Solution: [49.99459786, 0.49989213, 0.20315128, 0.08823228, 0.08491186]
# Convergence: 0.8063
# ----------------------------
# differential_evolution step 97: f(x)= -8.54454
# Best Solution: [49.99459786, 0.49989213, 0.20315128, 0.08823228, 0.08491186]
# Convergence: 0.95
# ----------------------------
# differential_evolution step 98: f(x)= -8.54454
# Best Solution: [49.99459786, 0.49989213, 0.20315128, 0.08823228, 0.08491186]
# Convergence: 1.8083
# ----------------------------
#  message: Optimization terminated successfully.
#  success: True
#      fun: -8.544544918988757
#        x: [ 4.999e+01  4.999e-01  2.032e-01  8.823e-02  8.491e-02]
#      nit: 98
#     nfev: 6336

# %%
def get_propagator(H, tlist, num_cpus, c_op_list, pulse_args, logi_idx, option_ideal=None, option_noisy=None):
    """
    Compute the propagator for a quantum system, supporting both noiseless and noisy systems.

    Args:
        H (list or qt.Qobj): The Hamiltonian of the system. Can be a single Qobj or a list where
                             the first element represents the static part.
        tlist (list): List of time points for the simulation.
        num_cpus (int): Number of CPUs to use for parallel computation (if `parallel=True`).
        c_op_list (list): List of collapse operators for modeling noise. If empty, the system is noiseless.
        pulse_args (dict): Arguments for time-dependent pulse functions in the Hamiltonian.
        option_ideal, option_noisy (qt.Options): Solver options for QuTiP.
        logi_idx (list): List of logical states (indices of basis states) to include in the propagator.

    Returns:
        qt.Qobj or list of qt.Qobj:
            - For noiseless systems: A `Qobj` representing the truncated propagator for logical states.
            - For noisy systems: A `Qobj` representing the superoperator propagator for the final time step.
    """
    dimz = len(logi_idx)
    H0 = H[0][0] if isinstance(H[0], list) else H[0] if isinstance(H, list) else H
    if len(c_op_list) == 0:

        N = H0.shape[0]
        if num_cpus > 1:
            u = np.zeros([N, dimz, len(tlist)], dtype=complex)
            output = qt.parallel.parallel_map(parallel_sesolve, logi_idx,
                                    task_args=(N, H, tlist, pulse_args, option_ideal),
                                    num_cpus=num_cpus)
            for n in range(dimz):
                for k, t in enumerate(tlist):
                    u[:, n, k] = output[n].states[k].full().T
            prop = [qt.Qobj(u[:, :, k], dims=[[[N], [N]], [[dimz], [dimz]]]) for k in range(len(tlist))][-1]
            return truncate_2(prop, logi_idx)
        else:
            # Computes the propagator for noiseless systems.
            prop = np.zeros((H0.shape[0], dimz), dtype=np.complex128)
            for i in logi_idx:
                res = qt.sesolve(H, qt.basis(H[0].shape[0], i), tlist, options=option_ideal, args=pulse_args)
                prop[:, logi_idx.index(i)] = res.states[-1].full().flatten()
            Uc = truncate_2(qt.Qobj(prop), logi_idx)
            return Uc

    else: # noise

        # Computes the propagator for noisy systems.
        proj_idx = [(i, j) for j in logi_idx for i in logi_idx]
        N = H0.shape[0]
        u = np.zeros([N * N, dimz * dimz, len(tlist)], dtype=complex)

        if num_cpus > 1:
            output = qt.parallel.parallel_map(
                parallel_mesolve, range(dimz * dimz),
                task_args=(N, H, tlist, c_op_list, pulse_args, option_noisy, proj_idx),
                task_kwargs={"dims": H0.dims}, num_cpus=num_cpus
            )
            for n in range(dimz * dimz):
                for k, t in enumerate(tlist):
                    u[:, n, k] = qt.superoperator.mat2vec(output[n].states[k].full()).T
        else:
            for n, idx in enumerate(proj_idx):
                row_idx, col_idx = idx
                rho0 = qt.states.projection(N, row_idx, col_idx)
                rho0.dims = H0.dims
                output = qt.mesolve(
                    H, rho0, tlist, c_op_list, args=pulse_args, options=option_noisy, _safe_mode=False
                )
                for k, t in enumerate(tlist):
                    u[:, n, k] = qt.superoperator.mat2vec(output.states[k].full()).T

        return [qt.Qobj(u[:, :, k], dims=[[[N], [N]], [[dimz], [dimz]]]) for k in range(len(tlist))][-1]

def XI_fidelity_log(arg_all):
    [tg, drive_amp_A, drive_amp_B, detune_A, detune_B,
     H_qbt_drive, w_0_2, w_1_2, num_cpus, c_op_list, logi_idx, 
     mid_state, option_ideal, option_noisy] = arg_all
    pulse_args = {'drive_amp_A': drive_amp_A ,
                'drive_freq_A': w_0_2 + 2*np.pi*detune_A,
                'drive_amp_B': drive_amp_B ,
                'drive_freq_B': w_1_2 + 2*np.pi*detune_B,
                'gate_time': tg }
    tlist = np.linspace(0, tg, num=10*int(tg))  # total time

    propagator = get_propagator(H_qbt_drive, tlist, num_cpus, c_op_list, pulse_args, 
                          logi_idx, option_ideal, option_noisy)

    fidelity = get_fidelity_super_operator(propagator, logi_idx, XI, c_op_list, mid_state)
    
    return np.log10(1-fidelity)


def XI_fidelity_log_noise(arg_optimize, *args):
    [tg, drive_amp_A, drive_amp_B, detune_A, detune_B] = arg_optimize
    [H_qbt_drive, w_0_2, w_1_2, num_cpus, c_op_list, logi_idx, 
     mid_state, option_ideal, option_noisy] = args

    arg_all = [tg, drive_amp_A, drive_amp_B, detune_A, detune_B,
     H_qbt_drive, w_0_2, w_1_2, num_cpus, c_op_list, logi_idx, 
     mid_state, option_ideal, option_noisy]

    return XI_fidelity_log(arg_all)

def XI_phase_correct(U_kraus):
    U_final = [] 
    for prop in U_kraus:    
        prop = qt.Qobj(prop, dims=[[2, 2], [2, 2]]) 
        Uc_prime = swap()* prop* swap() # for |45> state
        phase = np.angle(Uc_prime)
        x1 = - phase[0,2]
        x2 = - phase[3,1]
        U_bef = qt.Qobj(np.diag([1, np.exp(1j* x1), np.exp(1j* x2), np.exp(1j* (x1+x2))])
                , dims=[[2, 2], [2, 2]])
        U_final.append(np.exp(-1j* phase[2,0])* Uc_prime* U_bef)
    return U_final

# %%
[tg, drive_amp_A, drive_amp_B, detune_A, detune_B] = [25.020473,0.180208,0.046132,-0.003789,0.001544 ] 
x0 = [tg, drive_amp_A, drive_amp_B, detune_A, detune_B]
# [tg, drive_amp_A, drive_amp_B, detune_A, detune_B]
# [25.020473,0.180208,0.046132,-0.003789,0.001544 ] 

tg_bound = (-0.01, 0.01) #(-1e-10, 1e-10) #
A1_bound, A2_bound, detune1_bound, detune2_bound = [
    (0.001, 0.5), (0.001, 0.5), (-0.5, 0.5), (-0.5, 0.5)     ]

workers, popsize = 100, 10
recombination, tol, mutation = [0.7, 0.01, (0.5, 1.0)]
num_cpus = 1

arg_truc = [H_drive_part, W_0_2, W_1_2, num_cpus, c_op_list, 
            logi_idx_part, mid_state, option_ideal, option_noisy]

tg_bounds = (tg+tg_bound[0], tg+tg_bound[1])
bounds = (tg_bounds, A1_bound, A2_bound, detune1_bound, detune2_bound)
res = sp.optimize.differential_evolution(
    func=ut.XI_fidelity_log_noise,
    bounds=bounds,
    args=arg_truc,
    disp=True,
    callback=ut.print_soln,
    init="sobol",
    workers=workers,
    popsize=popsize,
    mutation=mutation,
    recombination=recombination,
    tol=tol,
    x0=x0,
    polish=False, # 'True' will make the for-loop break
    )

print(res, '\n')
# Out:
# differential_evolution step 1: f(x)= -0.145299
# Best Solution: [25.01585436, 0.12752504, 0.26112662, -0.10641464, -0.06486127]
# Convergence: 0.1158
# ----------------------------
# differential_evolution step 2: f(x)= -0.160413
# Best Solution: [25.01556619, 0.35024696, 0.27591923, -0.30522827, -0.30510093]
# Convergence: 0.083
# ----------------------------
# differential_evolution step 3: f(x)= -0.160413
# Best Solution: [25.01556619, 0.35024696, 0.27591923, -0.30522827, -0.30510093]
# Convergence: 0.0821
# ----------------------------
# differential_evolution step 4: f(x)= -0.165124
# Best Solution: [25.01538621, 0.42226245, 0.3566554, -0.2194513, -0.20013681]
# Convergence: 0.0681
# ----------------------------
# differential_evolution step 5: f(x)= -0.196207
# Best Solution: [25.01320941, 0.33968508, 0.25982933, -0.18398339, -0.13686409]
# Convergence: 0.0523
# ----------------------------
# differential_evolution step 6: f(x)= -0.196207
# Best Solution: [25.01320941, 0.33968508, 0.25982933, -0.18398339, -0.13686409]
# Convergence: 0.0522
# ----------------------------
# differential_evolution step 7: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.047
# ----------------------------
# differential_evolution step 8: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.0483
# ----------------------------
# differential_evolution step 9: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.0455
# ----------------------------
# differential_evolution step 10: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.0458
# ----------------------------
# differential_evolution step 11: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.0472
# ----------------------------
# differential_evolution step 12: f(x)= -0.213818
# Best Solution: [25.02202293, 0.4228379, 0.42915723, -0.44253209, -0.39365133]
# Convergence: 0.0473
# ----------------------------
# differential_evolution step 13: f(x)= -0.216995
# Best Solution: [25.01694323, 0.41328514, 0.45097273, -0.49366573, -0.44766942]
# Convergence: 0.0477
# ----------------------------
# differential_evolution step 14: f(x)= -0.216995
# Best Solution: [25.01694323, 0.41328514, 0.45097273, -0.49366573, -0.44766942]
# Convergence: 0.0482
# ----------------------------
# differential_evolution step 15: f(x)= -0.216995
# Best Solution: [25.01694323, 0.41328514, 0.45097273, -0.49366573, -0.44766942]
# Convergence: 0.0492
# ----------------------------
# differential_evolution step 16: f(x)= -0.216995
# Best Solution: [25.01694323, 0.41328514, 0.45097273, -0.49366573, -0.44766942]
# Convergence: 0.0503
# ----------------------------
# differential_evolution step 17: f(x)= -0.216995
# Best Solution: [25.01694323, 0.41328514, 0.45097273, -0.49366573, -0.44766942]
# Convergence: 0.0525
# ----------------------------
# differential_evolution step 18: f(x)= -0.225712
# Best Solution: [25.02338424, 0.47976388, 0.44746671, -0.39754347, -0.36698373]
# Convergence: 0.0524
# ----------------------------
# differential_evolution step 19: f(x)= -0.225712
# Best Solution: [25.02338424, 0.47976388, 0.44746671, -0.39754347, -0.36698373]
# Convergence: 0.0526
# ----------------------------
# differential_evolution step 20: f(x)= -0.225712
# Best Solution: [25.02338424, 0.47976388, 0.44746671, -0.39754347, -0.36698373]
# Convergence: 0.0529
# ----------------------------
# differential_evolution step 21: f(x)= -0.225712
# Best Solution: [25.02338424, 0.47976388, 0.44746671, -0.39754347, -0.36698373]
# Convergence: 0.0544
# ----------------------------
# differential_evolution step 22: f(x)= -0.231173
# Best Solution: [25.01078018, 0.43353785, 0.49631608, -0.40921035, -0.36953385]
# Convergence: 0.0586
# ----------------------------
# differential_evolution step 23: f(x)= -0.237888
# Best Solution: [25.02778892, 0.46200103, 0.38878186, -0.32815502, -0.30031246]
# Convergence: 0.0626
# ----------------------------
# differential_evolution step 24: f(x)= -0.237888
# Best Solution: [25.02778892, 0.46200103, 0.38878186, -0.32815502, -0.30031246]
# Convergence: 0.064
# ----------------------------
# differential_evolution step 25: f(x)= -0.237888
# Best Solution: [25.02778892, 0.46200103, 0.38878186, -0.32815502, -0.30031246]
# Convergence: 0.0665
# ----------------------------
# differential_evolution step 26: f(x)= -0.237888
# Best Solution: [25.02778892, 0.46200103, 0.38878186, -0.32815502, -0.30031246]
# Convergence: 0.0702
# ----------------------------
# differential_evolution step 27: f(x)= -0.24267
# Best Solution: [25.01078018, 0.43353785, 0.37494247, -0.36632896, -0.33957753]
# Convergence: 0.0631
# ----------------------------
# differential_evolution step 28: f(x)= -0.245842
# Best Solution: [25.01320215, 0.45966485, 0.36789121, -0.36638792, -0.33940814]
# Convergence: 0.0649
# ----------------------------
# differential_evolution step 29: f(x)= -0.245842
# Best Solution: [25.01320215, 0.45966485, 0.36789121, -0.36638792, -0.33940814]
# Convergence: 0.0675
# ----------------------------
# differential_evolution step 30: f(x)= -0.245842
# Best Solution: [25.01320215, 0.45966485, 0.36789121, -0.36638792, -0.33940814]
# Convergence: 0.0687
# ----------------------------
# differential_evolution step 31: f(x)= -0.245842
# Best Solution: [25.01320215, 0.45966485, 0.36789121, -0.36638792, -0.33940814]
# Convergence: 0.0736
# ----------------------------
# differential_evolution step 32: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0758
# ----------------------------
# differential_evolution step 33: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.076
# ----------------------------
# differential_evolution step 34: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0769
# ----------------------------
# differential_evolution step 35: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0775
# ----------------------------
# differential_evolution step 36: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0802
# ----------------------------
# differential_evolution step 37: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0834
# ----------------------------
# differential_evolution step 38: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0888
# ----------------------------
# differential_evolution step 39: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0934
# ----------------------------
# differential_evolution step 40: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0939
# ----------------------------
# differential_evolution step 41: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0926
# ----------------------------
# differential_evolution step 42: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0941
# ----------------------------
# differential_evolution step 43: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0965
# ----------------------------
# differential_evolution step 44: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.0968
# ----------------------------
# differential_evolution step 45: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.101
# ----------------------------
# differential_evolution step 46: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.1041
# ----------------------------
# differential_evolution step 47: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.1033
# ----------------------------
# differential_evolution step 48: f(x)= -0.253427
# Best Solution: [25.01165909, 0.48783983, 0.44011811, -0.45230094, -0.42489624]
# Convergence: 0.1038
# ----------------------------
# differential_evolution step 49: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1037
# ----------------------------
# differential_evolution step 50: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1033
# ----------------------------
# differential_evolution step 51: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1147
# ----------------------------
# differential_evolution step 52: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1332
# ----------------------------
# differential_evolution step 53: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1432
# ----------------------------
# differential_evolution step 54: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1888
# ----------------------------
# differential_evolution step 55: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1898
# ----------------------------
# differential_evolution step 56: f(x)= -0.253649
# Best Solution: [25.01634963, 0.48915263, 0.45626598, -0.48019237, -0.45242004]
# Convergence: 0.1868
# ----------------------------
# differential_evolution step 57: f(x)= -0.255378
# Best Solution: [25.01331564, 0.49646834, 0.44370704, -0.46574872, -0.4383627]
# Convergence: 0.2923
# ----------------------------
# differential_evolution step 58: f(x)= -0.255608
# Best Solution: [25.01287509, 0.49637202, 0.45428941, -0.46392751, -0.43685704]
# Convergence: 0.3188
# ----------------------------
# differential_evolution step 59: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.3515
# ----------------------------
# differential_evolution step 60: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.4498
# ----------------------------
# differential_evolution step 61: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.4535
# ----------------------------
# differential_evolution step 62: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.4689
# ----------------------------
# differential_evolution step 63: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.5727
# ----------------------------
# differential_evolution step 64: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.6058
# ----------------------------
# differential_evolution step 65: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.6145
# ----------------------------
# differential_evolution step 66: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.6788
# ----------------------------
# differential_evolution step 67: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.6745
# ----------------------------
# differential_evolution step 68: f(x)= -0.256705
# Best Solution: [25.01071294, 0.49972211, 0.43672671, -0.46003086, -0.43342742]
# Convergence: 0.6787
# ----------------------------
# differential_evolution step 69: f(x)= -0.256727
# Best Solution: [25.01193348, 0.49874296, 0.45217958, -0.47716548, -0.4503908]
# Convergence: 0.6754
# ----------------------------
# differential_evolution step 70: f(x)= -0.256727
# Best Solution: [25.01193348, 0.49874296, 0.45217958, -0.47716548, -0.4503908]
# Convergence: 0.6819
# ----------------------------
# differential_evolution step 71: f(x)= -0.256912
# Best Solution: [25.01103803, 0.49983461, 0.4548392, -0.47669871, -0.45012587]
# Convergence: 0.7428
# ----------------------------
# differential_evolution step 72: f(x)= -0.256912
# Best Solution: [25.01103803, 0.49983461, 0.4548392, -0.47669871, -0.45012587]
# Convergence: 0.7751
# ----------------------------
# differential_evolution step 73: f(x)= -0.256912
# Best Solution: [25.01103803, 0.49983461, 0.4548392, -0.47669871, -0.45012587]
# Convergence: 1.0778
# ----------------------------
#  message: Optimization terminated successfully.
#  success: True
#      fun: -0.2569123614931608
#        x: [ 2.501e+01  4.998e-01  4.548e-01 -4.767e-01 -4.501e-01]
#      nit: 73
#     nfev: 4736
