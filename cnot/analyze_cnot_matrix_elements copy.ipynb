# %%
import sys
sys.path.append('../')

import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
import scqubits.settings as settings
settings.OVERLAP_THRESHOLD = 0.3
from sympy import symbols
import utils_2Q_gate_zp as ut
from brokenaxes import brokenaxes
import qutip as qt
import scqubits as scq
import pandas as pd
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# import plotly.graph_objects as go
# import plotly.io as pio
import scipy as sp
from scipy.ndimage import gaussian_filter
from joblib import Parallel, delayed
from IPython.display import display, Math
import ham_data as hd

# %%
1-10**(-2.68328839)
1-10**(-2.76949029)

print(1-10**(-2.07199956))
print(1-10**(-1.5531604))
# Out:
# 0.9915277172750115
# 0.9720205225027031

# %%
# truc1, truc_tot, charge_pick = 300, 1000, False
# truc_tot_2 = 1000
# num_cpus = 16
# folder = f'../../data/3ncut_two_zeropi/truc1={truc1}_truc2={truc_tot}_pick={charge_pick}/'
# hspace_full = pd.read_csv(folder+ 'hspace_full.txt').to_numpy().flatten().tolist()
# eval_tot = 2*np.pi* pd.read_csv(folder+ 'eval_tot.txt').to_numpy().flatten()
# n_theta0_dress = 2*np.pi* np.load(folder+'n_theta0_dress.npy')
# n_theta1_dress = 2*np.pi* np.load(folder+'n_theta1_dress.npy')

# eval_tot = eval_tot[:truc_tot_2]
# hspace_full = hspace_full[:truc_tot_2]
# n_theta0_dress = qt.Qobj(n_theta0_dress[np.ix_(np.arange(truc_tot_2), np.arange(truc_tot_2))])
# n_theta1_dress = qt.Qobj(n_theta1_dress[np.ix_(np.arange(truc_tot_2), np.arange(truc_tot_2))])

# %%
# truc1=300 
# truc_full = 2000 
# charge_pick=True
# [hspace_full, eket_tot, eval_tot, n_theta0_dress, 
#     n_theta1_dress, hspace_0, hspace_1, logi_state
#     ] = ut.load_qubit_data_2q()

folder_load = '../../data/_truc_3000'
[hspace_full, eket_tot, eval_tot, n_theta0, n_theta1, n_theta0_dress, 
n_theta1_dress, hspace_0, hspace_1, hspace_n_theta1, hspace_n_theta2, logi_state] = hd.load_two_qubit_data(folder_load, return_full=False)

# %%
ut.print_trans_freq('2-0','5-0', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
# Out:
# $\displaystyle \omega_{2-0\_5-0} = 2.545 \cdot 2\pi\ GHz = 15.992\ GHz,\ n_\theta^{2-0\_5-0} = 0.537 \cdot 2\pi = 3.375$

# %%
ut.print_trans_freq('0-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
ut.print_trans_freq('2-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
# Out:
# $\displaystyle \omega_{0-2\_8-2} = 7.251 \cdot 2\pi\ GHz = 45.560\ GHz,\ n_\theta^{0-2\_8-2} = 0.037 \cdot 2\pi = 0.234$
# $\displaystyle \omega_{2-2\_8-2} = 3.808 \cdot 2\pi\ GHz = 23.924\ GHz,\ n_\theta^{2-2\_8-2} = 0.057 \cdot 2\pi = 0.359$

# %%
10.661-3.410
# Out:
# 7.2509999999999994

# %%
ut.print_trans_freq('0-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
ut.print_trans_freq('2-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)

ut.print_trans_freq('0-2','4-5', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
ut.print_trans_freq('2-2','4-5', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)

ut.print_trans_freq('0-0','8-0', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
ut.print_trans_freq('2-0','8-0', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)

ut.print_trans_freq('0-0','1-4', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
ut.print_trans_freq('2-0','1-4', eval_tot, hspace=hspace_full, n_Theta=n_theta0_dress)
# Out:
# $\displaystyle \omega_{0-2\_8-2} = 7.251 \cdot 2\pi\ GHz = 45.560\ GHz,\ n_\theta^{0-2\_8-2} = 0.037 \cdot 2\pi = 0.234$
# $\displaystyle \omega_{2-2\_8-2} = 3.808 \cdot 2\pi\ GHz = 23.924\ GHz,\ n_\theta^{2-2\_8-2} = 0.057 \cdot 2\pi = 0.359$
# $\displaystyle \omega_{0-2\_4-5} = 7.442 \cdot 2\pi\ GHz = 46.761\ GHz,\ n_\theta^{0-2\_4-5} = 0.023 \cdot 2\pi = 0.143$
# $\displaystyle \omega_{2-2\_4-5} = 3.999 \cdot 2\pi\ GHz = 25.125\ GHz,\ n_\theta^{2-2\_4-5} = 0.029 \cdot 2\pi = 0.183$
# $\displaystyle \omega_{0-0\_8-0} = 7.306 \cdot 2\pi\ GHz = 45.906\ GHz,\ n_\theta^{0-0\_8-0} = 0.032 \cdot 2\pi = 0.198$
# $\displaystyle \omega_{2-0\_8-0} = 3.863 \cdot 2\pi\ GHz = 24.271\ GHz,\ n_\theta^{2-0\_8-0} = 0.046 \cdot 2\pi = 0.288$
# $\displaystyle \omega_{0-0\_1-4} = 7.226 \cdot 2\pi\ GHz = 45.402\ GHz,\ n_\theta^{0-0\_1-4} = 0.027 \cdot 2\pi = 0.167$
# $\displaystyle \omega_{2-0\_1-4} = 3.783 \cdot 2\pi\ GHz = 23.767\ GHz,\ n_\theta^{2-0\_1-4} = 0.042 \cdot 2\pi = 0.261$

# %%
ut.print_trans_freq('0-0','0-1', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
ut.print_trans_freq('0-2','0-1', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)

ut.print_trans_freq('0-0','0-8', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
ut.print_trans_freq('0-2','0-8', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
# Out:
# $\displaystyle \omega_{0-0\_0-1} = 2.410 \cdot 2\pi\ GHz = 15.141\ GHz,\ n_\theta^{0-0\_0-1} = 1.252 \cdot 2\pi = 7.869$
# $\displaystyle \omega_{0-2\_0-1} = 1.000 \cdot 2\pi\ GHz = 6.284\ GHz,\ n_\theta^{0-2\_0-1} = 0.018 \cdot 2\pi = 0.111$
# $\displaystyle \omega_{0-0\_0-8} = 6.820 \cdot 2\pi\ GHz = 42.854\ GHz,\ n_\theta^{0-0\_0-8} = 0.045 \cdot 2\pi = 0.284$
# $\displaystyle \omega_{0-2\_0-8} = 3.410 \cdot 2\pi\ GHz = 21.429\ GHz,\ n_\theta^{0-2\_0-8} = 0.114 \cdot 2\pi = 0.714$

# %%
ut.print_trans_freq('0-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
ut.print_trans_freq('2-2','8-2', eval_tot, hspace=hspace_full, n_Theta=n_theta1_dress)
# Out:
# $\displaystyle \omega_{0-2\_8-2} = 7.251 \cdot 2\pi\ GHz = 45.560\ GHz,\ n_\theta^{0-2\_8-2} = 0.002 \cdot 2\pi = 0.010$
# $\displaystyle \omega_{2-2\_8-2} = 3.808 \cdot 2\pi\ GHz = 23.924\ GHz,\ n_\theta^{2-2\_8-2} = 0.001 \cdot 2\pi = 0.009$

# %% [markdown]
# #### n_theta0

# %%
logi_state = ['0-0', '0-2', '2-0', '2-2', '1-0', '5-0', '2-1']
w_trans, n_trans, trans_int = ut.get_w_trans(eval_tot, hspace_full, n_theta0_dress, logi_state)
print('len(w_trans0)=', len(w_trans))

xlims = ((2.3, 2.65),) # 01 state
# xlims = ((3.74, 4.09), (7.12, 7.545)) # 01 state
data = []
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            data.append({'w_trans': np.round(w_trans[i]/(2*np.pi), 3),
                       'state_i': trans_int[i][0],
                       'state_j': trans_int[i][1],
                       'n_theta0': n_trans[i],
                           })
df = pd.DataFrame(data)
df
# Out:
# len(w_trans0)= 398
#     w_trans state_i state_j  n_theta0
# 0     2.337     2-2     2-5     0.387
# 1     2.341     0-2     0-5     0.313
# 2     2.355     1-0     4-0     0.977
# 3     2.382     2-1     9-0     0.982
# 4     2.403     2-0     2-1     0.573
# 5     2.410     0-0     0-1     0.434
# 6     2.448     5-0     5-1     1.011
# 7     2.487     5-0     4-2     0.005
# 8     2.501     1-0     1-1     1.529
# 9     2.535     2-2     5-2     1.278
# 10    2.545     2-0     5-0     1.206
# 11    2.590     0-2     1-2     1.316
# 12    2.591     2-1     5-1     0.862
# 13    2.596     0-0     1-0     1.281
# 14    2.629     2-1     4-2     0.003

# %%
width = 0.8
y_shift = 0
fig = plt.figure(figsize=(10, 4))
bax = brokenaxes(xlims=xlims, wspace=0.05, d=0.004, despine=False, hspace=0.05)
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            txt_label = str(trans_int[i][0]) + '_' + str(trans_int[i][1])
            if trans_int[i] in [('5-0', '4-2'), ('1-0', '4-0'), ('2-1', '4-2')]:
                continue
            if trans_int[i] in [('0-2', '0-8'),  ('2-0', '15-0')]:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, color='red', alpha=0.3)
                bax.text(w_trans[i]/(2*np.pi) +0.03, n_trans[i] , txt_label, ha="center",
                         va="bottom", rotation=90, fontsize=10)
            else:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, alpha=1)
                bax.text(w_trans[i]/(2*np.pi), n_trans[i] , txt_label, ha="center", va="bottom", rotation=90, fontsize=10)
# bax.set_ylim(0, 0.07)
bax.grid()
bax.set_title(r'$\tilde{n}_{\theta 1}$', fontsize=15)
bax.set_xlabel(r'Frequency (2$\pi\cdot$GHz)')
# plt.xticks(np.arange(x_min, x_max, 2))  # Set custom x-axis ticks
# Out:
# Text(0.5, 0, 'Frequency (2$\\pi\\cdot$GHz)')

# %%
data = []
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            if trans_int[i] in [('5-0', '4-2'),  ('1-0', '4-0')]:
                continue            
            x = w_trans[i] / (2*np.pi)
            y = n_trans[i]

            data.append({
                'transition': trans_int[i],
                'w': x,
                'ntheta0': y,
            })
df1 = pd.DataFrame(data)
df1
# Out:
#     transition         w  ntheta0
# 0   (2-2, 2-5)  2.337190    0.387
# 1   (0-2, 0-5)  2.340533    0.313
# 2   (2-1, 9-0)  2.382072    0.982
# 3   (2-0, 2-1)  2.402603    0.573
# 4   (0-0, 0-1)  2.409765    0.434
# 5   (5-0, 5-1)  2.448280    1.011
# 6   (1-0, 1-1)  2.501438    1.529
# 7   (2-2, 5-2)  2.535497    1.278
# 8   (2-0, 5-0)  2.545206    1.206
# 9   (0-2, 1-2)  2.590406    1.316
# 10  (2-1, 5-1)  2.590724    0.862
# 11  (0-0, 1-0)  2.596295    1.281
# 12  (2-1, 4-2)  2.629081    0.003

# %% [markdown]
# #### n_theta1

# %%
w_trans, n_trans, trans_int = ut.get_w_trans(eval_tot, hspace_full, n_theta1_dress, logi_state)
print('len(w_trans)=', len(w_trans))

xlims = ((2.3, 2.65),) # 01 state
# xlims = ((3.701,3.91), (6.85, 7.54)) # 01 state
data = []
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            data.append({'w_trans': np.round(w_trans[i]/(2*np.pi), 3),
                       'state_i': trans_int[i][0],
                       'state_j': trans_int[i][1],
                       'n_theta1': n_trans[i],
                           })
df = pd.DataFrame(data)
df
# Out:
# len(w_trans)= 337
#     w_trans state_i state_j  n_theta1
# 0     2.337     2-2     2-5     1.240
# 1     2.341     0-2     0-5     1.258
# 2     2.355     1-0     4-0     0.973
# 3     2.382     2-1     9-0     0.325
# 4     2.403     2-0     2-1     1.198
# 5     2.410     0-0     0-1     1.252
# 6     2.448     5-0     5-1     1.257
# 7     2.487     5-0     4-2     0.005
# 8     2.501     1-0     1-1     0.928
# 9     2.535     2-2     5-2     0.345
# 10    2.545     2-0     5-0     0.537
# 11    2.590     0-2     1-2     0.270
# 12    2.591     2-1     5-1     0.108
# 13    2.596     0-0     1-0     0.393

# %%
width = 0.8
y_shift = 0
fig = plt.figure(figsize=(10, 4))
bax = brokenaxes(xlims=xlims, wspace=0.05, d=0.004, despine=False, hspace=0.05)
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            txt_label = str(trans_int[i][0]) + '_' + str(trans_int[i][1])
            if trans_int[i] in [('5-0', '4-2'),  ('1-0', '4-0')]:
                continue            
            if trans_int[i] in [('0-2', '0-8'), ('0-0', '0-8')]:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, color='red', alpha=0.3)
                bax.text(w_trans[i]/(2*np.pi) +0.03, n_trans[i] , txt_label, ha="center",
                         va="bottom", rotation=90, fontsize=10)
            else:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, alpha=1)
                bax.text(w_trans[i]/(2*np.pi), n_trans[i] , txt_label, ha="center", va="bottom", rotation=90, fontsize=10)
# bax.set_ylim(0, 0.105)
bax.grid()
bax.set_title(r'$\tilde{n}_{\theta 2}$', fontsize=15)
bax.set_xlabel(r'Frequency (2$\pi\cdot$GHz)')
# plt.xticks(np.arange(x_min, x_max, 2))  # Set custom x-axis ticks
# Out:
# Text(0.5, 0, 'Frequency (2$\\pi\\cdot$GHz)')

# %%
data = []
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            if trans_int[i] in [('5-0', '4-2'),  ('1-0', '4-0')]:
                continue            
            x = w_trans[i] / (2*np.pi)
            y = n_trans[i]

            data.append({
                'transition': trans_int[i],
                'w': x,
                'ntheta1': y,
            })
df2 = pd.DataFrame(data)
df2
# Out:
#     transition         w  ntheta1
# 0   (2-2, 2-5)  2.337190    1.240
# 1   (0-2, 0-5)  2.340533    1.258
# 2   (2-1, 9-0)  2.382072    0.325
# 3   (2-0, 2-1)  2.402603    1.198
# 4   (0-0, 0-1)  2.409765    1.252
# 5   (5-0, 5-1)  2.448280    1.257
# 6   (1-0, 1-1)  2.501438    0.928
# 7   (2-2, 5-2)  2.535497    0.345
# 8   (2-0, 5-0)  2.545206    0.537
# 9   (0-2, 1-2)  2.590406    0.270
# 10  (2-1, 5-1)  2.590724    0.108
# 11  (0-0, 1-0)  2.596295    0.393

# %%
df1['ntheta1'] = df2['ntheta1']
df1
# Out:
#     transition         w  ntheta0  ntheta1
# 0   (2-2, 2-5)  2.337190    0.387    1.240
# 1   (0-2, 0-5)  2.340533    0.313    1.258
# 2   (2-1, 9-0)  2.382072    0.982    0.325
# 3   (2-0, 2-1)  2.402603    0.573    1.198
# 4   (0-0, 0-1)  2.409765    0.434    1.252
# 5   (5-0, 5-1)  2.448280    1.011    1.257
# 6   (1-0, 1-1)  2.501438    1.529    0.928
# 7   (2-2, 5-2)  2.535497    1.278    0.345
# 8   (2-0, 5-0)  2.545206    1.206    0.537
# 9   (0-2, 1-2)  2.590406    1.316    0.270
# 10  (2-1, 5-1)  2.590724    0.862    0.108
# 11  (0-0, 1-0)  2.596295    1.281    0.393
# 12  (2-1, 4-2)  2.629081    0.003      NaN

# %%
df1.to_csv('../figure/data/cz_ntheta_v2.txt', sep=';', index=False)

# %%
df1['transition'] = [
    "2,2-2,5",
    "0,2-0,5",
    "2,0-2,1",
    "0,0-0,1",
    "5,0-5,1",
    "1,0-1,1",
    "2,2-5,2",
    "2,0-5,0",
    "0,2-1,2",
    "0,0-1,0",
]
df1
# Out:
#   transition         w  ntheta0  ntheta1
# 0    2,2-2,5  2.337190    0.387    1.240
# 1    0,2-0,5  2.340533    0.313    1.258
# 2    2,0-2,1  2.402603    0.573    1.198
# 3    0,0-0,1  2.409765    0.434    1.252
# 4    5,0-5,1  2.448280    1.011    1.257
# 5    1,0-1,1  2.501438    1.529    0.928
# 6    2,2-5,2  2.535497    1.278    0.345
# 7    2,0-5,0  2.545206    1.206    0.537
# 8    0,2-1,2  2.590406    1.316    0.270
# 9    0,0-1,0  2.596295    1.281    0.393

# %%
w_trans, n_trans, trans_int = ut.get_w_trans(eval_tot, hspace_full, n_theta1_dress, logi_state)
print('len(w_trans)=', len(w_trans))

xlims = ((3.701,3.91), (6.85, 7.54)) # 01 state
data = []
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            data.append({'w_trans': np.round(w_trans[i]/(2*np.pi), 3),
                       'state_i': trans_int[i][0],
                       'state_j': trans_int[i][1],
                       'n_theta1': n_trans[i],
                           })
df = pd.DataFrame(data)
df
# Out:
# len(w_trans)= 164
#     w_trans state_i state_j  n_theta1
# 0     3.743     2-2     9-1     0.015
# 1     3.783     2-0     1-4     0.001
# 2     3.808     2-2     8-2     0.001
# 3     3.816     0-2     1-4     0.010
# 4     3.863     2-0     8-0     0.001
# 5     3.896     0-2     8-0     0.009
# 6     6.904     2-2     5-9     0.010
# 7     6.966     0-2     1-9     0.010
# 8     7.153     2-0     9-1     0.008
# 9     7.185     2-2     9-5     0.003
# 10    7.226     0-0     1-4     0.006
# 11    7.251     0-2     8-2     0.002
# 12    7.306     0-0     8-0     0.006
# 13    7.339     2-0     5-4     0.006
# 14    7.442     0-2     4-5     0.004
# 15    7.533     0-0     4-1     0.002

# %%
width = 0.8
y_shift = 0
fig = plt.figure(figsize=(10, 4))
bax = brokenaxes(xlims=xlims, wspace=0.05, d=0.004, despine=False, hspace=0.05)
for i in range(len(w_trans)):
    for xlim in xlims:
        if xlim[0] < w_trans[i]/(2*np.pi) < xlim[1]:
            txt_label = str(trans_int[i][0]) + '_' + str(trans_int[i][1])
            if trans_int[i] in [('0-2', '0-8'), ('0-0', '0-8')]:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, color='red', alpha=0.3)
                bax.text(w_trans[i]/(2*np.pi) +0.03, n_trans[i] , txt_label, ha="center",
                         va="bottom", rotation=90, fontsize=10)
            else:
                bax.bar(w_trans[i]/(2*np.pi), n_trans[i], width=0.01, alpha=1)
                bax.text(w_trans[i]/(2*np.pi), n_trans[i] , txt_label, ha="center", va="bottom", rotation=90, fontsize=10)
# bax.set_ylim(0, 0.105)
bax.grid()
bax.set_title(r'$\tilde{n}_{\theta 2}$', fontsize=15)
bax.set_xlabel(r'Frequency (2$\pi\cdot$GHz)')
# plt.xticks(np.arange(x_min, x_max, 2))  # Set custom x-axis ticks
# Out:
# Text(0.5, 0, 'Frequency (2$\\pi\\cdot$GHz)')

# %%
=
# Out:
#   Cell In[9], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Matrix element table

# %%
vmax = 0.1
truc2 = 30
fig, ax = plt.subplots(figsize=(12,10))
font_size = 15
hspace_label = hspace_full[:truc2]
plt.imshow(np.abs(n_theta1_dress[:truc2,:truc2]/(2*np.pi)), vmax=vmax, aspect="auto",cmap='rainbow')
plt.title(r'$n_{\theta 1}$($v_{max}$='+f'{vmax})' , pad=8, fontsize=font_size)
ax.set_xticks(np.arange(0, truc2), hspace_label, fontsize=8)
ax.set_yticks(np.arange(0, truc2), hspace_label, fontsize=12)
ax.xaxis.tick_top()
ax.set_xticks(np.arange(-.5, truc2, 1), minor=True)
ax.set_yticks(np.arange(-.5, truc2, 1), minor=True)
ax.grid(which='minor', color='k', linestyle='-', linewidth=0.5)
ax.tick_params(which='both', left=False, top=False)
plt.colorbar(shrink=0.3, aspect=40, pad=0.01)
# plt.savefig('image/n_theta.png',dpi=150, bbox_inches='tight')
