# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# f_cnot = pd.read_csv('data/data_cnot_45_2A.txt')
# f_n2_20 = pd.read_csv('../cz/data/data_fig/data_cz_n2_20.txt')
f_theta_1ncut = pd.read_csv('data/other/data_xgate_theta_1ncut.txt')
f_phi_1ncut = pd.read_csv('data/other/data_xgate_phi_1ncut.txt')
f_theta = pd.read_csv('data/data_xgate_theta_3ncut.txt')
f_phi = pd.read_csv('data/data_xgate_phi_3ncut.txt')
# df = pd.DataFrame(f_comb, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1',
#                                    'detune_2', 'f_157', 'f_500',  'f_noise_9_2us', 'f_noise_100_5us', 'f_noise_100_50us', 'f_78'])
# df.to_csv('data/data_xgate_theta_3ncut.txt', sep=',', index=False, header=True)

# %% [markdown]
# ### state 1

# %%
p10 = np.array([
[9.990604, 0.044348, 0.036196, -0.190649, 0.193372] ,
[10.997461, 0.04245, 0.034183, -0.186762, 0.238984] ,
[11.991334, 0.037947, 0.036397, -0.183101, 0.200386] ,
[12.990075, 0.034127, 0.038225, -0.180592, 0.167005] ,
[13.990252, 0.047057, 0.053847, -0.253041, 0.282926] ,
[14.990197, 0.045097, 0.057171, -0.249366, 0.249975] ,
[16.000834, 0.046245, 0.049412, -0.246733, 0.281431] ,
[16.990069, 0.043536, 0.051572, -0.2409, 0.252486] ,
[18.008902, 0.044806, 0.054767, -0.249513, 0.289425] ,
[19.009855, 0.041746, 0.045406, -0.236241, 0.252862] ,
[19.99034, 0.03994, 0.047898, -0.230655, 0.230206] ,
[20.991188, 0.042684, 0.053594, -0.252243, 0.279839] ,
[21.9902, 0.040026, 0.045001, -0.239699, 0.248018] ,
[22.996778, 0.042002, 0.052749, -0.260226, 0.292918] ,
[23.992252, 0.039896, 0.052903, -0.242923, 0.2583] ,
[24.990661, 0.03756, 0.052088, -0.23427, 0.233314] ,
[25.997519, 0.039754, 0.046728, -0.250335, 0.271274] ,
[26.992204, 0.037416, 0.052648, -0.238249, 0.244412] ,
[27.990181, 0.03639, 0.053517, -0.238288, 0.230353] ,
[28.99777, 0.037398, 0.050391, -0.242477, 0.253924] ,

[29.99038, 0.035595, 0.050244, -0.234653, 0.233418] ,
[31.009788, 0.037447, 0.044278, -0.250003, 0.265737] ,
[32.001077, 0.03561, 0.054594, -0.243176, 0.246355] ,
[33.009333, 0.037336, 0.042256, -0.254891, 0.275657] ,
[34.003227, 0.035527, 0.04832, -0.242709, 0.251657] ,
[35.009592, 0.037222, 0.048654, -0.266359, 0.291337] ,
[35.99008, 0.028023, 0.036778, -0.203337, 0.19099] ,
[36.990592, 0.033931, 0.046664, -0.238411, 0.24218] ,
[37.990202, 0.033155, 0.054814, -0.239198, 0.232544] ,
[38.998262, 0.034127, 0.0392, -0.242192, 0.250081] ,
[39.990085, 0.0331, 0.053665, -0.243817, 0.24226] ,
[40.999871, 0.027902, 0.056857, -0.202217, 0.189937] ,
[42.001755, 0.032843, 0.051896, -0.243336, 0.245031] ,

[51.990435, 0.030951, 0.052584, -0.244272, 0.24641] ,
[52.990233, 0.030057, 0.053137, -0.239649, 0.234087] ,
[54.009878, 0.031213, 0.039496, -0.246544, 0.250727] ,
[55.000166, 0.030136, 0.054197, -0.244469, 0.241627] ,
[56.00956, 0.031371, 0.034342, -0.248967, 0.256531] ,
[56.993506, 0.030112, 0.051027, -0.243768, 0.245132] ,
[57.990101, 0.031781, 0.047049, -0.271805, 0.283657] ,
[59.009931, 0.0304, 0.037454, -0.246087, 0.249727] ,
[59.999105, 0.028853, 0.053276, -0.236417, 0.233501] ,
])
f10 = np.array([
-0.92066076, -1.06186934, -1.07052703, -0.82931519 ,
-1.11850829, -1.09336069, -1.44706181, -1.46730073 ,
-1.40139073, -1.47937632, -1.36234086, -1.63882846 ,
-1.50750666, -1.78253858, -1.88710758, -1.56244349 ,
-1.84502798, -1.93055369, -1.50968553, -1.92080332 ,

-1.89749257, -2.0397997, -2.14660513, -1.82487958 ,
-2.39900424, -1.72447075, -1.46318106, -2.31839105 ,
-1.87698028, -2.60466531, -2.46382773, -1.65174523 ,
-2.61600533 ,

-3.05698226, -2.64197041, -2.69248129, -2.90794232 ,
-2.42372939, -3.18918015, -2.15488086, -2.71466039 ,
-2.71877999 ,
])

# %%
fig, ax = plt.subplots(figsize=(10,10), nrows=3, gridspec_kw={'height_ratios': [2,2,2]})
fig.suptitle(r'X-gate $n_\theta$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_state7')
ax[2].plot(p10[:,0], 10**f10, '.--', label=r'f_state1')
ax[0].plot(p10[:,0], p10[:,1], '.--', label=r'zp1:drive_amp_1')
ax[0].plot(p10[:,0], p10[:,2], '.--', label=r'zp1:drive_amp_2')
ax[1].plot(p10[:,0], p10[:,3], '.--', label=r'zp1:detune_1')
ax[1].plot(p10[:,0], p10[:,4], '.--', label=r'zp1:detune_2')
plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].legend(loc='best', fontsize=12)
    ax[i].grid()
    ax[i].set_xlim(8, p10[-1,0])
    # ax[i].set_xlim(150, 200)

# %%
=
# Out:
#   Cell In[4], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### state 7

# %%
tg = [80]
f_100_50us = np.array([-3.609009642582861 ,])
f_9_2us = np.array([-2.4417530405806365 ,])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.-', label=r'f_old')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.-', label=r'f_100_5us_old')

plt.plot(tg, 10**f_100_50us, 's', label=r'f_t1_27_tphi_1e6')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ f_100_50us', fontsize=15)
plt.grid()
legend = plt.legend( loc="lower left", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.-', label=r'f_100_50us_old')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.-', label=r'f_100_5us_old')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_9_2us'], '.-', label=r'f_9_2us_old')

plt.plot(tg, 10**f_100_50us, 's', label=r'f_100_50us')
plt.plot(tg, 10**f_9_2us, 's', label=r'f_9_2us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$', fontsize=15)
plt.grid()
legend = plt.legend( loc="lower left", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
tg5 = [10.1, 55.26, 119.91]
f_100_50us_new_tphit1 = np.array([-0.4881927593287252, -2.8119787138406047, -2.910879975023617 ,])
f_9_2us_new_tphit1 = np.array([-0.43362469445894464, -1.4410609439975772, -1.594393162802305 ,])
f_100_100us_new_tphit1 = np.array([-0.48960434980066647, -2.9742840462464035, -3.102580236175397 ,])
f_200_100us_new_tphit1 = np.array([-0.4896147749729254, -3.0007624445503254, -3.221272710789212 ,])
f_200_200us_new_tphit1 = np.array([-0.4903282475379217, -3.262841892825527, -3.418528750191732 ,])
tg3b = [10.1, 40, 119.91]
f_50_10us_new_tphit1 = np.array([-0.4774383681767577, -2.0341991075120274, -2.2930074727960026 ,])
f_300_100us_new_tphit1 = np.array([-0.4896182944065941, -3.0099608469370263, -3.269351374728646 ,])


tg9 = f_theta.to_numpy()[1::2, 0]
f_500_500us_new_tphit1_v2 = np.array([
-0.8777951175785413, -2.7065174616322887, -3.4244568327422087, -3.7967842075025877 ,
-3.9243842655954864, -3.936447959579588, -3.9239895965978815, -3.897025415461952 ,
-3.8650981355484797 ,
])
f_200_200us_new_tphit1_v2 = np.array([
-0.8765428622690827, -2.625510273059727, -3.149994196524867, -3.3473483848247527 ,
-3.4139729193564405, -3.4339706344027854, -3.44357634218624, -3.437074324600879 ,
-3.418528750190721 ,
])
f_300_100us_new_tphit1_v2 = np.array([
-0.874551825171062, -2.52470172125066, -2.9255665226404504, -3.077436402560574 ,
-3.1466915040460046, -3.1851897260080317, -3.2264731215233557, -3.256944291979265 ,
-3.2693513747287355 ,
])
f_200_100us_new_tphit1_v2 = np.array([
-0.8745317766114389, -2.522820628690048, -2.9189267176727256, -3.0652229385254173 ,
-3.1294040491203337, -3.1631920356928553, -3.1968148241374457, -3.217611967979755 ,
-3.2212727107884893 ,
])
f_50_10us_new_tphit1_v2 = np.array([
-0.8405469569033595, -1.8448561530312344, -1.9908206593132718, -2.0754623028833192 ,
-2.132312070017021, -2.174866898482918, -2.2261662009695065, -2.2692747718302537 ,
-2.2930074727959835 ,
])
f_9_2us_new_tphit1_v2 = np.array([
-0.7245832988783077, -1.2111801992103264, -1.313393575065478, -1.3878374420310584 ,
-1.4410609439975732, -1.481903555043816, -1.531214865602548, -1.5722833545301114 ,
-1.5943931628022994 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.--', label=r'f_100_50us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.--', label=r'f_100_5us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_9_2us'], '.--', label=r'f_9_2us')
# plt.plot(tg5, 10**f_100_50us_new_tphit1, 's', label=r'f_100_50us_new_tphit1')
# plt.plot(tg5, 10**f_100_100us_new_tphit1, 's-', label=r'f_100_100us_new_tphit1')
# plt.plot(tg5, 10**f_200_100us_new_tphit1, 's-', label=r'f_200_100us_new_tphit1')
# plt.plot(tg5, 10**f_200_200us_new_tphit1, 's-', label=r'f_200_200us_new_tphit1')

# plt.plot(tg3b, 10**f_50_10us_new_tphit1, 's', label=r'f_50_10us_new_tphit1')
# plt.plot(tg3b, 10**f_300_100us_new_tphit1, 's', label=r'f_300_100us_new_tphit1')

plt.plot(tg9, 10**f_200_100us_new_tphit1_v2, 's--', label=r'f_200_100us')
plt.plot(tg9, 10**f_50_10us_new_tphit1_v2, '.--', label=r'f_50_10us')
plt.plot(tg9, 10**f_9_2us_new_tphit1_v2, '^--', label=r'f_9_2us')
# plt.plot(tg9, 10**f_300_100us_new_tphit1_v2, 'x--', label=r'f_300_100us_new_tphit1')
# plt.plot(tg9, 10**f_200_200us_new_tphit1_v2, 'v--', label=r'f_200_200us_new_tphit1')
# plt.plot(tg9, 10**f_500_500us_new_tphit1_v2, 'D--', label=r'f_500_500us_new_tphit1')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ new t1+tphi', fontsize=15)
plt.grid()
legend = plt.legend( loc="lower left", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.--', label=r'f_100_50us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.--', label=r'f_100_5us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_9_2us'], '.--', label=r'f_9_2us')
plt.plot(tg5, 10**f_100_50us_new_tphit1, 's-', label=r'f_100_50us_new_tphit1')
plt.plot(tg5, 10**f_9_2us_new_tphit1, 's-', label=r'f_9_2us_new_tphit1')
# plt.plot(tg5, 10**f_100_100us_new_tphit1, 's-', label=r'f_100_100us_new_tphit1')
# plt.plot(tg5, 10**f_200_100us_new_tphit1, 's-', label=r'f_200_100us_new_tphit1')
# plt.plot(tg5, 10**f_200_200us_new_tphit1, 's-', label=r'f_200_200us_new_tphit1')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ new t1+tphi', fontsize=15)
plt.grid()
legend = plt.legend( loc="best")
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
tg5 = [10.1, 25, 55.26, 69.96, 119.91]
f_50us_tphi_t1_07 = np.array([
-0.48971864161126244, -2.5176756261764974, -3.17696419132829, -3.199101138759042 ,
-3.147564342934249 ,
])
f_5us_tphi_t1_07 = np.array([
-0.47878638553592323, -1.8567587577890126, -2.2402882692861836, -2.2974928878356926 ,
-2.3401127700181483 ,
])
tg7 = [10.1, 25, 40, 55.26, 69.96, 99.93, 119.91]
f_2us_t1_07 = np.array([
-0.4612137903904183, -1.4643643436272695, -1.6435583915696739, -1.7020817388473368 ,
-1.7130153721016137, -1.6824283849889494 ,-1.6476524578456149 ,
])
f_2us_t1_27 = np.array([
-0.4873292567910768, -2.1313160802238706, -2.2134405865243942, -2.1502527803829716 ,
-2.0813807753680407, -1.9581040204798208, -1.8892850488575603 ,
])
f_2us_tphi = np.array([
-0.4904610392165948, -2.411297520935854, -2.470910483953965, -2.346187283128358 ,
-2.245062984657775, -2.0916610476861623, -2.01341883531477 ,
])
f_2us_tphi_t1_07 = np.array([
-0.4621627192394048, -1.4954167468743131, -1.7092040563981648, -1.8007268076811784 ,
-1.838747967978879, -1.8488003928378154, -1.832110722990955 ,
])
f_50us_t1_07 = np.array([
-0.48969967242104345, -2.505780045220095, -2.9841191485459313, -3.068633145923253 ,
-3.061870540675982, -3.0031827445458603, -2.9565788322325424 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.--', label=r'f_100_50us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.--', label=r'f_100_5us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_9_2us'], '.--', label=r'f_9_2us')
plt.plot(tg5, 10**f_50us_tphi_t1_07, 's-', label=r'f_50us_tphi_t1_07')
plt.plot(tg5, 10**f_5us_tphi_t1_07, 's-', label=r'f_5us_tphi_t1_07')
plt.plot(tg7, 10**f_2us_tphi_t1_07, 's-', label=r'f_2us_tphi_t1_07')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ t1 + unadjusted tphi', fontsize=15)
plt.grid()
legend = plt.legend( loc="best")
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_9_2us'], '.--', label=r'f_2us')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_5us'], '.--', label=r'f_100_5us')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_100_50us'], '.--', label=r'f_100_50us')
plt.plot(tg7, 10**f_2us_t1_07, 'D-', label=r'f_2us_t1_07')
plt.plot(tg7, 10**f_2us_t1_27, '^-', label=r'f_2us_t1_27')
plt.plot(tg7, 10**f_2us_tphi, 'v-', label=r'f_2us_tphi')
plt.plot(tg7, 10**f_2us_tphi_t1_07, 's-', label=r'f_2us_tphi_t1_07')
# plt.plot(tg7, 10**f_100_50us_t1_07, 's-', label=r'f_100_50us_t1_07')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$', fontsize=15)
plt.grid()
legend = plt.legend( loc="best")
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
=
# Out:
#   Cell In[5], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %%
f_theta_pick = f_theta.to_numpy()[[0,3,6,9,12,15],:]
f_ideal = np.array([
-0.4910633820518103, -2.7698332063770645, -4.103645121794385, -4.962721017092489 ,
-5.495481812444968, -6.266506251930366 ,
])
f_2us = np.array([
-0.4852392773794758, -1.8103109763789313, -1.7383137858262023, -1.6400731436278173 ,
-1.5597414091633022, -1.4291333344410448 ,
])
f_inf_10us = np.array([
-0.49075326297406857, -2.607922630433667, -2.96346809839368, -2.8838710151948104 ,
-2.790400757975588, -2.643570848671563 ,
])
f_inf_20us = np.array([
-0.4909043240867041, -2.681577946720095, -3.2523021596260886, -3.2044617502862307 ,
-3.104114501168851, -2.950225240978936 ,
])
f_inf_30us = np.array([
-0.4909559749860134, -2.7092160291721115, -3.416726416135844, -3.401304862310382 ,
-3.293593999581745, -3.1324402962506097 ,
])
f_inf_50us = np.array([
-0.4909978011473404, -2.732678427864347, -3.6162655999580506, -3.668154459242944 ,
-3.5437341226857866, -3.3670661180746353 ,
])

f_400_50us = np.array([
-0.49099215641737715, -2.7281284033606843, -3.563241525663561, -3.5880448231136692 ,
-3.4672213221508508, -3.2939799498212174 ,
])
f_100_50us = np.array([
-0.4909764918031428, -2.7147515907973223, -3.4345999064026955, -3.410438452513234 ,
-3.295652502021076, -3.128294736723581 ,
])
f_100_10us = np.array([
-0.49073210642993187, -2.594421511064357, -2.9160536647599047, -2.829681258939668 ,
-2.7351526621320033, -2.587387915810156 ,
])
f_100_5us = np.array([
-0.49043552346795627, -2.479818455714293, -2.644345018701979, -2.546596645911441 ,
-2.4557610595974815, -2.31190735632999 ,
])

f_50_50us = np.array([
-0.4909554869594147, -2.6975455400821624, -3.3069362747446975, -3.2498599387018463 ,
-3.1388209214168805, -2.975211693412143 ,
])
f_40_40us = np.array([
-0.49092971499368143, -2.6810942447155246, -3.215433709172299, -3.144048063798382 ,
-3.0362592630294314, -2.8757696418932603 ,
])
f_30_30us = np.array([
-0.49088602183992425, -2.654997189843162, -3.096043237024361, -3.010433051551837 ,
-2.9058022913630803, -2.748397023665768 ,
])
f_20_20us = np.array([
-0.49079973617084344, -2.607089424710177, -2.92558137871183, -2.8259703234780607 ,
-2.7244096152618718, -2.5700918183419965 ,
])
print(10**(f_inf_10us - f_inf_50us))
print(10**(f_100_5us - f_inf_50us))
# Out:
# [1.00056323 1.33277181 4.49570185 6.08532033 5.66674102 5.29048234]
# [ 1.00129553  1.79002861  9.37390572 13.22993813 12.24540245 11.35425809]

# %%
fig, ax = plt.subplots(figsize=(6,6))
# plt.plot(f_theta_pick[:,0], 10**f_theta_pick[:,-1], '.-', label=r'f_500')
plt.plot(f_theta_pick[:,0], 10**f_ideal, '.-', label=r'f_ideal')
plt.plot(f_theta_pick[:,0], 10**f_2us, '.--', label=r'f_2us')
# plt.plot(f_theta_pick[:,0], 10**f_0_10us, '.--', label=r'f_$\infty$_10us')
# plt.plot(f_theta_pick[:,0], 10**f_0_20us, '.--', label=r'f_$\infty$_20us')
# plt.plot(f_theta_pick[:,0], 10**f_0_30us, '.--', label=r'f_$\infty$_30us')
# plt.plot(f_theta_pick[:,0], 10**f_inf_50us, '.--', label=r'f_$\infty$_50us')
# plt.plot(f_theta_pick[:,0], 10**f_400_50us, '.--', label=r'f_400_50us')
plt.plot(f_theta_pick[:,0], 10**f_100_50us, '.--', label=r'f_100_50us')
# plt.plot(f_theta_pick[:,0], 10**f_50_50us, '.--', label=r'f_50_50us')
# plt.plot(f_theta_pick[:,0], 10**f_40_40us, '.--', label=r'f_40_40us')
plt.plot(f_theta_pick[:,0], 10**f_30_30us, '.--', label=r'f_30_30us')
# plt.plot(f_theta_pick[:,0], 10**f_20_20us, '.--', label=r'f_20_20us')

plt.plot(f_theta_pick[:,0], 10**f_100_10us, '.--', label=r'f_100_10us')
plt.plot(f_theta_pick[:,0], 10**f_100_5us, '.--', label=r'f_100_5us')


plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
# plt.axhline(y= g*tg/10e3, color='black', linestyle='--', label=r'$T_1^{0-7}=10\ \mu s$')
# plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate $n_\theta$ (f_$T_{\phi}^{\rm logi}$_$T_{\phi/1}^{\rm other}$)')
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f157_theta = np.array([
-0.36053698, -0.63374723, -0.99338974, -1.07320978 ,
-1.12021231, -2.01694565,-1.31328258, -2.28185761, -1.03652133, -6.19572695 ,
-2.53040234 ,
])
f500_theta = np.array([
-0.36050837, -0.63375731, -0.99338169, -1.07320221 ,
-1.12108459, -2.00439871,-1.31325199, -2.28177113, -1.03651074, -5.74049405 ,
-2.52987193 ,
])
para_theta = np.array([
[10.118229, 0.280314, 0.063653, -0.016967, -0.020259] ,
[15.000463, 0.258785, 0.050646, -0.014106, 0.008087] ,
[20.002327, 0.206237, 0.038654, 0.004079, 0.009995] ,
[25.009262, 0.15683, 0.030888, 0.009981, 0.008207] ,
[30.000413, 0.257322, 0.042523, -0.027514, -0.005418] ,
[39.981896, 0.215956, 0.02825, -0.00894, -0.004616] ,
[60.000173, 0.065903, 0.011715, 0.004316, 0.009702] ,
[70.009986, 0.056462, 0.010014, 0.006052, 0.005395] ,
[80.000003, 0.049855, 0.008631, 0.002249, 0.007615] ,
[90.001423, 0.043715, 0.007717, 0.003615, 0.00398] ,
[119.925707, 0.085296, 0.034147, -0.053028, -0.040903] ,
])

# %%
fig, ax = plt.subplots(figsize=(10,10), nrows=3, gridspec_kw={'height_ratios': [2,2,2]})
fig.suptitle(r'X-gate $n_\theta$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
ax[0].plot(f_theta['tg'], f_theta['drive_amp_1'], '.-', label=r'zp0:drive_amp_1')
ax[0].plot(f_theta['tg'], f_theta['drive_amp_2'], '.-', label=r'zp0:drive_amp_2')
ax[1].plot(f_theta['tg'], f_theta['detune_1'], '.-', label=r'zp0:detune_1')
ax[1].plot(f_theta['tg'], f_theta['detune_2'], '.-', label=r'zp0:detune_2')
ax[2].plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'fidelity_zp0')

ax[2].plot(para_theta[:,0], 10**f500_theta, '.--', label=r'fidelity_zp1')
ax[0].plot(para_theta[:,0], para_theta[:,1], '.--', label=r'zp1:drive_amp_1')
ax[0].plot(para_theta[:,0], para_theta[:,2], '.--', label=r'zp1:drive_amp_2')
ax[1].plot(para_theta[:,0], para_theta[:,3], '.--', label=r'zp1:detune_1')
ax[1].plot(para_theta[:,0], para_theta[:,4], '.--', label=r'zp1:detune_2')
plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].legend(loc='best', fontsize=12)
    ax[i].grid()
    # ax[i].set_xlim(25, 40)
    # ax[i].set_xlim(150, 200)

# %%
f_theta_pick = f_theta.to_numpy()[[0,3,6,9,12,15],:]
f_ideal = np.array([
-0.4910633820518103, -2.7698332063770645, -4.103645121794385, -4.962721017092489 ,
-5.495481812444968, -6.266506251930366 ,
])


f_2us = np.array([
-0.4852392773794758, -1.8103109763789313, -1.7383137858262023, -1.6400731436278173 ,
-1.5597414091633022, -1.4291333344410448 ,
])
f_inf_10us = np.array([
-0.49075326297406857, -2.607922630433667, -2.96346809839368, -2.8838710151948104 ,
-2.790400757975588, -2.643570848671563 ,
])
f_inf_20us = np.array([
-0.4909043240867041, -2.681577946720095, -3.2523021596260886, -3.2044617502862307 ,
-3.104114501168851, -2.950225240978936 ,
])
f_inf_30us = np.array([
-0.4909559749860134, -2.7092160291721115, -3.416726416135844, -3.401304862310382 ,
-3.293593999581745, -3.1324402962506097 ,
])
f_inf_50us = np.array([
-0.4909978011473404, -2.732678427864347, -3.6162655999580506, -3.668154459242944 ,
-3.5437341226857866, -3.3670661180746353 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.plot(f_theta_pick[:,0], 10**f_theta_pick[:,-1], '.-', label=r'f_500')
plt.plot(f_theta_pick[:,0], 10**f_ideal, '.-', label=r'f_ideal_78')
plt.plot(f_theta_pick[:,0], 10**f_2us, '.--', label=r'f_noise_78_2us')
plt.plot(f_theta_pick[:,0], 10**f_inf_10us, '.--', label=r'f_noise_78_10us')
plt.plot(f_theta_pick[:,0], 10**f_inf_20us, '.--', label=r'f_noise_78_20us')
plt.plot(f_theta_pick[:,0], 10**f_inf_30us, '.--', label=r'f_noise_78_30us')
plt.plot(f_theta_pick[:,0], 10**f_inf_50us, '.--', label=r'f_noise_78_50us')
plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
# plt.axhline(y= g*tg/10e3, color='black', linestyle='--', label=r'$T_1^{0-7}=10\ \mu s$')
# plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate $n_\theta$ (truc=78, mstep=1e-3, 3ncut)')
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f_theta_pick = f_theta.to_numpy()[[0,3,6,9,12,15],:]
f_ideal_105_10us = np.array([
-0.4840772692419313, -2.774138643210286, -4.11026043832185, -4.977262632118764 ,
-5.475604274814514, -6.2364312201367404 ,
])
f_noise_105_10us = np.array([
-0.48379190259040533, -2.6132729056349393, -2.969340178083151, -2.8808487877920226 ,
-2.7894955171827425, -2.6449229983006446 ,
])

f_ideal_157_10us = np.array([
-0.4769677267949767, -2.7912553972089627, -4.121553746975662, -4.992674571747171 ,
-5.458955572454935, -6.124622380481844 ,
])
f_noise_157_10us = np.array([
-0.47682239513588054, -2.6264055229875534, -2.970256539379118, -2.87214573651417 ,
-2.784528503577153, -2.6469359731733535 ,
])

f_ideal_55_10us = np.array([
-0.4953064686394687, -2.8844148104221463, -4.230797359308311, -5.349051637514103 ,
-6.187667741310885, -7.301258275062352 ,
])
f_noise_55_10us = np.array([
-0.49494414559358946, -2.677938227677573, -2.9448255476248866, -2.8575132092150204 ,
-2.7733979851395287, -2.637060889372834 ,
])

f_ideal_150_10us = np.array([
-0.4910702902785794, -2.7719532943357663, -4.100638256934594, -4.917043083788133 ,
-5.464268282621023, -6.382617729632303 ,
])
f_noise_150_10us = np.array([
-0.4907785013525453, -2.6120058183666948, -2.9883598962327547, -2.8806284477052717 ,
-2.787547516571787, -2.6420212612249165 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.plot(f_theta_pick[:,0], 10**f_theta_pick[:,-1], '.-', label=r'f_500')
# plt.plot(f_theta_pick[:,0], 10**f_ideal_55_10us, '.-', label=r'f_ideal_55')
# plt.plot(f_theta_pick[:,0], 10**f_noise_55_10us, '.--', label=r'f_noise_55')
plt.plot(f_theta_pick[:,0], 10**f_ideal, '.-', label=r'f_ideal_78')
plt.plot(f_theta_pick[:,0], 10**f_inf_10us, '.--', label=r'f_noise_78')
plt.plot(f_theta_pick[:,0], 10**f_ideal_105_10us, '.-', label=r'f_ideal_105')
plt.plot(f_theta_pick[:,0], 10**f_noise_105_10us, '.--', label=r'f_noise_105')
plt.plot(f_theta_pick[:,0], 10**f_ideal_157_10us, '.-', label=r'f_ideal_157')
plt.plot(f_theta_pick[:,0], 10**f_noise_157_10us, '.--', label=r'f_noise_157')

plt.plot(f_theta_pick[:,0], 10**f_ideal_150_10us, '.-', label=r'f_ideal_150_full')
plt.plot(f_theta_pick[:,0], 10**f_noise_150_10us, '.--', label=r'f_noise_150_full')
plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
# plt.axhline(y= g*tg/10e3, color='red', linestyle='--', label=r'$T_1^{0-7}=10\ \mu s$')
# plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate $n_\theta$ (10us, mstep=1e-3, 3ncut)')
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
ftheta_ideal_30 = np.array([
-0.461330602605662, -0.9700190935558803, -2.005608641187015, -2.4719235383906484 ,
-2.7672031799005086, -2.873535557239684, -2.7841070554455807, -2.7622160899413877 ,
-2.766017938275496, -2.770937502873421, -2.777920735542645, -2.807945341050634 ,
-2.839605442012072, -2.901080246366208, -2.9678863343680693, -3.030555644081004 ,
-3.094779194272048, -3.1592757815567163 ,
])

ftheta_noise_30 = np.array([
-0.456865128016097, -0.9371135860333678, -1.6741696085215731, -1.790569494922504 ,
-1.7896558980342474, -1.757244941708474, -1.7123995942246477, -1.6724212465049955 ,
-1.6430970306508514, -1.6139768097068388, -1.593117150615664, -1.56524666538501 ,
-1.540315954597818, -1.4965701173506074, -1.4565541165630405, -1.4195822482668325 ,
-1.3853421167939892, -1.3536108866665446 ,
])
ftheta_ideal_40 = np.array([
-0.605034566968221, -1.229520191767138, -2.2579797396771766, -2.38625433115137 ,
-2.9515256965020624, -3.1685550856795652, -3.1677634595628734, -3.2606017910272485 ,
-3.341475583688872, -3.3967864915164294, -3.427982791012916, -3.4980192923344195 ,
-3.557312272378198, -3.6526348577480343, -3.7445732418753823, -3.821303445706697 ,
-3.899305193076052, -3.979659017163199 ,
])
ftheta_noise_40 = np.array([
-0.5962939560376574, -1.1634467591964404, -1.758335477045963, -1.756016663941303 ,
-1.7905714588638242, -1.761774697740648, -1.724803480565741, -1.6894738899333825 ,
-1.6613632297862346, -1.6323319592783148, -1.610998737258281, -1.5815561951096306 ,
-1.5549863862587099, -1.5083753211419124, -1.4658974884035834, -1.4270359126681562 ,
-1.3912866697007034, -1.3583723143652926 ,
])
ftheta_ideal_100 = np.array([
-0.49340468173154417, -0.9694391498271738, -2.142013465549031, -2.673241220100574 ,
-3.427649274366055, -3.8269219939923476, -4.227182757989097, -4.64269466646787 ,
-4.976647144552677, -5.26209889823497, -5.41431220781966, -5.595151699273812 ,
-5.701661733957301, -5.772870002823564, -5.7887761868115515, -5.790004282453417 ,
-5.783972692072418, -5.7302464479503294 ,
])

ftheta_noise_100 = np.array([
-0.48746921149438804, -0.9337734659482264, -1.7055520675612008, -1.7996318643153184 ,
-1.8064424791297415, -1.772435777434771, -1.737217427531704, -1.699334315983145 ,
-1.669242181674846, -1.638953713316035, -1.6169293493645265, -1.586316347771858 ,
-1.558919952792772, -1.5112390794295871, -1.4680131112495896, -1.4286643328971405 ,
-1.3925444519295398, -1.3593438009648098 ,
])
ftheta_ideal_200 = np.array([
-5.6283639431648025, -5.704117631690039, -5.741802808298386, -5.755173822933054 ,
-5.712671617423349 ,
])

ftheta_noise_200 = np.array([
-1.511236442681678, -1.468012746193586, -1.4286647144402096, -1.3925449585621394 ,
-1.3593442150062285 ,
])

ftheta_ideal_30_t9000 = np.array([
-0.46132809835332755, -0.9700120408898384, -2.0055474923510297, -2.4717400300681187 ,
-2.7668390290836093, -2.8730554289543084, -2.783709852261982, -2.761833449780701 ,
-2.7656288646799756, -2.7705409095587425, -2.777515029920555, -2.8075085448541413 ,
-2.839134106987179, -2.9005486932117406, -2.967247758226109, -3.0298205158767213 ,
-3.093948064102611, -3.15831079992048 ,
])

ftheta_noise_30_t9000 = np.array([
-0.4608121234553072, -0.9655789571871374, -1.9441086272405614, -2.2889600886653363 ,
-2.422760595730795, -2.4318675065246236, -2.3670744905915853, -2.32752084350137 ,
-2.304320464647864, -2.281185030315013, -2.2652256737790233, -2.248250811800367 ,
-2.232945729990991, -2.2043064318546435, -2.1765199479372095, -2.1482839179568223 ,
-2.120736366911444, -2.0939617908120773 ,
])

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_500')
plt.plot(f_theta['tg'], 10**ftheta_ideal_30, '.-', label=r'f_ideal_30')
plt.plot(f_theta['tg'], 10**ftheta_noise_30, '.--', label=r'f_noise_30')
plt.plot(f_theta['tg'], 10**ftheta_ideal_40, '.-', label=r'f_ideal_40')
plt.plot(f_theta['tg'], 10**ftheta_noise_40, '.--', label=r'f_noise_40')
# plt.plot(f_theta['tg'], 10**ftheta_ideal_30_t9000, '+', label=r'f_ideal_30_t9000')
# plt.plot(f_theta['tg'], 10**ftheta_noise_30_t9000, '.-', label=r'f_noise_30_t9000')
plt.plot(f_theta['tg'], 10**ftheta_ideal_100, '.--', label=r'f_ideal_100')
plt.plot(f_theta['tg'], 10**ftheta_noise_100, '.-', label=r'f_noise_100')
plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate 1ncut $n_\theta \ (1-F=0.75t_g/T_2)$(tg=%d)'%tg)
plt.grid()
legend = plt.legend( loc="best",)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fphi_ideal_30 = np.array([
-0.18019187973611184, -0.18447062010811885, -0.18534729492321297, -0.18320732807022921 ,
-0.1819756744382943, -0.17872004303330682, -0.17698721354271293, -0.17691185387184566 ,
-0.1799917183065255, -0.1780581600914333, -0.17696350167213523, -0.17660738910281495 ,
-0.17648421448420004, -0.17640671175056197, -0.17613925531632785, -0.17627903558660207 ,
-0.17642058625448875, -0.17612219313784563, -0.17610285267382214 ,
])

fphi_noise_30 = np.array([
-0.18023869896427083, -0.1844746815144653, -0.1853406369793755, -0.1832582828669888 ,
-0.18208391916996394, -0.17896638216321345, -0.17734622967526062, -0.17731930251355177 ,
-0.18029736035130292, -0.1784997811639335, -0.17751343012087065, -0.177230123578687 ,
-0.177164938355739, -0.17715385001854067, -0.17696168457435157, -0.17714120377587644 ,
-0.17733510894343227, -0.17711486495185, -0.17717526889729804 ,
])

fphi_ideal_100 = np.array([
-0.6457815250528595, -0.7671948805949267, -1.0595674498410295, -1.644233670951893 ,
-1.6798395443416994, -1.8606029124291454, -2.3555816811729478, -2.126593435371679 ,
-2.34530484619372, -2.3262903715466763, -2.3100953720311397, -2.440488260696564 ,
-2.331207290020214, -2.2906881843550555, -2.0928719921572125, -2.2527414401685184 ,
-2.2069740527882766, -2.1962042473089958, -2.049091388718098 ,
])

fphi_noise_100 = np.array([
-0.6252003247960661, -0.73275427763829, -0.9631751357016208, -1.2900672595662162 ,
-1.2642692070320485, -1.2705077228099069, -1.2796715905973746, -1.2338800634657834 ,
-1.2566310588740437, -1.2151816315638406, -1.1760750770927653, -1.149986028164136 ,
-1.118421404039458, -1.0885167681805947, -1.040067192217772, -1.0478037123407038 ,
-1.0314450718136476, -0.9990964821165951, -0.9608572976853174 ,
])
fphi_ideal_40 = np.array([
-0.3957498920991189, -0.46336948472726774, -0.5226762949777244, -0.5003354134466884 ,
-0.5634807405715914, -0.4821298026377649, -0.3024818912880113, -0.315725443840789 ,
-0.36464026947226147, -0.29197044148843065, -0.23636584109231476, -0.19849072451757593 ,
-0.18462103754279813, -0.17612430993158584, -0.18447071573258708, -0.18587348459156264 ,
-0.21020292068061588, -0.24454467604711466, -0.3166458820909759 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_500')
plt.plot(f_theta['tg'], 10**fphi_ideal_30, '.-', label=r'f_ideal_30')
plt.plot(f_theta['tg'], 10**fphi_noise_30, 'x', label=r'f_noise_30')
# plt.plot(f_phi['tg'], 10**fphi_ideal_40, '.-', label=r'f_ideal_40')
plt.plot(f_theta['tg'], 10**fphi_ideal_100, '.-', label=r'f_ideal_100')
plt.plot(f_theta['tg'], 10**fphi_noise_100, '.-', label=r'f_noise_100')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate $n_\phi$')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 fig, ax = plt.subplots(figsize=(6,3))
#       2 plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_500')
# ----> 3 plt.plot(f_theta['tg'], 10**fphi_ideal_30, '.-', label=r'f_ideal_30')
#       4 plt.plot(f_theta['tg'], 10**fphi_noise_30, 'x', label=r'f_noise_30')
#       5 # plt.plot(f_phi['tg'], 10**fphi_ideal_40, '.-', label=r'f_ideal_40')
#
# File ~/anaconda3/envs/qutip4/lib/python3.11/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
# ...

# %%
f157_phi = np.array([-0.40106527, -0.75167091, -1.09786349, -1.19616409 ,-1.53194675 ,])
f500_phi = np.array([-0.40119934, -0.74385016, -1.08980239, -1.18396283 , -1.52970251 ,])
para_phi = np.array([
[10.003267, 0.24348, 0.211892, 0.444743, 0.499987] ,
[20.000082, 0.255455, 0.169295, 0.338178, 0.443775] ,
[30.009674, 0.226521, 0.166161, 0.34729, 0.404246] ,
[40.008273, 0.169565, 0.211625, 0.342425, 0.34903] ,
[60.010631, 0.201448, 0.117206, 0.300092, 0.339997] ,
])

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3)
fig.suptitle(r'X-gate $n_\phi$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
ax[0].plot(f_phi['tg'], f_phi['drive_amp_1'], '.-', label=r'zp0:drive_amp_1')
ax[0].plot(f_phi['tg'], f_phi['drive_amp_2'], '.-', label=r'zp0:drive_amp_2')
ax[1].plot(f_phi['tg'], f_phi['detune_1'], '.-', label=r'zp0:detune_1')
ax[1].plot(f_phi['tg'], f_phi['detune_2'], '.-', label=r'zp0:detune_2')
ax[2].plot(f_phi['tg'], 10**f_phi['f_500'], '.-', label=r'fidelity_zp0')

ax[0].plot(para_phi[:,0], para_phi[:,1], '.-', label=r'zp1:drive_amp_1')
ax[0].plot(para_phi[:,0], para_phi[:,2], '.-', label=r'zp1:drive_amp_2')
ax[1].plot(para_phi[:,0], para_phi[:,3], '.-', label=r'zp1:detune_1')
ax[1].plot(para_phi[:,0], para_phi[:,4], '.-', label=r'zp1:detune_2')
ax[2].plot(para_phi[:,0], 10**f500_phi, '.-', label=r'fidelity_zp1')

plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].grid()
    # ax[i].set_xlim(25, 40)
    # ax[i].set_xlim(150, 200)
    legend = ax[i].legend(loc='best', fontsize=10)
    legend.get_frame().set_alpha(0.01)  # 0.5 makes the legend 50% transparent

# %%
=

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3)
fig.suptitle(r'X-gate $n_\theta$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
ax[0].plot(f_theta['tg'], f_theta['drive_amp_1'], '.-', label=r'$n_\theta$:drive_amp_1')
ax[0].plot(f_theta['tg'], f_theta['drive_amp_2'], '.-', label=r'$n_\theta$:drive_amp_2')
ax[1].plot(f_theta['tg'], f_theta['detune_1'], '.-', label=r'$n_\theta$:detune_1')
ax[1].plot(f_theta['tg'], f_theta['detune_2'], '.-', label=r'$n_\theta$:detune_2')
# ax[2].plot(f_theta['tg'], 10**f_theta['f_157'], '.-', label=r'f_157')
ax[2].plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_500')
ax[2].plot(f_theta_1ncut['tg'], 10**f_theta_1ncut['f_500'], '.-', label=r'f_500_1ncut')

plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].legend(loc='best', fontsize=12)
    ax[i].grid()
    # ax[i].set_xlim(25, 40)
    # ax[i].set_xlim(150, 200)

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3)
fig.suptitle(r'X-gate $n_\phi$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
ax[0].plot(f_phi['tg'], f_phi['drive_amp_1'], '.-', label=r'drive_amp_1')
ax[0].plot(f_phi['tg'], f_phi['drive_amp_2'], '.-', label=r'drive_amp_2')
ax[1].plot(f_phi['tg'], f_phi['detune_1'], '.-', label=r'detune_1')
ax[1].plot(f_phi['tg'], f_phi['detune_2'], '.-', label=r'detune_2')
# ax[2].plot(f_phi['tg'], 10**f_phi['f_160'], '.-', label=r'f_phi_3ncut')
ax[2].plot(f_phi['tg'], 10**f_phi['f_500'], '.-', label=r'f_phi_3ncut_500')
ax[2].plot(f_phi_1ncut['tg'], 10**f_phi_1ncut['f_500'], '.-', label=r'f_phi_1ncut_500')
plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].legend(loc='best', fontsize=12)
    ax[i].grid()
    # ax[i].set_xlim(25, 40)
    # ax[i].set_xlim(150, 200)

# %%
=
# Out:
#   Cell In[7], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %%
f_300= np.array([
-1.46077394, -2.19906405, -2.90461442, -3.62523544 ,
-4.03806759, -4.4332224, -4.75257569, -4.90651287 ,
-5.04976356, -5.24134123, -5.40882835, -5.61706204 ,
-5.73780323, -5.76831101, -5.76233218, -5.69815342 ,
])
leakage_300= np.array([
0.03377333, 0.00604388, 0.00119418, 0.00022972 ,
9.109e-05, 3.636e-05, 1.758e-05, 1.234e-05 ,
8.68e-06, 5.49e-06, 3.78e-06, 2.24e-06 ,
1.65e-06, 1.48e-06, 1.47e-06, 1.48e-06 ,
])

f_phi_300_unitary = np.array([
-0.5480401, -0.6728601, -0.77256596, -1.11328614 ,
-1.34345521, -1.57821601, -1.62516542, -1.65216837 ,
-1.76722751, -1.84499704, -2.02135056, -1.95997496 ,
-2.10162104, -2.1737414, -2.49066392, -2.43980362 ,
-2.56593641, -2.70904585, -2.54755593 ,
])
leakage_phi_300 = np.array([
0.26979764, 0.19477552, 0.15808094, 0.05848223 ,
0.04310577, 0.02598701, 0.02331423, 0.02192492 ,
0.01626642, 0.01399647, 0.00944966, 0.0107493 ,
0.00786211, 0.00664846, 0.00322691, 0.00360591 ,
0.00268659, 0.00191312, 0.00279736 ,
])

# %%
tg_peter =  np.arange(20, 210, 10)
f_peter_200 = np.array([
-0.82707509, -0.8340652, -0.82227775, -0.8147383 ,
-1.07723559, -0.72991757 ,
-0.72061041, -0.70539987, -0.71889157, -0.5643321 ,
-0.60553461, -0.52135402, -0.47834509, -0.50532184 ,
-0.58888034, -0.6124411, -0.4746966, -0.44261567 ,
-0.52851414 ,
])
f_peter_300 = np.array([
-0.78881089, -0.78606029, -0.77908916, -0.62418737 ,
-0.70601525, -0.37711677 ,
-0.46987989, -0.45861733, -0.37741561, -0.29399604 ,
-0.41743811, -0.35668414, -0.41435171, -0.12503593 ,
-0.36574271, -0.34397562, -0.34445034, -0.14946846 ,
-0.3449492 ,
])
f_peter_30 = np.array([
-0.69505277, -0.98448866, -1.28667674, -1.45316385 ,
-1.80372807, -1.73424621 ,
-1.93807113, -1.81988892, -2.3845121, -2.15238949 ,
-1.68216635, -1.99352278, -2.37518297, -2.36602526 ,
-2.14386744, -1.9307199, -1.96209909, -2.11739249 ,
-1.78362674 ,
])

tg_30_v2 =  [20, 40, 60, 80, 100, 120, 140, 160]
f_peter_30_v2 = np.array([
-0.88672394, -1.005142, -1.55509345, -1.99109511 ,
-1.8641355, -1.88214733, -2.30104491, -2.49091768 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'$n_\theta$_Andras_500')
# plt.plot(f_theta['tg'], 10**f_300, '.-', label=r'$n_\theta$:unitary_fidelity')
# plt.plot(f_theta['tg'], leakage_300, '.-', label=r'$n_\theta$:leakage_300')
# plt.plot(tg_peter, 10**f_peter_200, '.-', label=r'$n_\theta$_Peter_200')
# plt.plot(tg_peter, 10**f_peter_300, '.-', label=r'$n_\theta$_Peter_300')
plt.plot(tg_peter, 10**f_peter_30, '.-', label=r'$n_\theta$_Peter_30')
plt.plot(tg_30_v2, 10**f_peter_30_v2, '.-', label=r'$n_\theta$_Peter_30_v2')

# plt.plot(f_phi['tg'], 10**f_phi_300_v2, '.-', label=r'$n_\phi$:unitary_fidelity')
# plt.plot(f_phi['tg'], leakage_phi_300_v2, '.-', label=r'$n_\phi$:leakage_300')
# plt.plot(f_phi['tg'], 10**f_phi['f_2000'], '.--', label=r'$n_\phi$_Andras')
plt.axhline(y= 1-0.985, color='b', linestyle='--', label=r'F=98.6% (Abdelhafez)')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.ylabel('Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
