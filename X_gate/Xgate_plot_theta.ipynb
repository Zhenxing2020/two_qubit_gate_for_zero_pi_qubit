# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# f_cnot = pd.read_csv('data/data_cnot_45_2A.txt')
# f_n2_20 = pd.read_csv('../cz/data/data_fig/data_cz_n2_20.txt')
f_theta_1ncut = pd.read_csv('data/other/data_xgate_theta_1ncut.txt')
f_phi_1ncut = pd.read_csv('data/other/data_xgate_phi_1ncut.txt')
f_theta = pd.read_csv('data/data_xgate_theta_3ncut.txt')
f_phi = pd.read_csv('data/data_xgate_phi_3ncut.txt')
# df = pd.DataFrame(f_comb, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1',
#                                    'detune_2', 'f_157', 'f_500',  'f_noise_9_2us', 'f_noise_100_5us', 'f_noise_100_50us', 'f_78'])
# df.to_csv('data/data_xgate_theta_3ncut.txt', sep=',', index=False, header=True)
params = f_theta[['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2'
                    ]].to_numpy() [1::4, :]

colors = [
    '#1f77b4',  # Blue
    '#ff7f0e',  # Orange
    '#2ca02c',  # Green
    '#d62728',  # Red
    '#9467bd',  # Purple
    '#8c564b',  # Brown
    '#e377c2',  # Pink
    '#7f7f7f',  # Gray
    '#bcbd22',  # Yellow-green
    '#17becf'   # Cyan
]

# %%
print(' ', np.round(10**-3.5286973113799185  , 8) )
# Out:
#   0.00029601

# %% [markdown]
# ### Find best truncation
#
# max_step=3e-4

# %%
f_ideal_55 = np.array([
-0.4952989209748051, -0.9750864069386653, -2.1762804560680187, -2.8841389201139527 ,
-3.422628246811922, -3.8434862818923343, -4.233575431176374, -4.677474870329673 ,
-5.012920766913601, -5.353581903081116, -5.611037854005285, -5.93131650740306 ,
-6.209646950444646, -6.553564294307515, -6.934702252410016, -7.36693863981132 ,
-7.052201779810175, -7.695129169449177 ,
])
f_ideal_59 = np.array([
-0.4880718965341387, -0.9783969455087297, -2.181562953360337, -2.8988572665533314 ,
-3.437147674633219, -3.8517008334512632, -4.240684415504272, -4.681826145048625 ,
-5.013313040449415, -5.352587776433708, -5.604066741623058, -5.921719461690158 ,
-6.207910633594867, -6.561361163743207, -6.935652428893715, -7.378872934990837 ,
-7.047966642088174, -7.678477654075753 ,
])
f_ideal_63 = np.array([
-0.4985683098014894, -0.9827626670196494, -2.2548237167441814, -2.9930651864258264 ,
-3.551821139654499, -3.967087797100846, -4.344709994002454, -4.761299118426912 ,
-5.063918563497289, -5.380174567496063, -5.617573672651362, -5.921721063303754 ,
-6.205059546648846, -6.5630167316657575, -6.929883861854128, -7.373570473945196 ,
-7.047897012782581, -7.647475537939448 ,
])
f_ideal_70 = np.array([
-0.4919617412656398, -0.9780390205702874, -2.2266761174919396, -2.9884207529783353 ,
-3.5512738966024755, -3.9663716392812587, -4.346405290078726, -4.764763707455171 ,
-5.067543965299129, -5.385403827059692, -5.621874669332259, -5.925050687996824 ,
-6.21003768110777, -6.571709770038175, -6.9282219400443985, -7.371259685650962 ,
-7.045808952762617, -7.627511932656508 ,
])
f_ideal_76 = np.array([
-0.49599857324312013, -0.8802068614432665, -1.8898135232801145, -2.76658631519469 ,
-3.3493887619714227, -3.7658386750106287, -4.117894861071901, -4.478870143948168 ,
-4.738140158968169, -4.995124594928574, -5.177792549997062, -5.415609848790415 ,
-5.626925840363245, -5.953800699360282, -6.254077912650524, -6.546792271591325 ,
-6.640790912942781, -6.967658017146375 ,
])
f_ideal_78 = np.array([
-0.4910401279060491, -0.8788087913806248, -1.9092459162631445, -2.7694128276542247 ,
-3.341884243798919, -3.7530981001621195, -4.101265966511826, -4.457766375638734 ,
-4.714158592362988, -4.968023026496211, -5.148294981427083, -5.383688856889358 ,
-5.592911697258704, -5.9191030412597225, -6.217924075791553, -6.508004132593557 ,
-6.612541926604733, -6.930806814043593 ,
])
f_ideal_100 = np.array([
-0.49529925025664634, -0.975087370443019, -2.176285980444016, -2.8841535790432493 ,
-3.4226588282662362, -3.843531184200982, -4.2336440021642385, -4.677575855869898 ,
-5.013049523545664, -5.353756199842104, -5.6112860429006455, -5.93162447206822 ,
-6.210072711449519, -6.553964703556435, -6.9349569736632475, -7.366471667124848 ,
-7.049942848320972, -7.684301935452057 ,
])
f_ideal_157 = np.array([
-0.4769510348817827, -0.8906153488846216, -1.939246848191887, -2.790873370655956 ,
-3.3631461930231796, -3.772191658186468, -4.119779608582934, -4.476160690563936 ,
-4.7324947819096455, -4.987352803229129, -5.1683638084418435, -5.40460290008453 ,
-5.615373829228771, -5.94258067188785, -6.2406314873662545, -6.531872251431755 ,
-6.629353889143676, -6.94700158804423 ,
])
f_ideal_500 = np.array([
-0.4768675209404182, -0.8896245836286782, -1.940226809840099, -2.7919084217410095 ,
-3.363639246003947, -3.77240122168517, -4.119876709167307, -4.476080627787024 ,
-4.7322718481350154, -4.986955240785758, -5.167946409697648, -5.403979403607491 ,
-5.614900843393097, -5.943264394436332, -6.240010397491758, -6.529790195540401 ,
-6.627806005151546, -6.935072288899299 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_ideal_500, 'D-', label=r'n_charge=500')
# plt.plot(f_theta['tg'], 10**f_ideal_157, 'v-', label=r'n_charge=157')
# plt.plot(f_theta['tg'], 10**f_ideal_100, 's-', label=r'n_charge=100')
plt.plot(f_theta['tg'], 10**f_ideal_78, '.-', label=r'n_charge=78')
plt.plot(f_theta['tg'], 10**f_ideal_76, '.-', label=r'n_charge=76')
plt.plot(f_theta['tg'], 10**f_ideal_70, '.-', label=r'n_charge=70')
# plt.plot(f_theta['tg'], 10**f_ideal_63, '.-', label=r'n_charge=63')
# plt.plot(f_theta['tg'], 10**f_ideal_59, '.-', label=r'n_charge=59')
# plt.plot(f_theta['tg'], 10**f_ideal_55, '.-', label=r'n_charge=55')
plt.title(r'X gate $n_\theta$ Ideal, max_step=3e-4')
plt.yscale('log')
plt.ylim(1e-8, 1e0)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Infidelity')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Check max_steps
#
# truncation = 500, no charge pick

# %%
f_1e6 = np.array([
-0.8896162115157531, -3.772849560387933, -4.987050189878212, -5.939595305180405 ,
-6.950824848765797 ,
])
f_1e5 = np.array([
-0.8896183802244116, -3.7729249196612433, -4.987184712411418, -5.939820459183566 ,
-6.951983634222558 ,
])
f_1e4 = np.array([
-0.8896202810196633, -3.773200969174526, -4.988596030259518, -5.943190503304305 ,
-6.96135645552231 ,
])
f_3e4 = np.array([
-0.8896245836286782, -3.77240122168517, -4.986955240785758, -5.943264394436332 ,
-6.935072288899299 ,
])
f_1e3 = np.array([
-0.889660225337849, -3.7654955645317676, -4.931589891271577, -5.599013203824828 ,
-5.829376467622418 ,
])
f_0 = np.array([
-0.889671022617285, -3.7672130524617193, -4.929447138269877, -5.58886678498183 ,
-5.804948598807993 ,
])
msteps = [1e-6, 1e-5, 1e-4, 3e-4, 1e-3]
f_ideal_truc500 = np.column_stack((f_1e6, f_1e5, f_1e4, f_3e4, f_1e3))
f_ideal_truc500
# Out:
# array([[-0.88961621, -0.88961838, -0.88962028, -0.88962458, -0.88966023],
#        [-3.77284956, -3.77292492, -3.77320097, -3.77240122, -3.76549556],
#        [-4.98705019, -4.98718471, -4.98859603, -4.98695524, -4.93158989],
#        [-5.93959531, -5.93982046, -5.9431905 , -5.94326439, -5.5990132 ],
#        [-6.95082485, -6.95198363, -6.96135646, -6.93507229, -5.82937647]])

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(msteps, 10**f_ideal_truc500[i], 'D-', label=fr'$t_g = {params[:,0][i]:.0f}$ns')
    ax[i].set_xscale('log')
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    # ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')
ax[4].set_xlabel('max_step')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta$ ideal ')
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(params[:,0], 10**f_1e6, 'D-', label=r'max_step=1e-6 (10.2hours)')
# plt.plot(params[:,0], 10**f_1e5, 'v-', label=r'max_step=1e-5 (50 minutes)')
# plt.plot(params[:,0], 10**f_1e4, 'x-', label=r'max_step=1e-4 (4.5 minutes)')
plt.plot(params[:,0], 10**f_3e4, '+-', label=r'max_step=3e-4 (1.5 minutes)')
plt.plot(params[:,0], 10**f_1e3, 'x--', label=r'max_step=1e-3 (1.3 minute)')
# plt.plot(params[:,0], 10**f_0, '.--', label=r'max_step=0 (1 minute)')

plt.title(r'X gate $n_\theta$ Ideal, trucation=500')
plt.yscale('log')
plt.ylim(1e-7, 1e0)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Infidelity')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Check truncation

# %%
f_theta_900 = np.array([
-0.476903128108458, -0.8896790648763959, -1.9414180711112312, -2.7917104650355107 ,
-3.3615629556409408, -3.76670794004569, -4.1048234622714865, -4.437418453807678 ,
-4.672443262776792, -4.87965007490315, -5.018296267214746, -5.172646997599651 ,
-5.272078257282874, -5.406238591742835, -5.487760379794714, -5.5065875431524764 ,
-5.550701182129182, -5.526733535099553 ,
])
f_theta_800 = np.array([
-0.4768992363452663, -0.8896673555328354, -1.9406763484324778, -2.7915189638838576 ,
-3.361289481068896, -3.7663642908392974, -4.107990954183725, -4.445209806184739 ,
-4.68248249782077, -4.8976924266252775, -5.034860526652693, -5.192055036289345 ,
-5.308201759663773, -5.45881792077373, -5.510564655945, -5.581430090284119 ,
-5.577383546966255, -5.588311232978919 ,
])
f_theta_700 = np.array([
-0.47689846834235705, -0.8896715184296968, -1.9406888506995372, -2.7917535450512303 ,
-3.3614688529894585, -3.767005570860691, -4.107959685735577, -4.450135764637316 ,
-4.685627698961644, -4.905614062181384, -5.04696767843294, -5.216399748488768 ,
-5.360053232487924, -5.501715724828387, -5.569698785245428, -5.621985216765386 ,
-5.617470589548146, -5.656845808367973 ,
])
f_theta_600 = np.array([
-0.47689378940831506, -0.8896531181941285, -1.9406050359148532, -2.795772902094325 ,
-3.361504069848514, -3.7675982151685723, -4.1103825752779075, -4.454822721262368 ,
-4.692197293951154, -4.922273881833251, -5.072605756396119, -5.245843322191953 ,
-5.385003203406441, -5.553945402542144, -5.6496952987013085, -5.720864890422338 ,
-5.700466888663011, -5.752246741687437 ,
])
n_truc_large = [ 300, 400, 500, 600, 700, 800, 900, 1000]

f_ideal_large = np.column_stack((
    f_theta['f_300'].to_numpy(), 
    f_theta['f_400'].to_numpy(), 
    f_theta['f_500'].to_numpy(), 
    f_theta_600, f_theta_700, f_theta_800, f_theta_900, 
    f_theta['f_1000'].to_numpy(), 
    ))[[1, 5, 9, 13, 17 ], ]

# np.shape(f_ideal_large)

# %% [markdown]
# ### fidelity convergence

# %%
f_ideal_181 = np.array([
-0.8894435183030804, -3.7740314663864702, -4.972461997150224, -5.79304130916251 ,
-6.234505290340139 ,
])
f_170us_181 = np.array([
-0.8892363422147926, -3.6630655038726117, -3.911777621846385, -3.8230675389802995 ,
-3.7317271419634994 ,
])
f_ideal_157 = np.array([
-0.8906454796863686, -3.7728852130070125, -5.041233712054058, -5.826554357869655 ,
-6.304700284172778 ,
])
f_170us_157 = np.array([
-0.8904604187449506, -3.6911349543826275, -3.984849674773383, -3.8141472886797683 ,
-3.716158794767101 ,
])
f_ideal_131 = np.array([
-0.8899526270578597, -3.770946298533558, -5.085064189588203, -5.88818635660766 ,
-6.372963710092098 ,
])
f_170us_131 = np.array([
-0.8896748560073189, -3.6739120135633607, -4.103107210095756, -3.8680271397941453 ,
-3.6676030066743746 ,
])

f_ideal_118 = np.array([
-0.8895514183022839, -3.7738659293347343, -5.077598594722927, -6.030417971044005 ,
-6.425523127106116 ,
])
f_170us_118 = np.array([
-0.8892518583327204, -3.666054584861276, -4.103579008527569, -3.8581596841628247 ,
-3.6296301204273584 ,
])

f_ideal_105 = np.array([
-0.8808101887749133, -3.7613829988020133, -5.030208177791011, -6.249308006502248 ,
-6.4852271253988185 ,
])
f_170us_105 = np.array([
-0.8804792039741156, -3.6484379347551963, -4.1122545970407565, -3.8536222714874406 ,
-3.634089367884747 ,
])
f_ideal_92 = np.array([
-0.9013855959648269, -3.7413446881487284, -4.963426257688915, -6.292924645231845 ,
-6.555420181452293 ,
])
f_170us_92 = np.array([
-0.9010364268166411, -3.6255850040440123, -4.1223566622673875, -3.846798074484321 ,
-3.620592884235752 ,
])
f_ideal_78 = np.array([
-0.8788633187240702, -3.7599186024639493, -4.961652206723905, -6.307173709173524 ,
-6.683187068075573 ,
])
f_170us_78 = np.array([
-0.8785264587790031, -3.626497486382378, -4.166947136261655, -3.850004150685549 ,
-3.60758325502953 ,
])
f_ideal_68 = np.array([
-0.9782311932401822, -3.9687225806042803, -5.420059410371868, -6.4127236717783935 ,
-6.724599355489097 ,
])
f_170us_68 = np.array([
-0.9777715666100574, -3.675802970005805, -3.8233011441497666, -3.703013377185887 ,
-3.6061348564729814 ,
])
f_ideal_55 = np.array([
-0.9751038167729129, -3.8447486648093503, -5.352699243716754, -6.457571640173486 ,
-6.95752184824705 ,
])
f_170us_55 = np.array([
-0.9746530896357324, -3.612175488855331, -3.8238394080624936, -3.7065891700442872 ,
-3.6035173186281364 ,
])
f_ideal_41 = np.array([
-0.9044241751797325, -3.685784054661029, -5.356750640149107, -6.287261205003941 ,
-7.339741782962481 ,
])
f_170us_41 = np.array([
-0.9040103621009893, -3.5095868285505496, -3.826083561415875, -3.6944653404126404 ,
-3.540968090555939 ,
])

n_truc = [41, 55, 68, 78, 92, 105, 118, 131, 157, 181]
f_170us = np.column_stack((f_170us_41, f_170us_55, f_170us_68, f_170us_78, 
                           f_170us_92, f_170us_105, f_170us_118, f_170us_131, 
                           f_170us_157, f_170us_181, ))
f_ideal = np.column_stack((f_ideal_41, f_ideal_55, f_ideal_68, f_ideal_78, 
                           f_ideal_92, f_ideal_105, f_ideal_118, f_ideal_131, 
                           f_ideal_157, f_ideal_181,  ))

# %%
f_ideal_3e4_100 = np.array([
-0.975087370443019, -3.843531184200982, -5.353756199842104, -6.553964703556435 ,
-7.684301935452057 ,
])
f_ideal_3e4_200 = np.array([
-0.8807583664544218, -3.7608945832065093, -4.983467385291614, -5.942940874132047 ,
-6.947402397241186 ,
])
f_ideal_3e4_300 = np.array([
-0.8906157015191669, -3.772242486397306, -4.987648860974033, -5.94370525593791 ,
-6.943343548407614 ,
])
f_ideal_3e4_400 = np.array([
-0.8895971182952138, -3.7727044856849745, -4.987539205236665, -5.943825374304322 ,
-6.938939813986679 ,
])
f_ideal_3e4_500 = np.array([
-0.8896245836286782, -3.77240122168517, -4.986955240785758, -5.943264394436332 ,
-6.935072288899299 ,
])
f_ideal_3e4_600 = np.array([
-0.8896294798534035, -3.772208639134615, -4.986657401013696, -5.943147339907898 ,
-6.931877271181984 ,
])
f_ideal_3e4_700 = np.array([
-0.8896291703510549, -3.772110798888699, -4.986503612945826, -5.943197413732836 ,
-6.929126066338575 ,
])
f_ideal_3e4_800 = np.array([
-0.8896286751712543, -3.7720672367887236, -4.986436846787878, -5.943487696034406 ,
-6.926156022339486 ,
])
f_ideal_3e4_900 = np.array([
-0.8896289093752379, -3.77205559292962, -4.98645591015109, -5.943907598053868 ,
-6.9236136748069725 ,
])
f_ideal_3e4_1000 = np.array([
-0.8896294989838538, -3.7717739353600197, -4.985327308523193, -5.9419097405082235 ,
-6.876490155400263 ,
])
n_truc_2 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
f_ideal_3e4 = np.column_stack((f_ideal_3e4_100, f_ideal_3e4_200, f_ideal_3e4_300, 
                               f_ideal_3e4_400, f_ideal_3e4_500, f_ideal_3e4_600,
                               f_ideal_3e4_700, f_ideal_3e4_800, f_ideal_3e4_900, 
                               f_ideal_3e4_1000, ))

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(n_truc, 10**f_ideal[i], '.-', color=colors[0], label=fr'max_step=0')  # Change label if needed
    ax[i].plot(n_truc_large, 10**f_ideal_large[i], '.-', color=colors[0])  # Change label if needed
    # ax.set_yscale('log')
    ax[i].plot(n_truc_2, 10**f_ideal_3e4[i], 'x-', color=colors[1], label=fr'max_step=3e-4')  # Change label if needed
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')
ax[4].set_xlabel('truncation')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta$ ideal ')
# axes[4].set_ylim(0, 1e-4)
plt.tight_layout()

# %%
truc_3e4 = np.array([55, 78, 105, 131, 157])
f_170us_3e4 = np.array([-3.5176308297943346 , -3.5119800529022025 ,-3.5111643193984126 , -3.511166900253059 , -3.511171382408034 , ])
truc_1e4 = np.array([55, 105, 157, 206])
f_170us_1e4 = np.array([ -3.528833513469994 ,-3.5286979319698335 , -3.5286973113799185 , -3.5286973057810966 ,])
f_170us_3e5 = np.array([ -3.5308716254070216 , -3.5307354032176392 , ])

f_55ns_170us_1e4 = np.array([ -3.8295710591483 ,])
f_80ns_170us_1e4 = np.array([ -3.7007806358278015,])

# %%
f_170us[4]
# Out:
# array([-3.54096809, -3.60351732, -3.60613486, -3.60758326, -3.62059288,
#        -3.63408937, -3.62963012, -3.66760301, -3.71615879, -3.73172714])

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(n_truc, 10**f_170us[i], '.-', color=colors[0], label=fr'max_step=1e-3')  # Change label if needed
ax[4].plot(truc_3e4, 10**f_170us_3e4, 'v-', color=colors[2], label=fr'max_step=3e-4')
ax[4].plot(truc_1e4, 10**f_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[2].plot(206, 10**f_55ns_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[3].plot(206, 10**f_80ns_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[4].plot(truc_1e4[:-2], 10**f_170us_3e5, 'x-', color=colors[3], label=fr'max_step=3e-5')
for i in range(5):
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')

ax[4].set_xlabel('truncation')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta\ 170\mu s$ ')
plt.tight_layout()

# %%
f_55 = np.array([

])
msteps = [3e-5, 1e-4, 3e-4, 1e-3]
f_ideal_truc500 = np.column_stack((f_1e6, f_1e5, f_1e4, f_3e4, f_1e3))
f_ideal_truc500
# Out:
# array([[-0.88961621, -0.88961838, -0.88962028, -0.88962458, -0.88966023],
#        [-3.77284956, -3.77292492, -3.77320097, -3.77240122, -3.76549556],
#        [-4.98705019, -4.98718471, -4.98859603, -4.98695524, -4.93158989],
#        [-5.93959531, -5.93982046, -5.9431905 , -5.94326439, -5.5990132 ],
#        [-6.95082485, -6.95198363, -6.96135646, -6.93507229, -5.82937647]])

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(msteps, 10**f_ideal_truc500[i], 'D-', label=fr'$t_g = {params[:,0][i]:.0f}$ns')
    ax[i].set_xscale('log')
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    # ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')
ax[4].set_xlabel('max_step')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta$ ideal ')
plt.tight_layout()

# %%
=
# Out:
#   Cell In[14], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.plot(params[:,0], 10**f_ideal_181, '.--', label=r'f_ideal_181') # 350
plt.plot(params[:,0], 10**f_ideal_157, '.--', label=r'f_ideal_157') # 300
plt.plot(params[:,0], 10**f_ideal_131, '.--', label=r'f_ideal_131') # 250
# plt.plot(params[:,0], 10**f_ideal_118, '.--', label=r'f_ideal_118') # 225
plt.plot(params[:,0], 10**f_ideal_105, '.--', label=r'f_ideal_105') # 200
# plt.plot(params[:,0], 10**f_ideal_92, '.--', label=r'f_ideal_92') # 175
plt.plot(params[:,0], 10**f_ideal_78, '.--', label=r'f_ideal_78') # 150
# plt.plot(params[:,0], 10**f_ideal_68, '.--', label=r'f_ideal_68') # 125
plt.plot(params[:,0], 10**f_ideal_55, '.--', label=r'f_ideal_55') # 100
# plt.plot(params[:,0], 10**f_ideal_41, '.--', label=r'f_ideal_41') # 75

plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_157, 's-', label=r'f_170us_157')
plt.plot(params[:,0], 10**f_170us_131, 's-', label=r'f_170us_131')
# plt.plot(params[:,0], 10**f_170us_118, 's-', label=r'f_170us_118')
plt.plot(params[:,0], 10**f_170us_105, 's-', label=r'f_170us_105')
# plt.plot(params[:,0], 10**f_170us_92, 's-', label=r'f_170us_92')
plt.plot(params[:,0], 10**f_170us_78, 's-', label=r'f_170us_78')
# plt.plot(params[:,0], 10**f_170us_68, 's-', label=r'f_170us_68')
plt.plot(params[:,0], 10**f_170us_55, 's-', label=r'f_170us_55')
# plt.plot(params[:,0], 10**f_170us_41, 's-', label=r'f_170us_41')
plt.title(r'X gate $n_\theta\ 170\mu s$: decay_all')
plt.yscale('log')
plt.ylim(1e-7, 1e0)
# plt.title(f"Mean Absolute Error: {mae2:.2e}")
# plt.xlabel('Gate Time $t_g$ (ns)')
# plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_157, 's-', label=r'f_170us_157')
plt.plot(params[:,0], 10**f_170us_131, 's-', label=r'f_170us_131')
# plt.plot(params[:,0], 10**f_170us_118, 's-', label=r'f_170us_118')
plt.plot(params[:,0], 10**f_170us_105, 's-', label=r'f_170us_105')
# plt.plot(params[:,0], 10**f_170us_92, 's-', label=r'f_170us_92')
plt.plot(params[:,0], 10**f_170us_78, 's-', label=r'f_170us_78')
# plt.plot(params[:,0], 10**f_170us_68, 's-', label=r'f_170us_68')
plt.plot(params[:,0], 10**f_170us_55, 's-', label=r'f_170us_55')
# plt.plot(params[:,0], 10**f_170us_41, 's-', label=r'f_170us_41')
plt.title(r'X gate $n_\theta\ 170\mu s$: decay_all')
plt.yscale('log')
# plt.ylim(6e-5, 4e-4)
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_78, 's-', label=r'f_170us_78')
plt.plot(params[:,0], np.abs(10**f_170us_78 - 10**f_170us_181), '.--', label=r'|f_170us_78 - f_170us_181|')
plt.yscale('log')
plt.ylim(1e-6, 2e-1)
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_105, 's-', label=r'f_170us_105')
plt.plot(params[:,0], np.abs(10**f_170us_105 - 10**f_170us_181), '.--', label=r'|f_170us_105 - f_170us_181|')
plt.yscale('log')
plt.ylim(1e-6, 2e-1)
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_131, 's-', label=r'f_170us_131')
plt.plot(params[:,0], np.abs(10**f_170us_181 - 10**f_170us_131), '.--', label=r'|f_170us_131 - f_170us_181|')
plt.yscale('log')
plt.ylim(1e-6, 2e-1)
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(params[:,0], 10**f_170us_181, 's-', label=r'f_170us_181')
plt.plot(params[:,0], 10**f_170us_157, 's-', label=r'f_170us_157')
plt.plot(params[:,0], np.abs(10**f_170us_181 - 10**f_170us_157), '.--', label=r'|f_170us_157 - f_170us_181|')
plt.yscale('log')
plt.ylim(1e-6, 2e-1)
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
=
# Out:
#   Cell In[6], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %%
f_theta_900 = np.array([
-0.476903128108458, -0.8896790648763959, -1.9414180711112312, -2.7917104650355107 ,
-3.3615629556409408, -3.76670794004569, -4.1048234622714865, -4.437418453807678 ,
-4.672443262776792, -4.87965007490315, -5.018296267214746, -5.172646997599651 ,
-5.272078257282874, -5.406238591742835, -5.487760379794714, -5.5065875431524764 ,
-5.550701182129182, -5.526733535099553 ,
])
f_theta_800 = np.array([
-0.4768992363452663, -0.8896673555328354, -1.9406763484324778, -2.7915189638838576 ,
-3.361289481068896, -3.7663642908392974, -4.107990954183725, -4.445209806184739 ,
-4.68248249782077, -4.8976924266252775, -5.034860526652693, -5.192055036289345 ,
-5.308201759663773, -5.45881792077373, -5.510564655945, -5.581430090284119 ,
-5.577383546966255, -5.588311232978919 ,
])
f_theta_700 = np.array([
-0.47689846834235705, -0.8896715184296968, -1.9406888506995372, -2.7917535450512303 ,
-3.3614688529894585, -3.767005570860691, -4.107959685735577, -4.450135764637316 ,
-4.685627698961644, -4.905614062181384, -5.04696767843294, -5.216399748488768 ,
-5.360053232487924, -5.501715724828387, -5.569698785245428, -5.621985216765386 ,
-5.617470589548146, -5.656845808367973 ,
])
f_theta_600 = np.array([
-0.47689378940831506, -0.8896531181941285, -1.9406050359148532, -2.795772902094325 ,
-3.361504069848514, -3.7675982151685723, -4.1103825752779075, -4.454822721262368 ,
-4.692197293951154, -4.922273881833251, -5.072605756396119, -5.245843322191953 ,
-5.385003203406441, -5.553945402542144, -5.6496952987013085, -5.720864890422338 ,
-5.700466888663011, -5.752246741687437 ,
])

# %%
f_1000 = 1 - 10**f_theta[['f_1000']].to_numpy().flatten()  # 模型1的保真度
f_78 = 1 - 10**f_theta[['f_78']].to_numpy().flatten()  # 模型2的保真度
f_157 = 1 - 10**f_theta[['f_157']].to_numpy().flatten()  # 模型2的保真度
f_300 = 1 - 10**f_theta[['f_300']].to_numpy().flatten()  
f_400 = 1 - 10**f_theta[['f_400']].to_numpy().flatten()  
f_500 = 1 - 10**f_theta[['f_500']].to_numpy().flatten()  
f_600 = 1 - 10**f_theta_600  
f_700 = 1 - 10**f_theta_700  
f_800 = 1 - 10**f_theta_800 
f_900 = 1 - 10**f_theta_900

mae2 = np.mean(np.abs(f_1000 - f_157)) # 平均绝对误差
max2 = np.max(np.abs(f_1000 - f_157)) # 最大绝对误差
percent2 = np.abs(f_1000 - f_157)/f_1000 # 绝对误差 百分比
print(f"MAE: {mae2:.2e}, Max: {max2:.2e}, Percent: {np.mean(percent2):.4%}")
print(np.abs(f_1000 - f_157))

mae3 = np.mean(np.abs(f_1000 - f_78)) # 平均绝对误差
max3 = np.max(np.abs(f_1000 - f_78)) # 最大绝对误差
percent3 = np.abs(f_1000 - f_78)/f_1000 # 绝对误差 百分比
print(f"MAE: {mae3:.2e}, Max: {max3:.2e}, Percent: {np.mean(percent3):.4%}")
print(np.abs(f_1000 - f_78))
# Out:
# MAE: 2.35e-05, Max: 2.89e-04, Percent: 0.0027%
# [4.51037323e-05 2.88830491e-04 3.79560582e-05 9.55107673e-07
#  2.90120125e-06 2.82445093e-06 3.02931920e-06 6.33687348e-06
#  5.87562511e-06 4.58370618e-06 3.76583889e-06 3.13579787e-06
#  3.13859473e-06 2.91054079e-06 3.02055510e-06 2.87907171e-06
#  2.74418447e-06 3.05247720e-06]
# MAE: 8.29e-04, Max: 1.07e-02, Percent: 0.1154%
# [1.06949218e-02 3.24757156e-03 8.54747269e-04 8.30465156e-05
#  1.55469686e-05 4.24039622e-06 6.21679598e-08 2.01058325e-06
#  2.49171213e-06 2.78164545e-06 2.75763412e-06 2.44189228e-06
#  2.63538863e-06 2.71377577e-06 3.09577188e-06 3.01236358e-06
#  3.05602204e-06 3.40194344e-06]

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['f_1000'], 's-', label=r'f_1000')
# plt.plot(f_theta['tg'], 10**f_theta['f_300'], 'v--', label=r'f_300')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_300), 'x--', label=r'|f_1000-f_300|')
# plt.plot(f_theta['tg'], 10**f_theta['f_400'], '+--', label=r'f_400')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_400), 'x--', label=r'|f_1000-f_400|')
# plt.plot(f_theta['tg'], 10**f_theta['f_500'], 'D--', label=r'f_500')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_500), 'x--', label=r'|f_1000-f_500|')

# plt.plot(f_theta['tg'], 10**f_theta_600, 'v--', label=r'f_600')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_600), 'x--', label=r'|f_1000-f_600|')
# plt.plot(f_theta['tg'], 10**f_theta_700, 'v--', label=r'f_700')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_700), 'x--', label=r'|f_1000-f_700|')
# plt.plot(f_theta['tg'], 10**f_theta_800, 'v--', label=r'f_800')
# plt.plot(f_theta['tg'], np.abs(f_1000 - f_800), 'x--', label=r'|f_1000-f_800|')
plt.plot(f_theta['tg'], 10**f_theta_900, 'v--', label=r'f_900')
plt.plot(f_theta['tg'], np.abs(f_1000 - f_900), 'x--', label=r'|f_1000-f_900|')



# plt.plot(f_theta['tg'], 10**f_theta['f_157'], 'x--', label=r'f_157')
# plt.plot(f_theta['tg'], 10**f_theta['f_157_low'], '.--', label=r'f_157_low')
# plt.plot(f_theta['tg'], 10**f_theta['f_78'], '.--', label=r'f_78')

# plt.plot(f_theta['tg'], np.abs(f1 - f2), '.--', label=r'f_1000 - f_157', color='black')
# plt.axhline(y=mae2, color='red', linestyle='--', label=f'MAE: {mae2:.2e}')
# plt.plot(f_theta['tg'], np.abs(f1 - f3), '.--', label=r'f_1000 - f_78', color='black')
# plt.axhline(y=mae3, color='red', linestyle='--', label=f'MAE: {mae3:.2e}')
plt.yscale('log')
plt.ylim(1e-7, 1e0)
# plt.title(f"Mean Absolute Error: {mae2:.2e}")
# plt.xlabel('Gate Time $t_g$ (ns)')
# plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_ideal')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_170us'], '.-', label=r'f_noise_170us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_30us'], '.-', label=r'f_noise_30us')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_3us'], '.-', label=r'f_noise_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ ', fontsize=15)
plt.grid()
legend = plt.legend( loc="lower left", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f_theta_pick = f_theta.to_numpy()[[0,3,6,9,12,15],:]
f_ideal_105_10us = np.array([
-0.4840772692419313, -2.774138643210286, -4.11026043832185, -4.977262632118764 ,
-5.475604274814514, -6.2364312201367404 ,
])
f_noise_105_10us = np.array([
-0.48379190259040533, -2.6132729056349393, -2.969340178083151, -2.8808487877920226 ,
-2.7894955171827425, -2.6449229983006446 ,
])

f_ideal_157_10us = np.array([
-0.4769677267949767, -2.7912553972089627, -4.121553746975662, -4.992674571747171 ,
-5.458955572454935, -6.124622380481844 ,
])
f_noise_157_10us = np.array([
-0.47682239513588054, -2.6264055229875534, -2.970256539379118, -2.87214573651417 ,
-2.784528503577153, -2.6469359731733535 ,
])

f_ideal_55_10us = np.array([
-0.4953064686394687, -2.8844148104221463, -4.230797359308311, -5.349051637514103 ,
-6.187667741310885, -7.301258275062352 ,
])
f_noise_55_10us = np.array([
-0.49494414559358946, -2.677938227677573, -2.9448255476248866, -2.8575132092150204 ,
-2.7733979851395287, -2.637060889372834 ,
])

f_ideal_150_10us = np.array([
-0.4910702902785794, -2.7719532943357663, -4.100638256934594, -4.917043083788133 ,
-5.464268282621023, -6.382617729632303 ,
])
f_noise_150_10us = np.array([
-0.4907785013525453, -2.6120058183666948, -2.9883598962327547, -2.8806284477052717 ,
-2.787547516571787, -2.6420212612249165 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.plot(f_theta_pick[:,0], 10**f_theta_pick[:,-1], '.-', label=r'f_500')
# plt.plot(f_theta_pick[:,0], 10**f_ideal_55_10us, '.-', label=r'f_ideal_55')
# plt.plot(f_theta_pick[:,0], 10**f_noise_55_10us, '.--', label=r'f_noise_55')
plt.plot(f_theta_pick[:,0], 10**f_ideal, '.-', label=r'f_ideal_78')
plt.plot(f_theta_pick[:,0], 10**f_inf_10us, '.--', label=r'f_noise_78')
plt.plot(f_theta_pick[:,0], 10**f_ideal_105_10us, '.-', label=r'f_ideal_105')
plt.plot(f_theta_pick[:,0], 10**f_noise_105_10us, '.--', label=r'f_noise_105')
plt.plot(f_theta_pick[:,0], 10**f_ideal_157_10us, '.-', label=r'f_ideal_157')
plt.plot(f_theta_pick[:,0], 10**f_noise_157_10us, '.--', label=r'f_noise_157')

plt.plot(f_theta_pick[:,0], 10**f_ideal_150_10us, '.-', label=r'f_ideal_150_full')
plt.plot(f_theta_pick[:,0], 10**f_noise_150_10us, '.--', label=r'f_noise_150_full')
plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
# plt.axhline(y= g*tg/10e3, color='red', linestyle='--', label=r'$T_1^{0-7}=10\ \mu s$')
# plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate $n_\theta$ (10us, mstep=1e-3, 3ncut)')
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
ftheta_ideal_30 = np.array([
-0.461330602605662, -0.9700190935558803, -2.005608641187015, -2.4719235383906484 ,
-2.7672031799005086, -2.873535557239684, -2.7841070554455807, -2.7622160899413877 ,
-2.766017938275496, -2.770937502873421, -2.777920735542645, -2.807945341050634 ,
-2.839605442012072, -2.901080246366208, -2.9678863343680693, -3.030555644081004 ,
-3.094779194272048, -3.1592757815567163 ,
])

ftheta_noise_30 = np.array([
-0.456865128016097, -0.9371135860333678, -1.6741696085215731, -1.790569494922504 ,
-1.7896558980342474, -1.757244941708474, -1.7123995942246477, -1.6724212465049955 ,
-1.6430970306508514, -1.6139768097068388, -1.593117150615664, -1.56524666538501 ,
-1.540315954597818, -1.4965701173506074, -1.4565541165630405, -1.4195822482668325 ,
-1.3853421167939892, -1.3536108866665446 ,
])
ftheta_ideal_40 = np.array([
-0.605034566968221, -1.229520191767138, -2.2579797396771766, -2.38625433115137 ,
-2.9515256965020624, -3.1685550856795652, -3.1677634595628734, -3.2606017910272485 ,
-3.341475583688872, -3.3967864915164294, -3.427982791012916, -3.4980192923344195 ,
-3.557312272378198, -3.6526348577480343, -3.7445732418753823, -3.821303445706697 ,
-3.899305193076052, -3.979659017163199 ,
])
ftheta_noise_40 = np.array([
-0.5962939560376574, -1.1634467591964404, -1.758335477045963, -1.756016663941303 ,
-1.7905714588638242, -1.761774697740648, -1.724803480565741, -1.6894738899333825 ,
-1.6613632297862346, -1.6323319592783148, -1.610998737258281, -1.5815561951096306 ,
-1.5549863862587099, -1.5083753211419124, -1.4658974884035834, -1.4270359126681562 ,
-1.3912866697007034, -1.3583723143652926 ,
])
ftheta_ideal_100 = np.array([
-0.49340468173154417, -0.9694391498271738, -2.142013465549031, -2.673241220100574 ,
-3.427649274366055, -3.8269219939923476, -4.227182757989097, -4.64269466646787 ,
-4.976647144552677, -5.26209889823497, -5.41431220781966, -5.595151699273812 ,
-5.701661733957301, -5.772870002823564, -5.7887761868115515, -5.790004282453417 ,
-5.783972692072418, -5.7302464479503294 ,
])

ftheta_noise_100 = np.array([
-0.48746921149438804, -0.9337734659482264, -1.7055520675612008, -1.7996318643153184 ,
-1.8064424791297415, -1.772435777434771, -1.737217427531704, -1.699334315983145 ,
-1.669242181674846, -1.638953713316035, -1.6169293493645265, -1.586316347771858 ,
-1.558919952792772, -1.5112390794295871, -1.4680131112495896, -1.4286643328971405 ,
-1.3925444519295398, -1.3593438009648098 ,
])
ftheta_ideal_200 = np.array([
-5.6283639431648025, -5.704117631690039, -5.741802808298386, -5.755173822933054 ,
-5.712671617423349 ,
])

ftheta_noise_200 = np.array([
-1.511236442681678, -1.468012746193586, -1.4286647144402096, -1.3925449585621394 ,
-1.3593442150062285 ,
])

ftheta_ideal_30_t9000 = np.array([
-0.46132809835332755, -0.9700120408898384, -2.0055474923510297, -2.4717400300681187 ,
-2.7668390290836093, -2.8730554289543084, -2.783709852261982, -2.761833449780701 ,
-2.7656288646799756, -2.7705409095587425, -2.777515029920555, -2.8075085448541413 ,
-2.839134106987179, -2.9005486932117406, -2.967247758226109, -3.0298205158767213 ,
-3.093948064102611, -3.15831079992048 ,
])

ftheta_noise_30_t9000 = np.array([
-0.4608121234553072, -0.9655789571871374, -1.9441086272405614, -2.2889600886653363 ,
-2.422760595730795, -2.4318675065246236, -2.3670744905915853, -2.32752084350137 ,
-2.304320464647864, -2.281185030315013, -2.2652256737790233, -2.248250811800367 ,
-2.232945729990991, -2.2043064318546435, -2.1765199479372095, -2.1482839179568223 ,
-2.120736366911444, -2.0939617908120773 ,
])

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.-', label=r'f_500')
plt.plot(f_theta['tg'], 10**ftheta_ideal_30, '.-', label=r'f_ideal_30')
plt.plot(f_theta['tg'], 10**ftheta_noise_30, '.--', label=r'f_noise_30')
plt.plot(f_theta['tg'], 10**ftheta_ideal_40, '.-', label=r'f_ideal_40')
plt.plot(f_theta['tg'], 10**ftheta_noise_40, '.--', label=r'f_noise_40')
# plt.plot(f_theta['tg'], 10**ftheta_ideal_30_t9000, '+', label=r'f_ideal_30_t9000')
# plt.plot(f_theta['tg'], 10**ftheta_noise_30_t9000, '.-', label=r'f_noise_30_t9000')
plt.plot(f_theta['tg'], 10**ftheta_ideal_100, '.--', label=r'f_ideal_100')
plt.plot(f_theta['tg'], 10**ftheta_noise_100, '.-', label=r'f_noise_100')
plt.yscale('log')
tg = 120
g = 0.75
# plt.axhline(y= g*tg/400, color='red', linestyle='--', label=r'$T_{\phi}^{0-7}=400$ ns')
plt.axhline(y= g*tg/2e3, color='blue', linestyle='--', label=r'$T_1^{0-7}=2\ \mu s$')
# plt.axhline(y= g*tg/9e3, color='black', linestyle='--', label=r'$T_1^{0-2}=9\ \mu s$')
# plt.axhline(y= g*tg/1600e3, color='black', linestyle='--', label=r'$T_1^{0-2}=1600\ \mu s$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'X-gate 1ncut $n_\theta \ (1-F=0.75t_g/T_2)$(tg=%d)'%tg)
plt.grid()
legend = plt.legend( loc="best",)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
tg_peter =  np.arange(20, 210, 10)
f_peter_200 = np.array([
-0.82707509, -0.8340652, -0.82227775, -0.8147383 ,
-1.07723559, -0.72991757 ,
-0.72061041, -0.70539987, -0.71889157, -0.5643321 ,
-0.60553461, -0.52135402, -0.47834509, -0.50532184 ,
-0.58888034, -0.6124411, -0.4746966, -0.44261567 ,
-0.52851414 ,
])
f_peter_300 = np.array([
-0.78881089, -0.78606029, -0.77908916, -0.62418737 ,
-0.70601525, -0.37711677 ,
-0.46987989, -0.45861733, -0.37741561, -0.29399604 ,
-0.41743811, -0.35668414, -0.41435171, -0.12503593 ,
-0.36574271, -0.34397562, -0.34445034, -0.14946846 ,
-0.3449492 ,
])
f_peter_30 = np.array([
-0.69505277, -0.98448866, -1.28667674, -1.45316385 ,
-1.80372807, -1.73424621 ,
-1.93807113, -1.81988892, -2.3845121, -2.15238949 ,
-1.68216635, -1.99352278, -2.37518297, -2.36602526 ,
-2.14386744, -1.9307199, -1.96209909, -2.11739249 ,
-1.78362674 ,
])

tg_30_v2 =  [20, 40, 60, 80, 100, 120, 140, 160]
f_peter_30_v2 = np.array([
-0.88672394, -1.005142, -1.55509345, -1.99109511 ,
-1.8641355, -1.88214733, -2.30104491, -2.49091768 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'$n_\theta$_Andras_500')
# plt.plot(f_theta['tg'], 10**f_300, '.-', label=r'$n_\theta$:unitary_fidelity')
# plt.plot(f_theta['tg'], leakage_300, '.-', label=r'$n_\theta$:leakage_300')
# plt.plot(tg_peter, 10**f_peter_200, '.-', label=r'$n_\theta$_Peter_200')
# plt.plot(tg_peter, 10**f_peter_300, '.-', label=r'$n_\theta$_Peter_300')
plt.plot(tg_peter, 10**f_peter_30, '.-', label=r'$n_\theta$_Peter_30')
plt.plot(tg_30_v2, 10**f_peter_30_v2, '.-', label=r'$n_\theta$_Peter_30_v2')

# plt.plot(f_phi['tg'], 10**f_phi_300_v2, '.-', label=r'$n_\phi$:unitary_fidelity')
# plt.plot(f_phi['tg'], leakage_phi_300_v2, '.-', label=r'$n_\phi$:leakage_300')
# plt.plot(f_phi['tg'], 10**f_phi['f_2000'], '.--', label=r'$n_\phi$_Andras')
plt.axhline(y= 1-0.985, color='b', linestyle='--', label=r'F=98.6% (Abdelhafez)')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.ylabel('Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
