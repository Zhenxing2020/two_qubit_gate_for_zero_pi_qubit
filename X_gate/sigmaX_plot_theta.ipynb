# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# f_cnot = pd.read_csv('data/data_cnot_45_2A.txt')
# f_n2_20 = pd.read_csv('../cz/data/data_fig/data_cz_n2_20.txt')
f_theta_29 = pd.read_csv('data/data_xgate_theta_truc1=50_truc2=29.txt')
f_theta = pd.read_csv('data/data_xgate_theta_truc1=80_truc2=44.txt')

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['fidelity_truc44'], '.--', label=r'$n_\theta$(truc2=44)')
plt.plot(f_theta['tg'], 10**f_theta['fidelity_truc157'], '.-', label=r'$n_\theta$(truc2=157)')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title('Use optimized pulse from 44-level model')
plt.ylabel('Error')

legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# plt.savefig('cnot_fidelity_2A0_and_1A0.png',dpi=300,bbox_inches='tight')

# %%
# para_tot = np.column_stack((tg_tc80_op2, f_theta_tc80_op2,  drive_param))
columns = ['tg',  'fidelity_truc44', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2']
# df = pd.DataFrame(np.round(para_tot, 6), columns=columns)
# df.to_csv('data/data_fig/data_xgate_theta_truc1=80_truc2=44.txt', sep=',', index=False, header=True)

# %%
tg =  [20, 30, 40]
f157 = np.array([-1.63312234,  -3.07440094, -2.30243717])
f157_drag1 = np.array([-1.89539926 ,-1.440853, -2.24521245, ])
f157_drag2 = np.array([-1.9236039, -1.45184588 ,-2.21076078])

f44 = np.array([-1.64362602, -2.87572646, -2.99076036,])
f44_drag1 = np.array([-1.98386453 ,-2.44018157, -3.01054291, ])
f44_drag2 = np.array([-2.02006001, -2.4951854 ,-2.52535088 ,])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(tg, 10**f44, '.-', label=r'Pulse A: truc=44')
plt.plot(tg, 10**f44_drag1, '.-', label=r'Pulse B: truc=44, 1 drag')
plt.plot(tg, 10**f44_drag2, '.-', label=r'Pulse C: truc=44, 2 drag')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ : pulses are optimized from 44-level model')
plt.ylabel('Error')

legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# plt.savefig('cnot_fidelity_2A0_and_1A0.png',dpi=300,bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(tg, 10**f157, '.-', label=r'Pulse A: truc=157')
plt.plot(tg, 10**f157_drag1, '.-', label=r'Pulse B: truc=157, 1 drag')
plt.plot(tg, 10**f157_drag2, '.-', label=r'Pulse C: truc=157, 2 drag')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ : pulses are optimized from 44-level model')
plt.ylabel('Error')

legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# plt.savefig('cnot_fidelity_2A0_and_1A0.png',dpi=300,bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6,3))
# plt.plot(f_cnot['tg'], 10**f_cnot['fidelity_qt'], '-', label='CNOT')   #r'$1-F_{qt}$')
# plt.plot(f_n2_20['tg'], 10**f_n2_20['fidelity_qt'], '-',  label=r'CZ')
# plt.plot(tg_ptheta, 10**f_ptheta_t40, '.-', label=r'$n_\phi + n_\theta$')   #r'$1-F_{qt}$')
plt.plot(f_theta_29['tg'], 10**f_theta_29['fidelity_truc29'], '.-', label=r'$n_\theta$(truc2=29)')
# plt.plot(f_xgate_theta['tg'], 10**f_xgate_theta['fidelity_truc100'], '.-', label=r'$n_\theta$(truc2=100)')
# plt.plot(f_xgate_theta['tg'], 10**f_theta_tc200, '.-', label=r'$n_\theta$(truc2=200)')
# plt.plot(f_xgate_theta['tg'], 10**f_theta_tc300, '.-', label=r'$n_\theta$(truc2=300)')
# plt.plot(f_xgate_theta['tg'], 10**f_theta_tc256, '.-', label=r'$n_\theta$(truc2=256)')
plt.plot(f_theta_29['tg'], 10**f_theta_tc80, '.-', label=r'$n_\theta$(truc2=44)')
plt.plot(f_theta_29['tg'], 10**f_theta_tc157, '.-', label=r'$n_\theta$(truc2=157)')
# plt.plot(f_xgate_theta['tg'], 10**f_theta_tc44, '.-', label=r'$n_\theta$(truc2=44)-op1')
# plt.plot(tg_op2_v2, 10**f_op2_v2, '*', label=r'$n_\theta$(truc2=44)-op2-v2')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title('Use optimized pulse from 29-level model')
plt.ylabel('Error')

legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# plt.savefig('cnot_fidelity_2A0_and_1A0.png',dpi=300,bbox_inches='tight')

# %%
=
# Out:
#   Cell In[12], line 1
#     =
#     ^
# SyntaxError: invalid syntax
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
f_157_real = 1-10**f_theta_tc157
f_300_real = 1-10**f_theta_tc300
fig, ax = plt.subplots(figsize=(6,1.5))
plt.plot(f_theta_29['tg'], np.abs(10**f_theta_tc300 - 10**f_theta_tc256), '.-', label=r'$n_\theta$(truc2=300)')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)', fontsize=15)
plt.title(r'$|F_{256}-F_{300}|$', fontsize=15)
# Out:
# Text(0.5, 1.0, '$|F_{256}-F_{300}|$')

# %%
fig, ax = plt.subplots(figsize=(3,2))
plt.plot(f_theta_29['tg'], f_theta_29['drive_amp_1'])
plt.plot(f_theta_29['tg'], f_theta_29['drive_amp_2'])

# %%
fig, ax = plt.subplots(figsize=(3,2))
plt.plot(f_theta_29['tg'], f_theta_29['detune_1'])
plt.plot(f_theta_29['tg'], f_theta_29['detune_2'])

# %%
# para_tot = np.column_stack((tg_theta, f_theta_tc29, f_theta_tc100, param_theta))
columns = ['tg',  'fidelity_truc29',  'fidelity_truc100', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2']
# df = pd.DataFrame(np.round(para_tot, 6), columns=columns)
# df.to_csv('data/data_fig/data_xgate_theta_truc1=50_truc2=29.txt', sep=',', index=False, header=True)

# %%
tg =  [ 60.]
fidelity =  -4.021999100148462 ,
drive_param = [0.15042571732968524, 0.04685021908945983, 0.03748943485669252, 0.04001032187908264] ,

# %%
tg22_theta =  [22, 26, 30, 34, 38, 42, 46, 50, 54, 58, 62]
f_theta_tg22 = np.array([
-1.30950086, -1.55062715, -2.40916616, -1.76403097 ,
-2.71730657, -1.96823662, -1.69933207, -3.25555349 ,
-2.24294886, -2.87041967, -2.64766894 ,
])
param_theta_tg22 = np.array([
[0.211429, 0.049914, 0.002936, -0.00243] ,
[0.297359, 0.096245, -0.000198, 0.01725] ,
[0.298429, 0.048571, -0.03174, -0.029243] ,
[0.289968, 0.03821, -0.016758, -0.025908] ,
[0.225004, 0.050753, -0.027189, -0.019438] ,
[0.217053, 0.038772, -0.015846, -0.01794] ,
[0.228266, 0.052582, 0.045605, 0.056706] ,
[0.173029, 0.063655, 0.035993, 0.038554] ,
[0.27803, 0.064647, 0.070758, 0.084421] ,
[0.192693, 0.055201, 0.0521, 0.058062] ,
[0.129987, 0.050651, 0.032396, 0.031764] ,
])

tg22_ptheta =  [22, 26, 30, 34, 38, 42, 46, 50]
f_ptheta_tg22 = np.array([
-0.54422357, -0.69582564, -0.85297571, -0.98005608 ,
-1.29176593, -1.59208706, -1.47383638, -1.62599608 ,
])
param_ptheta_tg22 = np.array([
[0.272307, 0.123559, 0.015294, 0.099825] ,
[0.272055, 0.104176, 0.003277, 0.09836] ,
[0.26935, 0.094517, -0.002913, 0.09982] ,
[0.243057, 0.196046, -0.02903, 0.020586] ,
[0.242207, 0.170454, -0.041518, 0.018967] ,
[0.21556, 0.142528, -0.063299, -0.017881] ,
[0.194459, 0.125459, -0.072863, -0.039786] ,
[0.235563, 0.245892, -0.019091, 0.023434] ,
])
# plt.plot(tg22_theta, 10**f_theta_tg22, '.-', label=r'$n_\theta$')
# plt.plot(tg22_ptheta, 10**f_ptheta_tg22, '.-', label=r'$n_\theta$')

# %%
f_theta_tc200 = np.array([
-1.23870449, -0.74442157, -1.64947923, -1.05493429 ,
-1.12202402, -1.49595205, -0.71254455, -1.73417998 ,
-1.2370485, -1.65236848, -1.26866909, -0.99865627 ,
-2.51034263, -2.08340066, -2.2625505, -2.6349872 ,
    ])

f_theta_tc300 = np.array([
-1.23989336, -0.78639359, -1.64991257, -1.05186432 ,
-1.11646275, -1.50033237, -0.7419526, -1.73854773 ,
-1.23864252, -1.64903779, -1.26538011, -1.00539667 ,
-2.51564257, -2.05770363, -2.25266992, -2.63150129 ,
    ])

f_theta_tc256 = np.array([
-1.24063012, -0.79042744, -1.6513146, -1.05287572 ,
-1.11562688, -1.49802633, -0.73586673, -1.74262958 ,
-1.24706985, -1.65391428, -1.27042834, -1.00781399 ,
-2.52275147, -2.05238106, -2.25611194, -2.63881815 ,
    ])

f_theta_tc157 = np.array([
-1.24018842, -0.78708657, -1.65028722, -1.05236415 ,
-1.11654723, -1.49972594, -0.74274381, -1.73976517 ,
-1.23965418, -1.64965293, -1.2660852, -1.00651745 ,
-2.51695527, -2.05666833, -2.25417265, -2.63409131 ,
])

f_theta_tc80 = np.array([
-1.12270357, -0.86223197, -1.60956982, -1.4995354 ,
-1.13984798, -1.58257405, -1.55012786, -2.21822955 ,
-2.23773864, -2.33192875, -2.2245648, -0.40449405 ,
-2.43427417, -1.79428188, -1.71810714, -2.08931725 ,
    ])

f_theta_tc44 = np.array([
-1.12256384, -0.86214656, -1.6096018, -1.49975659 ,
-1.14003902, -1.58291632, -1.54977782, -2.21804923 ,
-2.23751173, -2.33163238, -2.22442756, -0.40445137 ,
-2.43445926, -1.79426162, -1.71812384, -2.08955578 ,
])
