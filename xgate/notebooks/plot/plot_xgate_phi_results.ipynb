# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# f_theta_1ncut = pd.read_csv('data/other/data_xgate_theta_1ncut.txt')
# f_phi_1ncut = pd.read_csv('data/other/data_xgate_phi_1ncut.txt')
# f_theta = pd.read_csv('data/data_xgate_theta_3ncut.txt')
f_phi = pd.read_csv('../../../figure/data/data_xgate_phi_3ncut_mstep_1e3.txt')
pd.set_option('display.precision', 8)
# params = f_phi[['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2'
#                     ]].to_numpy() #[1::4, :]
# params

# %%
params = np.array([
[20.000087, 0.249753, 0.216297, 0.43883, 0.490612] ,
[60.000967, 0.213711, 0.14419, 0.358967, 0.378127] ,
[100.001683, 0.212233, 0.113924, 0.340021, 0.36258] ,
[140.008725, 0.211735, 0.099358, 0.338134, 0.362321] ,
[180.006237, 0.21108, 0.084566, 0.335734, 0.36059] ,
])
f_ideal_160 = np.array([
-0.60538298, -1.48640358, -1.84305643, -2.27633037 ,
-2.63563254 ,])
f_170us_160 = np.array([
-0.60412001, -1.45945568, -1.75542410, -2.02407105 ,
-2.13268082 ,])
f_30us_160 = np.array([
-0.59847121, -1.35449575, -1.49298374, -1.54709582 ,
-1.51957589 ,])
f_3us_160 = np.array([
-0.54428182, -0.86362862, -0.77599905, -0.70573687 ,
-0.64643358 ,])

# %%
fig, ax = plt.subplots(figsize=(5,3))

plt.plot(f_phi['tg'], 10**f_phi['f_160_charge'], '.-', label=r'f_ideal_160_old')
plt.plot(f_phi['tg'], 10**f_phi['f_160_170us'], '.-', label=r'170us_old')
plt.plot(f_phi['tg'], 10**f_phi['f_160_30us'], '.-', label=r'30us_old')
plt.plot(f_phi['tg'], 10**f_phi['f_160_3us'], '.-', label=r'3us_old')

plt.plot(params[:,0], 10**f_ideal_160, '.-', label=r'f_ideal_160')
plt.plot(params[:,0], 10**f_170us_160, '.-', label=r'170us')
plt.plot(params[:,0], 10**f_30us_160, '.-', label=r'30us')
plt.plot(params[:,0], 10**f_3us_160, '.-', label=r'3us')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, 1st vs 2nd derivative ', fontsize=12)
plt.grid()
legend = plt.legend( loc="best", fontsize=8)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f_ideal_160 = np.array([
-0.60543872, -0.75216502, -0.88531733, -1.12280287 ,
-1.48691618, -1.63816143, -1.69969521, -1.74075134 ,
-1.84497786, -1.90482151, -2.07223404, -2.19235225 ,
-2.27990349, -2.45649266, -2.53430458, -2.45509559 ,
-2.64076878, -2.62086952, -2.67313777 ,
])
f_170us_160 = np.array([
-0.60749255, -0.75613411, -0.88645740, -1.11395821 ,
-1.46088038, -1.60455364, -1.65783388, -1.67831710 ,
-1.76877662, -1.81850397, -1.92319924, -2.01305812 ,
-2.04794425, -2.12946590, -2.14301370, -2.09567201 ,
-2.15015545, -2.13545840, -2.13351896 ,
])
f_30us_160 = np.array([
-0.60151605, -0.74368615, -0.86662104, -1.07373106 ,
-1.35555309, -1.45345053, -1.47510379, -1.46032340 ,
-1.49966325, -1.51892186, -1.55312602, -1.58530682 ,
-1.55399351, -1.57736909, -1.55701932, -1.52368372 ,
-1.52401308, -1.50862169, -1.49496928 ,
])
f_3us_160 = np.array([
-0.54516065, -0.63706800, -0.70780226, -0.80014077 ,
-0.86412961, -0.86886721, -0.84413926, -0.79048389 ,
-0.77648656, -0.76996536, -0.75611595, -0.75786980 ,
-0.70626038, -0.70879065, -0.68340895, -0.65850921 ,
-0.64755698, -0.63455503, -0.62273186 ,
])
f_ideal_1000 = np.array([
-0.60575133, -0.76485051, -0.88467931, -1.13351455 ,
-1.48595991, -1.64029432, -1.66464015, -1.67163776 ,
-1.86396264, -1.86461959, -2.06315702, -2.21340621 ,
-2.27732384, -2.47968218, -2.51228746, -2.47339256 ,
-2.68291732, -2.62150207, -2.72060903 ,
])
f_ideal_300 = np.array([
-0.60545279, -0.75222012, -0.88545502, -1.12292432 ,
-1.48711468, -1.63853079, -1.70014114, -1.74102984 ,
-1.84546615, -1.90547607, -2.07260829, -2.19306368 ,
-2.28078839, -2.45693167, -2.53441622, -2.45550991 ,
-2.64058543, -2.62096434, -2.67302278 ,
])
f_160_low = np.array([
-0.50134842, -0.54042689, -0.94823787, -1.11969148 ,
-1.43905286, -1.46915291, -1.45899478, -1.46053613 ,
-2.06915746, -2.02978394, -2.10414748, -2.09474017 ,
-2.19618615, -2.38312625, -2.38605954, -2.45812263 ,
-2.54681441, -2.72399838, -2.70049819 ,
])

# %%
phi = np.column_stack((params, f_ideal_1000, f_ideal_300, f_160_low, f_ideal_160, f_170us_160, f_30us_160, f_3us_160))
df = pd.DataFrame(phi, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2', 
                                'f_1000', 'f_300', 'f_160', 'f_160_charge',  'f_160_170us', 'f_160_30us', 'f_160_3us'])
# df.to_csv('data/fidelity_xgate_phi_3ncut_mstep_1e3.txt', sep=',', index=False, header=True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
# plt.plot(params[:,0], 10**f_ideal_1000, '.-', label=r'f_ideal_1000')
plt.plot(params[:,0], 10**f_ideal_300, '.-', label=r'f_ideal_300')
# plt.plot(params[:,0], 10**f_ideal_160, '.-', label=r'f_ideal_160')
plt.plot(params[:,0], 10**f_160_low, '.-', label=r'f_160_low')
# plt.plot(params[:,0], 10**f_170us_160, '.-', label=r'170us')
# plt.plot(params[:,0], 10**f_30us_160, '.-', label=r'30us')
# plt.plot(params[:,0], 10**f_3us_160, '.-', label=r'3us')
plt.plot(params[:,0], np.abs(10**f_ideal_300 - 10**f_160_low) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, 170μs, max_step=1e-3 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Noisy infidelity convergence vs truncation
#
# max_step=3e-4

# %%
f_170us_263_3e4 = np.array([
-0.7624036814481177, -1.5968180570675208, -1.7655839913105131, -2.1168451082516433 ,
-2.109317689896817 ,
])
f_170us_160_3e4 = np.array([
-0.7493116567600718, -1.5962827421699788, -1.7997265127403734, -2.1116666448801222 ,
-2.1152283327502297 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_170us_263_3e4, '.-', label=r'truncation=263 (19hours)')
plt.plot(params[:,0], 10**f_170us_160_3e4, '.-', label=r'truncation=160 (5.6hours)')
plt.plot(params[:,0], np.abs(10**f_170us_263_3e4 - 10**f_170us_160_3e4) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, 170μs, max_step=3e-4 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Noisy infidelity convergence vs max_step
#
# truc=160

# %%
f_170us_160_1e3 = np.array([
-0.7561341112845914, -1.6045536416984727, -1.8185039737631303, -2.129465897725423 ,
-2.1354583983573017 ,
])

f_170us_160_1e4 = np.array([
-0.749329989148388, -1.5965175013688764, -1.8000992234870927, -2.1124727594249118 ,
-2.1160454292072277 ,
])
f_170us_160_3e5 = np.array([
-0.7493324785717822, -1.5965404945665096, -1.8001365165248424, -2.1125501615420945 ,
-2.1161234528625985 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_170us_160_3e5, '.-', label=r'max_step=3e-5 (30.3hours)')
# plt.plot(params[:,0], 10**f_170us_160_1e4, '.-', label=r'max_step=1e-4 (15.8hours)')
plt.plot(params[:,0], 10**f_170us_160_3e4, '.-', label=r'max_step=3e-4 (5.6hours)')
# plt.plot(params[:,0], 10**f_170us_160_1e3, '.-', label=r'max_step=1e-3 (4.9hours)')
plt.plot(params[:,0], np.abs(10**f_170us_160_3e5 - 10**f_170us_160_3e4) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, 170μs, n=160 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### different $T_1$

# %%
f_3us_160 = np.array([
-0.63572818753264, -0.8680517446798515, -0.7691338322219238, -0.707890640771755 ,
-0.6333866458797204 ,
])
f_30us_160 = np.array([
-0.7377765455516953, -1.448187435413988, -1.5103377630075214, -1.5724310239469315 ,
-1.503468366816635 ,
])
f_170us_160 = np.array([
-0.749329989148388, -1.5965175013688764, -1.8000992234870927, -2.1124727594249118 ,
-2.1160454292072277 ,
])
f_ideal_160 = np.array([
-0.7518855625257463, -1.6368123617633128, -1.901045607932464, -2.450986743064976 ,
-2.6148066517320228 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(f_phi['tg'], 10**f_phi['f_truc140_ideal'], '.--', label=r'ideal_old')
plt.plot(f_phi['tg'], 10**f_phi['f_truc140_170us'], '.--', label=r'170μs_old')
# plt.plot(f_phi['tg'], 10**f_phi['f_truc140_30us'], '.--', label=r'30μs_old')
# plt.plot(f_phi['tg'], 10**f_phi['f_truc140_3us'], '.--', label=r'3μs_old')

plt.plot(params[:,0], 10**f_ideal_160, 'v-', label=r'ideal')
plt.plot(params[:,0], 10**f_170us_160, 'v-', label=r'170μs')
# plt.plot(params[:,0], 10**f_30us_160, 'v-', label=r'30μs')
# plt.plot(params[:,0], 10**f_3us_160, 'v-', label=r'3μs')
plt.title(r'X gate $n_\phi$')
plt.yscale('log')
# plt.ylim(1e-6, 4e-1)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal infidelity convergence vs max_step
#
# truncation=160, no charge pick

# %%
f_ideal_160_0 = np.array([
-0.7521624851391504, -1.63813837764658, -1.9048422420549604, -2.456256060198235 ,
-2.62047830820094 ,
])
f_ideal_160_1e3 = np.array([
-0.7521650189446701, -1.6381614266857487, -1.904821511607261, -2.4564926627300454 ,
-2.6208695244170817 ,
])
f_ideal_160_3e4 = np.array([
-0.7519428853509471, -1.6369183964881266, -1.9012976822128833, -2.4512314311142207 ,
-2.61494377106448 ,
])
f_ideal_160_1e4 = np.array([
-0.7518855625257463, -1.6368123617633128, -1.901045607932464, -2.450986743064976 ,
-2.6148066517320228 ,
])
f_ideal_160_3e5 = np.array([
-0.7518847321265352, -1.6367519895304001, -1.9009829031072059, -2.450926716497322 ,
-2.6148052880043413 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_160_3e5, '.-', label=r'max_step=3e-5')
# plt.plot(params[:,0], 10**f_ideal_160_1e4, '.-', label=r'max_step=1e-4')
# plt.plot(params[:,0], np.abs(10**f_ideal_160_3e5 - 10**f_ideal_160_1e4) , 'x--', label=r'difference')

plt.plot(params[:,0], 10**f_ideal_160_3e4, '.-', label=r'max_step=3e-4')
plt.plot(params[:,0], np.abs(10**f_ideal_160_3e5 - 10**f_ideal_160_3e4) , 'x--', label=r'difference')

# plt.plot(params[:,0], 10**f_ideal_160_1e3, '.-', label=r'max_step=1e-3')
# plt.plot(params[:,0], np.abs(10**f_ideal_160_3e5 - 10**f_ideal_160_1e3) , 'x--', label=r'difference')

# plt.plot(params[:,0], 10**f_ideal_160_0, '.-', label=r'max_step=0')
# plt.plot(params[:,0], np.abs(10**f_ideal_160_3e5 - 10**f_ideal_160_0) , 'x--', label=r'difference')
# plt.plot(params[:,0], np.abs(10**f_ideal_160_1e3 - 10**f_ideal_160_0) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, Ideal, n=160 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal infidelity convergence vs truncation

# %%
f_ideal_1000_0 = np.array([
-0.7648379325845441, -1.6401457260108692, -1.8645474247675335, -2.4801946955862673 ,
-2.6158944943505307 ,
])
f_ideal_1000_1e3 = np.array([
-0.7648364390459246, -1.640104587021142, -1.8643492284280045, -2.480313842582376 ,
-2.615492052212633 ,
])
f_ideal_1000_3e4 = np.array([
-0.7646969777323853, -1.637556160541769, -1.8552012815271135, -2.4672970859767984 ,
-2.591617884570783 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_1000_3e4, '.-', label=r'truncation=1000 (29mins)')
plt.plot(params[:,0], 10**f_ideal_160_3e4, '.-', label=r'truncation=160 (32s)')
plt.plot(params[:,0], np.abs(10**f_ideal_1000_3e4 - 10**f_ideal_160_3e4) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, Ideal, max_step=3e-4', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_1000_0, '.-', label=r'truncation=1000 (36mins)')
plt.plot(params[:,0], 10**f_ideal_160_0, '.-', label=r'truncation=160 (26s)')
plt.plot(params[:,0], np.abs(10**f_ideal_1000_0 - 10**f_ideal_160_0) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, Ideal, max_step=0', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_1000_1e3, '.-', label=r'truncation=1000 (27mins)')
plt.plot(params[:,0], 10**f_ideal_160_1e3, '.-', label=r'truncation=160 (23s)')
plt.plot(params[:,0], np.abs(10**f_ideal_1000_1e3 - 10**f_ideal_160_1e3) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\phi$, Ideal, max_step=1e-3', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal infidelity convergence vs truncation
#
# max_step=1e-4, no charge pick

# %%
f_ideal_1000 = np.array([
-0.6056862674371347, -0.7646673654043741, -0.8842766955929773, -1.13247415816179 ,
-1.4828390724127547, -1.6376554094763092, -1.6615989704389011, -1.6656221104954776 ,
-1.8580396562994281, -1.8572105064005684, -2.0559678578180725, -2.2064696805060944 ,
plt.plot(f_phi['tg'][:-1], 10**f_ideal_1000, 'v-', label=r'truncation=1000 (48mins)')
plt.plot(f_phi['tg'][:-1], 10**f_ideal_160, 'v-', label=r'truncation=160 (2.5mins)')
plt.plot(f_phi['tg'][:-1], np.abs(10**f_ideal_1000 - 10**f_ideal_160), 'v-', label=r'difference')
plt.title(r'X gate $n_\phi$ Ideal, mstep=1e-4')
plt.yscale('log')
plt.ylim(1e-6, 4e-1)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(f_phi['tg'][:-1], 10**f_ideal_300, 'v-', label=r'300')
plt.plot(f_phi['tg'][:-1], 10**f_ideal_160, 'v-', label=r'160')
plt.plot(f_phi['tg'][:-1], np.abs(10**f_ideal_300 - 10**f_ideal_160), 'v-', label=r'difference')
plt.title(r'X gate $n_\phi$ Ideal, mstep=1e-4')
plt.yscale('log')
plt.ylim(1e-6, 4e-1)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal and noisy infidelity convergence vs truncation
#
# Ideal: max_step=0, Noisy: max_step=1e-3

# %%
f_phi_900 = np.array([
-0.6057350024781458, -0.7648276228093328, -0.8846267662320726, -1.1332102858857998 ,
-1.48500777556615, -1.63975762467941, -1.663930922111512, -1.6691277480211126 ,
-1.8613835222628825, -1.8621794217362104, -2.0608090103069636, -2.2116773660231184 ,
-2.274738999199776, -2.480019449328496, -2.5096130890290964, -2.466122180568392 ,
-2.6640884652178394, -2.6154470379343633, -2.7053015581095567 ,
])
f_phi_800 = np.array([
-0.6057494035385135, -0.764837361578364, -0.8846236988014182, -1.132885782036475 ,
-1.483975394518838, -1.6392077774195024, -1.6633977459200362, -1.6693164231519653 ,
-1.8611061501612853, -1.861734774349343, -2.05987930825754, -2.210606079253962 ,
-2.2737845006503736, -2.4747795302654643, -2.5059922529461556, -2.4635684952036314 ,
-2.6581362934574138, -2.6118839157769975, -2.6885026447068325 ,
])
f_phi_700 = np.array([
-0.6057205474327392, -0.7648432335519422, -0.884579731825432, -1.1328627262828503 ,
-1.4839734259279993, -1.6390645979152108, -1.6630946371406654, -1.6688553634475949 ,
-1.8608098554741503, -1.8614323860724524, -2.0596301454997143, -2.210316516923214 ,
-2.2722296076450803, -2.473804580552255, -2.504433956232904, -2.4607715499642238 ,
-2.6534133984686776, -2.6045833104039566, -2.677586254422506 ,
])
f_phi_600 = np.array([
-0.6056898005604863, -0.7648315574392204, -0.8846508640209452, -1.1329727027485463 ,
-1.4838539196794773, -1.6395203142164287, -1.6630619443882544, -1.6701334175372953 ,
-1.8601970534263084, -1.8621998270335371, -2.0594608555425356, -2.2088307737855915 ,
-2.2725403821681427, -2.4714625306381417, -2.5018111536378322, -2.459361426949576 ,
-2.6516266283082244, -2.598773682361837, -2.6705418834279775 ,
])
n_truc_large = [ 300, 400, 500, 600, 700, 800, 900, 1000]

f_ideal_large = np.column_stack((
    f_phi['f_300'].to_numpy(), 
    f_phi['f_400'].to_numpy(), 
    f_phi['f_500'].to_numpy(), 
    f_phi_600, f_phi_700, f_phi_800, f_phi_900, 
    f_phi['f_1000'].to_numpy(), 
    ))[[1, 5, 9, 13, 17 ], ]

# np.shape(f_ideal_large)

# %%
f_ideal_212 = np.array([
-0.7667048889003052, -1.6397282426293298, -1.8658981566721915, -2.4709675175443633 ,
-2.6109621752568155 ,
])
f_170us_212 = np.array([
-0.7678344649276907, -1.6116663072747437, -1.7866321240258745, -2.1688396559940966 ,
-2.154154641140731 ,
])
f_ideal_186 = np.array([
-0.77280195982027, -1.6349026348293614, -1.891781336086083, -2.5011223533309797 ,
-2.6483547933781377 ,
])
f_170us_186 = np.array([
-0.7774606752402542, -1.6036779339769343, -1.8078806682470172, -2.144725246391958 ,
-2.142945483913333 ,
])
f_ideal_160 = np.array([
-0.7521624851391499, -1.6381383776465843, -1.904842242054972, -2.456256060198235 ,
-2.62047830820094 ,
])
f_170us_160 = np.array([
-0.756134111284227, -1.6045536416984125, -1.8185039732520467, -2.129465901288052 ,
-2.135458403068922 ,
])
f_ideal_140 = np.array([
-0.7710296520870427, -1.6405575650317505, -1.9055133720239679, -2.53889878626774 ,
-2.6693074486470056 ,
])

f_170us_140 = np.array([
-0.773741548109618, -1.6053079869237696, -1.824819017592418, -2.2030609121580533 ,
-2.1961722745738808 ,
])

f_ideal_133 = np.array([
-0.7350263809611381, -1.4753346102832534, -1.828088676099656, -2.2004045597387285 ,
-2.1333049430006183 ,
])
f_170us_133 = np.array([
-0.7369063213848535, -1.4520336385727264, -1.7570995116663195, -1.9936058808466697 ,
-1.957205958919378 ,
])
f_ideal_107 = np.array([
-0.7995633573405894, -1.584689250493364, -1.8536249827448972, -2.25500564705734 ,
-2.710810780452977 ,
])
f_170us_107 = np.array([
-0.7969443796906768, -1.5441368699450853, -1.7619227550378214, -2.0169805046286133 ,
-2.2004257872862514 ,
])
f_ideal_81 = np.array([
-0.5826672957314747, -1.5469685633596464, -2.0189462335316866, -2.364997829961752 ,
-2.638442470090593 ,
])
f_170us_81 = np.array([
-0.580332020432013, -1.5113699506461749, -1.9046726418466053, -2.1033477485733787 ,
-2.136011294035378 ,
])
f_ideal_54 = np.array([
-0.639388835329316, -1.9163194205983503, -2.3581089076881696, -2.294923285594063 ,
-2.096628768489704 ,
])
f_170us_54 = np.array([
-0.6379738572468178, -1.8445857837310782, -2.119392757812456, -2.0395900094631227 ,
-1.881248657619048 ,
])

n_truc = [54, 81, 107, 133, 140, 160, 186, 212]
f_170us = np.column_stack((f_170us_54, f_170us_81, f_170us_107, f_170us_133, 
                           f_170us_140, f_170us_160, f_170us_186, f_170us_212, ))
f_ideal = np.column_stack((f_ideal_54, f_ideal_81, f_ideal_107, f_ideal_133, 
                           f_ideal_140, f_ideal_160, f_ideal_186, f_ideal_212, ))

# %%
fig, axes = plt.subplots(5, 1, figsize=(4, 8), sharex=True)
for i in range(5):
    ax = axes[i]
    ax.plot(n_truc, 10**f_ideal[i], '.-', label=fr'$t_g = {params[:,0][i]:.0f}$ns')  # Change label if needed
    ax.plot(n_truc_large, 10**f_ideal_large[i], '.-')  # Change label if needed
    # ax.set_yscale('log')
    ax.grid()
    legend = ax.legend(loc="best")
    legend.get_frame().set_alpha(0.2)
axes[4].set_xlabel('truncation')
axes[0].set_title(fr'Infidelity: $n_\phi$, ideal, max_step=0')
plt.tight_layout()

# %%
fig, axes = plt.subplots(5, 1, figsize=(4, 8), sharex=True)
for i in range(5):
    ax = axes[i]
    ax.plot(n_truc, 10**f_170us[i], '.-', label=fr'$t_g = {params[:,0][i]:.0f}$ns')  # Change label if needed
    ax.grid()
    legend = ax.legend(loc="best")
    legend.get_frame().set_alpha(0.2)
axes[4].set_xlabel('truncation')
axes[0].set_title(fr'Infidelity: $n_\phi$, 170μs, max_step=1e-3')
plt.tight_layout()

# %% [markdown]
# ### Ideal infidelity convergence vs max_steps
#
# truncation = 500, no charge pick

# %%
f_1e5 = np.array([
-0.7649739166946895, -1.6365538743817463, -1.8562108854805197, -2.4584726419049914 ,
-2.5903291583934602 ,
])
f_1e4 = np.array([
-0.7649767275556868, -1.6366226130216486, -1.8562941364405006, -2.458512537036306 ,
-2.5903897289140443 ,
])
f_3e4 = np.array([
-0.7648353239306913, -1.636064610944624, -1.8555942117466064, -2.459479980721102 ,
-2.589923851577087 ,
])
f_1e3 = np.array([
-0.7652402302007555, -1.6380518241609643, -1.8606637522491318, -2.466745658086577 ,
-2.5980266361859856 ,
])
f_0 = np.array([
-0.7652353220243557, -1.638036999983225, -1.8606622054132254, -2.4663776908405963 ,
-2.5979431318372654 ,
])

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.plot(params[:,0], 10**f_1e5, 'v-', label=r'max_step=1e-5 (90 minutes)')
plt.plot(params[:,0], 10**f_1e4, 'x-', label=r'max_step=1e-4 (8 minutes)')
plt.plot(params[:,0], 10**f_3e4, '+-', label=r'max_step=3e-4 (3 minutes)')
plt.plot(params[:,0], 10**f_1e3, 'x--', label=r'max_step=1e-3 (2.3 minute)')
plt.plot(params[:,0], 10**f_0, '.--', label=r'max_step=0 (1.5 minute)')

plt.title(r'X gate $n_\phi$ Ideal, trucation=500')
plt.yscale('log')
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Gate Error')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
#
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
#
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
#
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# pa = np.column_stack((f_phi.to_numpy(), np.round(f_500, 8), np.round(f_400, 8),  np.round(f_300, 8), np.round(f_157, 8), np.round(f_157_low, 8)))
# df = pd.DataFrame(pa, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2', 'f_160',
#                                'f_500', 'f_noise_9_2us', 'f_noise_100_5us', 'f_noise_100_50us', 'f_ideal_160',
#                                'f_1000', 'f_truc140_ideal', 'f_truc140_170us', 'f_truc140_30us', 'f_truc140_3us',
#                                'f_500', 'f_400', 'f_300','f_160', 'f_160_low'
#                                ])
# df.to_csv('data/data_xgate_phi_3ncut.txt', sep=',', index=False, header=True)

# pa = np.column_stack((f_theta.to_numpy(), np.round(f_1000, 8), np.round(f_500, 8), np.round(f_400, 8),  np.round(f_300, 8), np.round(f_157, 8), np.round(f_157_low, 8)))
# df = pd.DataFrame(pa, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2', 'f_157',
#                                'f_500', 'f_noise_9_2us', 'f_noise_100_5us', 'f_noise_100_50us', 
#                                'f_78', 'f_noise_170us', 'f_noise_30us', 'f_noise_3us',
#                                'f_1000','f_500', 'f_400', 'f_300','f_157', 'f_157_low'
#                                ])
# df.to_csv('data/data_xgate_theta_3ncut.txt', sep=',', index=False, header=True)

# %% [markdown]
# ## Print mean amplitude/ detune

# %%
A = [np.mean(f_theta[['drive_amp_1']]), np.mean(f_theta[['drive_amp_2']])]
detune = [np.mean(f_theta[['detune_1']]), np.mean(f_theta[['detune_2']])]
print(f' Theta gate:')
print(f'Amplitude: A0={A[0]:.6f}, A1={A[1]:.6f}')
print(f'detune_0={detune[0]:.6f}, detune_1={detune[1]:.6f}')

A = [np.mean(f_phi[['drive_amp_1']]), np.mean(f_phi[['drive_amp_2']])]
detune = [np.mean(f_phi[['detune_1']]), np.mean(f_phi[['detune_2']])]
print(f'\nPhi gate:')
print(f'Amplitude: A0={A[0]:.6f}, A1={A[1]:.6f}')
print(f'detune_0={detune[0]:.6f}, detune_1={detune[1]:.6f}')
# Out:
#  Theta gate:
# Amplitude: A0=0.119467, A1=0.028685
# detune_0=-0.006975, detune_1=-0.002039
#
# Phi gate:
# Amplitude: A0=0.214044, A1=0.120290
# detune_0=0.351830, detune_1=0.375322

# %% [markdown]
# ## Other

# %%
f_charge140_170us_v2 = np.array([
-0.603384124030712, -0.9003022322840204, -1.4630289009915025, -1.6569012495088442 ,
-1.8869198520317652, -2.0400081532373058, -2.2497001628206768, -2.512534408255835 ,
-2.505895126775401, -2.6213241163924197 ,
])
f_charge140_30us_v2 = np.array([
-0.6023835948636584, -0.8961866890012773, -1.4372339959804545, -1.6041503976614544 ,
-1.787068214544117, -1.8788895866091895, -1.9879654264077375, -2.0738735911352877 ,
-2.0442747958567145, -2.030625726965328 ,
])
f_charge140_3us_v2 = np.array([
-0.5917115328455644, -0.8544228593648189, -1.2296830011196724, -1.2611639909773373 ,
-1.2887387773541759, -1.2547229760539487, -1.229649123660188, -1.1961381114517318 ,
-1.155311708583152, -1.117491462170848 ,
])
v2_ideal = np.array([
-0.6009112143429436, -0.8953468063786553, -1.46633629292876, -1.6632854175496878 ,
-1.8939398906481715, -2.100645638428869, -2.2880623312778505, -2.5841711750029046 ,
-2.6794524498984034, -2.7365165224563937 ,
])
v2 = np.array([
[20.000087, 0.249753, 0.216297, 0.43883, 0.490612] ,
[40.006173, 0.223179, 0.160035, 0.358809, 0.386917] ,
[60.000967, 0.213711, 0.14419, 0.358967, 0.378127] ,
[80.007155, 0.210573, 0.122946, 0.355789, 0.37113] ,
[100.001683, 0.212233, 0.113924, 0.340021, 0.36258] ,
[120.004766, 0.209273, 0.104767, 0.341188, 0.360503] ,
[140.008725, 0.211735, 0.099358, 0.338134, 0.362321] ,
[160.000656, 0.209132, 0.090941, 0.337889, 0.359183] ,
[180.006237, 0.21108, 0.084566, 0.335734, 0.36059] ,
[200.005395, 0.208582, 0.081626, 0.335171, 0.357777] ,
])
v2tot = np.column_stack((v2, np.round(v2_ideal, 8), np.round(f_charge140_170us_v2, 8),
                         np.round(f_charge140_30us_v2, 8), np.round(f_charge140_3us_v2, 8) ))

# %%
f_charge140_170us_v3 = np.array([
-0.7761794330039011, -1.136974068566397, -1.6364561843108747, -1.649779365007976 ,
-1.9034720838457102, -2.1778548157427653, -2.4709933233521295, -2.3745061013160864 ,
-2.63398540043164 ,
])
f_charge140_30us_v3 = np.array([
-0.7738740011678911, -1.1275068993090454, -1.5926022942046747, -1.5934061361700882 ,
-1.7894363129283495, -1.9524905261080059, -2.068837875672322, -2.003601523219357 ,
-2.0603941827210117 ,
])
f_charge140_3us_v3 = np.array([
-0.7500017009370954, -1.037398163551171, -1.2883504158910843, -1.2360655677120598 ,
-1.2589640548056762, -1.2396064632792754, -1.2149204233039894, -1.171424405728427 ,
-1.138361377642085 ,
])
v3_ideal = np.array([
-0.7710296520870434, -1.137366901124569, -1.6405575650317505, -1.6549173821223386 ,
-1.9055133720239796, -2.250809546974744, -2.5388987862677066, -2.4791309644505026 ,
-2.6693074486470736 ,
])
v3 = np.array([
[30.002512, 0.222626, 0.201971, 0.389445, 0.425332] ,
[50.000191, 0.215248, 0.148153, 0.354356, 0.376483] ,
[70.001044, 0.209788, 0.131851, 0.353189, 0.36997] ,
[90.009744, 0.219753, 0.113433, 0.351332, 0.376525] ,
[110.009928, 0.211658, 0.106989, 0.341806, 0.362874] ,
[130.002315, 0.201238, 0.098495, 0.3428, 0.353056] ,
[150.002399, 0.205268, 0.094552, 0.339607, 0.355509] ,
[170.00663, 0.212306, 0.087921, 0.33633, 0.362475] ,
[190.009275, 0.209698, 0.083495, 0.335382, 0.359146] ,
])
v3tot = np.column_stack((v3, np.round(v3_ideal, 8), np.round(f_charge140_170us_v3, 8),
                         np.round(f_charge140_30us_v3, 8), np.round(f_charge140_3us_v3, 8) ))
arr = np.row_stack((v2tot, v3tot))
sorted_arr = arr[np.argsort(arr[:, 0])]
for i in range(len(sorted_arr)):
    print(sorted_arr[i].tolist(), ',')
# Out:
# [20.000087, 0.249753, 0.216297, 0.43883, 0.490612, -0.60091121, -0.60338412, -0.60238359, -0.59171153] ,
# [30.002512, 0.222626, 0.201971, 0.389445, 0.425332, -0.77102965, -0.77617943, -0.773874, -0.7500017] ,
# [40.006173, 0.223179, 0.160035, 0.358809, 0.386917, -0.89534681, -0.90030223, -0.89618669, -0.85442286] ,
# [50.000191, 0.215248, 0.148153, 0.354356, 0.376483, -1.1373669, -1.13697407, -1.1275069, -1.03739816] ,
# [60.000967, 0.213711, 0.14419, 0.358967, 0.378127, -1.46633629, -1.4630289, -1.437234, -1.229683] ,
# [70.001044, 0.209788, 0.131851, 0.353189, 0.36997, -1.64055757, -1.63645618, -1.59260229, -1.28835042] ,
# [80.007155, 0.210573, 0.122946, 0.355789, 0.37113, -1.66328542, -1.65690125, -1.6041504, -1.26116399] ,
# [90.009744, 0.219753, 0.113433, 0.351332, 0.376525, -1.65491738, -1.64977937, -1.59340614, -1.23606557] ,
# [100.001683, 0.212233, 0.113924, 0.340021, 0.36258, -1.89393989, -1.88691985, -1.78706821, -1.28873878] ,
# [110.009928, 0.211658, 0.106989, 0.341806, 0.362874, -1.90551337, -1.90347208, -1.78943631, -1.25896405] ,
# [120.004766, 0.209273, 0.104767, 0.341188, 0.360503, -2.10064564, -2.04000815, -1.87888959, -1.25472298] ,
# [130.002315, 0.201238, 0.098495, 0.3428, 0.353056, -2.25080955, -2.17785482, -1.95249053, -1.23960646] ,
# [140.008725, 0.211735, 0.099358, 0.338134, 0.362321, -2.28806233, -2.24970016, -1.98796543, -1.22964912] ,
# [150.002399, 0.205268, 0.094552, 0.339607, 0.355509, -2.53889879, -2.47099332, -2.06883788, -1.21492042] ,
# [160.000656, 0.209132, 0.090941, 0.337889, 0.359183, -2.58417118, -2.51253441, -2.07387359, -1.19613811] ,
# [170.00663, 0.212306, 0.087921, 0.33633, 0.362475, -2.47913096, -2.3745061, -2.00360152, -1.17142441] ,
# [180.006237, 0.21108, 0.084566, 0.335734, 0.36059, -2.67945245, -2.50589513, -2.0442748, -1.15531171] ,
# [190.009275, 0.209698, 0.083495, 0.335382, 0.359146, -2.66930745, -2.6339854, -2.06039418, -1.13836138] ,
# [200.005395, 0.208582, 0.081626, 0.335171, 0.357777, -2.73651652, -2.62132412, -2.03062573, -1.11749146] ,

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_phi['tg'], 10**f_phi['f_1000'], '.--', label=r'f_ideal')
# plt.plot(f_phi['tg'], 10**sorted_arr[:,5], 's--', label=r'f_charge140_ideal')
plt.plot(f_phi['tg'], 10**sorted_arr[:,6], 's--', label=r'f_charge140_170us')
plt.plot(f_phi['tg'], 10**sorted_arr[:,7], 'v--', label=r'f_charge140_30us')
plt.plot(f_phi['tg'], 10**sorted_arr[:,8], 'D--', label=r'f_charge140_3us')


plt.yscale('log')
plt.title(r'$n_\phi$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f_70_all = np.array([
-0.5766486851411565, -0.5834070487120887, -0.96091571160584, -1.2264790705142403 ,
-1.301624431089364, -1.5753777669062592, -1.4674855426000768, -1.4430303673326017 ,
-2.175550163132439, -2.0640454013049423, -2.117625762023804, -2.290636350340953 ,
f_test = np.array([
-0.5986231367421744, -0.7237265597596635, -0.8802066440964171, -1.1201719585209713 ,
-1.4557356876298317, -1.6297278576422207, -1.6538480974940664, -1.6071283232771019 ,
-1.9391205882296854, -1.8691453227298267, -2.10714805519766, -2.278962142477299 ,
-2.2938962080971184, -2.5458049528322175, -2.605650631737946, -2.502716507624691 ,
-2.709262640810357, -2.670435439479445, -2.738837250635131 ,
])

# %%
f_short_post_140 = np.array([
-0.5737747434913802, -0.7322366907514805, -0.8429486192351081, -1.0346811939300755 ,
-1.315632140473018, -1.5209244874450032, -1.4441344577711308, -1.540728635150984 ,
-1.7519097174135054, -1.8184241006634938, -2.1506915497641304, -2.148389501990708 ,
-2.004355866408247, -2.1304755584069617, -2.065269263240155, -1.985775758849014 ,
-2.1305651429895036, -2.181144131588821, -2.412670678429873 ,
])

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.plot(f_phi['tg'], 10**f_phi['f_1000'], 's--', label=r'f_1000')
# plt.plot(f_phi['tg'], 10**f_phi['f_500'], '.--', label=r'f_500')
# plt.plot(f_phi['tg'], 10**f_charge_140, '.--', label=r'f_charge_140')
# plt.plot(f_phi['tg'], 10**f_70_all, '.--', label=r'f_70_all')
# plt.plot(f_phi['tg'], 10**f_80_all, '.--', label=r'f_80_all')
# plt.plot(f_phi['tg'], 10**f_90_all, '.--', label=r'f_90_all')
# plt.plot(f_phi['tg'], 10**f_100_all, '.--', label=r'f_100_all')
# plt.plot(f_phi['tg'], 10**f_130_all, '.--', label=r'f_130_all')
# plt.plot(f_phi['tg'], 10**f_all300_160, '.--', label=r'f_160')
# plt.plot(f_phi['tg'], 10**f_150_all, '.--', label=r'f_150_all')
plt.plot(f_phi['tg'], 10**f_short_140, '.--', label=r'f_short_140')
# plt.plot(f_phi['tg'], 10**f_short_120, '.--', label=r'f_short_120')
# plt.plot(f_phi['tg'], 10**f_short_100, '.--', label=r'f_short_100')
# plt.plot(f_phi['tg'], 10**f_all500_200, '.--', label=r'f_all500_200')
# plt.plot(f_phi['tg'], 10**f_all500_180, '.--', label=r'f_all500_180')
# plt.plot(f_phi['tg'], 10**f_test, '.--', label=r'f_170_10b')
# plt.plot(f_phi['tg'], 10**f_all500_170_20, '.--', label=r'f_all500_170_20')
plt.plot(f_phi['tg'], 10**f_short_post_140, '.--', label=r'f_short_post_140')
plt.yscale('log')
plt.title(r'$n_\phi$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.grid()
legend = plt.legend( loc="best", fontsize=30 )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
=
# Out:
#   Cell In[16], line 1
#     =
#     ^
# SyntaxError: invalid syntax

# %%
f_50us_tphi_t1_29 = np.array([
-0.597837159026259, -1.0364488079341636, -1.30472009047845, -1.285174526891729 ,
-1.1911491932518665 ,
])
f_50us_tphi_t1_09 = np.array([
-0.6063112431542304, -1.100209088024563, -1.666978155178618, -1.7688117939637635 ,
-1.7310880067727425 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_phi['tg'], 10**f_phi['f_ideal_160'], '.--', label=r'f_ideal')
plt.plot(f_phi['tg'], 10**f_phi['f_noise_100_50us'], '.--', label=r'f_100_50us')
plt.plot(f_phi['tg'], 10**f_phi['f_noise_9_2us'], '.--', label=r'f_phi_9_2us')
# plt.plot(tg7, 10**f_50us_tphi_t1_29, '.-', label=r'f_50us_tphi_t1_29')
plt.plot(tg7, 10**f_50us_tphi_t1_09, '.-', label=r'f_50us_tphi_t1_09')
plt.plot(tg7, 10**f_2us_tphi_t1_09, '.-', label=r'f_9_2us_tphi_t1_09')
plt.yscale('log')
plt.title(r'$n_\phi$')
plt.xlabel('Gate time $t_g$ (ns)')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f157_phi = np.array([-0.40106527, -0.75167091, -1.09786349, -1.19616409 ,-1.53194675 ,])
f500_phi = np.array([-0.40119934, -0.74385016, -1.08980239, -1.18396283 , -1.52970251 ,])
para_phi = np.array([
[10.003267, 0.24348, 0.211892, 0.444743, 0.499987] ,
[20.000082, 0.255455, 0.169295, 0.338178, 0.443775] ,
[30.009674, 0.226521, 0.166161, 0.34729, 0.404246] ,
[40.008273, 0.169565, 0.211625, 0.342425, 0.34903] ,
[60.010631, 0.201448, 0.117206, 0.300092, 0.339997] ,
])

# %%
fig, ax = plt.subplots(figsize=(8,8), nrows=3)
fig.suptitle(r'X-gate $n_\phi$ 3ncut', fontsize=14)
fig.subplots_adjust(top=0.95)
ax[0].plot(f_phi['tg'], f_phi['drive_amp_1'], '.-', label=r'zp0:drive_amp_1')
ax[0].plot(f_phi['tg'], f_phi['drive_amp_2'], '.-', label=r'zp0:drive_amp_2')
ax[1].plot(f_phi['tg'], f_phi['detune_1'], '.-', label=r'zp0:detune_1')
ax[1].plot(f_phi['tg'], f_phi['detune_2'], '.-', label=r'zp0:detune_2')
ax[2].plot(f_phi['tg'], 10**f_phi['f_500'], '.-', label=r'fidelity_zp0')

ax[0].plot(para_phi[:,0], para_phi[:,1], '.-', label=r'zp1:drive_amp_1')
ax[0].plot(para_phi[:,0], para_phi[:,2], '.-', label=r'zp1:drive_amp_2')
ax[1].plot(para_phi[:,0], para_phi[:,3], '.-', label=r'zp1:detune_1')
ax[1].plot(para_phi[:,0], para_phi[:,4], '.-', label=r'zp1:detune_2')
ax[2].plot(para_phi[:,0], 10**f500_phi, '.-', label=r'fidelity_zp1')

plt.xlabel('Gate time $t_g$ (ns)')
ax[2].set_yscale('log')
# ax[0].set_ylim(0.04, 0.05)
# ax[1].set_ylim(0.01, 0.02)
# ax[0].set_ylim(0.0065, 0.009)
# ax[1].set_ylim(0.01, 0.02)
ax[2].set_yscale('log')
for i in range(3):
    ax[i].grid()
    # ax[i].set_xlim(25, 40)
    # ax[i].set_xlim(150, 200)
    legend = ax[i].legend(loc='best', fontsize=10)
    legend.get_frame().set_alpha(0.01)  # 0.5 makes the legend 50% transparent
