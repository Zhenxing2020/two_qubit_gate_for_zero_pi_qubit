# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# f_cnot = pd.read_csv('data/data_cnot_45_2A.txt')
# f_n2_20 = pd.read_csv('../cz/data/data_fig/data_cz_n2_20.txt')
f_theta = pd.read_csv('../../../figure/data/data_xgate_theta_mstep_3e4_npz.txt')
# f_phi_1ncut = pd.read_csv('data/other/data_xgate_phi_1ncut.txt')
# f_theta = pd.read_csv('data/data_xgate_theta_3ncut_mstep_3e4.txt')
# f_phi = pd.read_csv('data/data_xgate_phi_3ncut.txt')
# df = pd.DataFrame(f_comb, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1',
#                                    'detune_2', 'f_157', 'f_500',  'f_noise_9_2us', 'f_noise_100_5us', 'f_noise_100_50us', 'f_78'])
# df.to_csv('data/data_xgate_theta_3ncut.txt', sep=',', index=False, header=True)


colors = [
    '#1f77b4',  # Blue
    '#ff7f0e',  # Orange
    '#2ca02c',  # Green
    '#d62728',  # Red
    '#9467bd',  # Purple
    '#8c564b',  # Brown
    '#e377c2',  # Pink
    '#7f7f7f',  # Gray
    '#bcbd22',  # Yellow-green
    '#17becf'   # Cyan
]

# %%
params = f_theta[['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2'
                    ]].to_numpy()[::4] #[1::4, :]
params2 = f_theta[['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2'
                    ]].to_numpy()                  

f_ideal_78 = np.array([
-0.49104180, -0.87881360, -1.90927199, -2.76949029 ,
-3.34207259, -3.75336566, -4.10171898, -4.45843070 ,
-4.71504009, -4.96909463, -5.14971441, -5.38525860 ,
-5.59528458, -5.92356061, -6.21976207, -6.50879663 ,
-6.61042399, -6.90973566 ,
])

f_170us_78 = np.array([
-0.49100995, -0.87866400, -1.90697024, -2.75025101 ,
-3.26471675, -3.55768255, -3.71783349, -3.79416523 ,
-3.80552325, -3.79559243, -3.78053804, -3.75349439 ,
-3.72644945, -3.67609859, -3.62952805, -3.58695753 ,
-3.54783658, -3.51200831 ,
])

f_30us_78 = np.array([
-0.49091232, -0.87816486, -1.89865207, -2.68328839 ,
-3.04825470, -3.16532841, -3.18456161, -3.16379501 ,
-3.13384001, -3.09956341, -3.07359169, -3.03703651 ,
-3.00447660, -2.94824162, -2.89813941, -2.85314130 ,
-2.81231367, -2.77499108 ,
])

f_3us_78 = np.array([
-0.48985018, -0.87276157, -1.81704280, -2.27572700 ,
-2.32633333, -2.29210070, -2.24584529, -2.19460682 ,
-2.15428005, -2.11457956, -2.08638730, -2.04808130 ,
-2.01464383, -1.95773101, -1.90745052, -1.86250518 ,
-1.82187911, -1.78480201 ,
])

# %%
f_theta['f_78_charge'] = f_ideal_78
f_theta['f_78_170us'] = f_170us_78
f_theta['f_78_30us'] = f_30us_78
f_theta['f_78_3us'] = f_3us_78

# %%
f_theta = f_theta.drop(columns=['f_170us_78', 'f_30us_78', 'f_3us_78'])

# %%
# f_theta.to_csv("../../../figure/data/data_xgate_theta_mstep_3e4_npz.txt", index=False)

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params2[:,0], 10**f_theta['f_78_charge']  , '.-', label=r'')
plt.plot(params2[:,0], 10**f_ideal_78  , '.-', label=r'')

plt.plot(params2[:,0], np.abs(10**f_theta['f_78_charge'] - 10**f_ideal_78) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\theta$, 170μs, n=78 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
# 2nd / New dephasing
f_ideal_78 = np.array([
-0.49107346, -3.34543786, -4.70955972, -5.49786088 ,
-6.48469826 ,
])
f_170us_78 = np.array([
-0.49035846, -2.48472216, -2.32803626, -2.18854353 ,
-1.99559540 ,
])
f_30us_78 = np.array([
-0.48725395, -1.79242462, -1.58868649, -1.45208809 ,
-1.26776007 ,
])
f_3us_78 = np.array([
-0.45644861, -0.87487522, -0.70559090, -0.60932223 ,
-0.49865365 ,
])

# 1st / Old dephasing
f_170us_78_old = np.array([
-0.49101736, -3.28008702, -3.89836274, -3.83562963 ,
-3.66218080 ,
])
f_30us_78_old = np.array([
-0.49095418, -3.10359630, -3.24853015, -3.12290269 ,
-2.93193242 ,
])
f_3us_78_old = np.array([
-0.49026596, -2.43746832, -2.27415043, -2.13465541 ,
-1.94198273 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params2[:,0], 10**f_ideal_78  , '.-', label=r'ideal')
plt.plot(params2[:,0], 10**f_170us_78  , '.-', label=r'2nd_170us')
plt.plot(params2[:,0], 10**f_30us_78  , '.-', label=r'2nd_30us')
plt.plot(params2[:,0], 10**f_3us_78  , '.-', label=r'2nd_3us')

plt.plot(params[:,0], 10**f_170us_78_old  , '.--', label=r'1st_170us')
plt.plot(params[:,0], 10**f_30us_78_old  , '.--', label=r'1st_30us')
plt.plot(params[:,0], 10**f_3us_78_old  , '.--', label=r'1st_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'2nd vs 1st derivative: tphi', fontsize=15)
plt.ylabel(r'Infidelity, $n_\theta$, n=78 ', fontsize=15)
plt.grid()
plt.legend( loc="best", fontsize=8)

# %% [markdown]
# ## 2nd vs 1st derivative, tphi

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_78  , '.-', label=r'ideal')
plt.plot(params[:,0], 10**f_170us_78  , '.-', label=r'2nd_170us')
plt.plot(params[:,0], 10**f_30us_78  , '.-', label=r'2nd_30us')
plt.plot(params[:,0], 10**f_3us_78  , '.-', label=r'2nd_3us')

plt.plot(params[:,0], 10**f_170us_78_old  , '.--', label=r'1st_170us')
plt.plot(params[:,0], 10**f_30us_78_old  , '.--', label=r'1st_30us')
plt.plot(params[:,0], 10**f_3us_78_old  , '.--', label=r'1st_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'2nd vs 1st derivative: tphi', fontsize=15)
plt.ylabel(r'Infidelity, $n_\theta$, n=78 ', fontsize=15)
plt.grid()
plt.legend( loc="best", fontsize=8)

# %% [markdown]
# ## 2nd vs 1st derivative, t1

# %%
# 2nd / New dephasing
f_ideal_78 = np.array([
-0.49107346, -3.34543786, -4.70955972, -5.49786088 ,
-6.48469826 ,
])


# 1st / Old dephasing
f_170us_78 = np.array([
-0.49102350, -3.31222498, -4.20312039, -4.24049084 ,
-4.10239879 ,
])
f_30us_78 = np.array([
-0.49098873, -3.23973920, -3.69164412, -3.59796022 ,
-3.41450401 ,
])
f_3us_78 = np.array([
-0.49061024, -2.81193857, -2.75975531, -2.62402675 ,
-2.42994324 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_78  , '.-', label=r'ideal')
plt.plot(params[:,0], 10**f_170us_78  , '.-', label=r'2nd_170us')
plt.plot(params[:,0], 10**f_30us_78  , '.-', label=r'2nd_30us')
plt.plot(params[:,0], 10**f_3us_78  , '.-', label=r'2nd_3us')

# plt.plot(params[:,0], 10**f_170us_78_old  , '.--', label=r'1st_170us')
# plt.plot(params[:,0], 10**f_30us_78_old  , '.--', label=r'1st_30us')
# plt.plot(params[:,0], 10**f_3us_78_old  , '.--', label=r'1st_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'2nd vs 1st derivative: t1', fontsize=15)
plt.ylabel(r'Infidelity, $n_\theta$, n=78 ', fontsize=15)
plt.grid()
plt.legend( loc="best", fontsize=8)

# %% [markdown]
# ## 2nd vs 1st derivative, tphi + t1

# %%
# 2nd / New dephasing
f_ideal_78 = np.array([
-0.49107346, -3.34543786, -4.70955972, -5.49786088 ,
-6.48469826 ,
])
f_170us_78 = np.array([
-0.49035104, -2.48222459, -2.32527522, -2.18577773 ,
-1.99282427 ,
])
f_30us_78 = np.array([
-0.48721261, -1.78960548, -1.58592241, -1.44933282 ,
-1.26500858 ,
])
f_3us_78 = np.array([
-0.45609156, -0.87206486, -0.70290090, -0.60662593 ,
-0.49588651 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_78  , '.-', label=r'ideal')
plt.plot(params[:,0], 10**f_170us_78  , '.-', label=r'2nd_170us')
plt.plot(params[:,0], 10**f_30us_78  , '.-', label=r'2nd_30us')
plt.plot(params[:,0], 10**f_3us_78  , '.-', label=r'2nd_3us')

plt.plot(params[:,0], 10**f_theta['f_170us_78'][::4]  , '.--', label=r'1st_170us')
plt.plot(params[:,0], 10**f_theta['f_30us_78'][::4]  , '.--', label=r'1st_30us')
plt.plot(params[:,0], 10**f_theta['f_3us_78'][::4]  , '.--', label=r'1st_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'2nd vs 1st derivative: tphi+t1', fontsize=15)
plt.ylabel(r'Infidelity, $n_\theta$, n=78 ', fontsize=15)
plt.grid()
plt.legend( loc="best", fontsize=8)

# %%
f_ideal_78 = np.array([
-0.49296734, -0.89390446, -1.84438808, -2.28802525 ,
-2.97467243, -3.66406842, -4.16733256, -4.65183056 ,
-5.03998128, -5.38266460, -5.68748898, -6.00946332 ,
-6.18694474, -6.35778749, -6.75849608, -7.02333025 ,
-6.94851323, -7.58189003 ,
])
f_ideal_150 = np.array([
-0.49104290, -0.87881764, -1.90929885, -2.76956467 ,
-3.34217970, -3.75354024, -4.10202382, -4.45890128 ,
-4.71567264, -4.96985204, -5.15065593, -5.38633539 ,
-5.59671364, -5.92590138, -6.22076067, -6.50805292 ,
-6.60585703, -6.88800506 ,
])

# %%
f_theta['f_78'] = f_ideal_78
f_theta['f_150'] = f_ideal_150
f_theta.to_csv('data/data_xgate_theta_3ncut_mstep_3e4.txt', sep=',', index=False, header=True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_theta['f_78_charge']  , '.-', label=r'')
plt.plot(params[:,0], 10**f_ideal_78  , '.-', label=r'')

plt.plot(params[:,0], np.abs(10**f_theta['f_78_charge'] - 10**f_ideal_78) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\theta$, 170μs, n=78 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Noisy infidelity convergence vs max_step

# %%
f_170us_78_1e3 = np.array([
-0.8785264587791042, -3.6264974863852344, -4.166947136231203, -3.8500041506886213 ,
-3.6075832550273814 ,
])
f_170us_78_3e4 = np.array([
-0.8786638112255045, -3.557589856315058, -3.7954772870152733, -3.676035744598388 ,
-3.5119800529028296 ,
])
f_170us_78_1e4 = np.array([
-0.8786919085889747, -3.5761660393332795, -3.828183548705265, -3.700646119031446 ,
-3.528690176102402 ,
])
f_170us_78_1e5 = np.array([
-0.8786958795910216, -3.5786404684098443, -3.8326147933512256, -3.703944977626915 ,
-3.530907122487817 ,
])
f_170us_206_1e4 = np.array([
-0.8894731790580659, -3.5892795302392235 ,-3.8295710591483 , -3.7007806358278015,
-3.5286973057810966 ,])
f_170us_206_3e4 = np.array([
-0.8894829287788648, -3.569413361891439, -3.7953836209864726, -3.6750867331634556 ,
-3.511237930979044 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_170us_78_1e5, '.-', label=r'max_step=1e-5 (9.5hours)')
# plt.plot(params[:,0], 10**f_170us_78_1e4, '.-', label=r'max_step=1e-4 (2hours)')
# plt.plot(params[:,0], np.abs(10**f_170us_78_1e5 - 10**f_170us_78_1e4) , 'x--', label=r'difference')
# plt.plot(params[:,0], 10**f_170us_78_3e4, '.-', label=r'max_step=3e-4 (15mins)')
# plt.plot(params[:,0], np.abs(10**f_170us_78_1e5 - 10**f_170us_78_3e4) , 'x--', label=r'difference')
plt.plot(params[:,0], 10**f_170us_78_1e3, '.-', label=r'max_step=1e-3 (7mins)')
plt.plot(params[:,0], np.abs(10**f_170us_78_1e5 - 10**f_170us_78_1e3) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\theta$, 170μs, n=78 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Noisy infidelity convergence vs truncation

# %%
fig, ax = plt.subplots(figsize=(5,3))
# plt.plot(params[:,0], 10**f_170us_206_1e4, '.-', label=r'truncation=206 (16hours)')
# plt.plot(params[:,0], 10**f_170us_78_1e4, '.-', label=r'truncation=78 (2hours)')
# plt.plot(params[:,0], np.abs(10**f_170us_78_1e4 - 10**f_170us_206_1e4) , 'x--', label=r'difference')

plt.plot(params[:,0], 10**f_170us_206_3e4, '.-', label=r'truncation=206 (14hours)')
plt.plot(params[:,0], 10**f_170us_78_3e4, '.-', label=r'truncation=78 (15mins)')
plt.plot(params[:,0], np.abs(10**f_170us_78_3e4 - 10**f_170us_206_3e4) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity: $n_\theta$, 170μs, max_step=3e-4', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Infidelity: "decay between all states" vs "decay to 0 state"

# %%
f_ideal_78 = np.array([
-0.49103758889040255, -0.878807802058778, -1.9092417873325929, -2.769419021803559 ,
-3.3418918618408293, -3.753118565136611, -4.101280831868235, -4.4578028925369875 ,
-4.714225911200767, -4.968157769769386, -5.148420029628917, -5.384018922239932 ,
-5.593162360625406, -5.9184071497035164, -6.21972852154908, -6.511368237375638 ,
-6.609064357355396, -6.939974409343103 ,
])
f_170us_78_3e5 = np.array([
-0.491015227620051, -0.878695559702283, -1.9074017418509113, -2.753384618285333 ,
-3.2751341880613887, -3.5784400318825407, -3.748220710453887, -3.830674324184095 ,
-3.8430591138963366, -3.8322550244202684, -3.8159058077935364, -3.7866507730833847 ,
-3.7575354460546104, -3.703677483004979, -3.6542253026761977, -3.6092911082334123 ,
-3.5682024390387808, -3.530727610319087 ,
])
f_30us_78 = np.array([
-0.8781921325331272, -3.1725378457407567, -3.1058130174896843, -2.9526658863630186 ,
-2.777966086152775 ,
])
f_3us_78 = np.array([
-0.8727791915617726, -2.292794280922264, -2.115090866889265, -1.9581104118359862 ,
-1.785068566165355 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_theta['f_500'], '.--', label=r'f_ideal_old')
plt.plot(f_theta['tg'], 10**f_ideal_78, '.-', label=r'f_ideal_new')
plt.plot(f_theta['tg'], 10**f_170us_78_3e5, '.-', label=r'f_170us_new')
# plt.plot(params[:,0], 10**f_30us_78, '.-', label=r'f_30us_new')
# plt.plot(params[:,0], 10**f_3us_78, '.-', label=r'f_3us_new')
plt.plot(f_theta['tg'], 10**f_theta['f_noise_170us'], '.--', label=r'f_170us_old')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_30us'], '.-', label=r'f_noise_30us')
# plt.plot(f_theta['tg'], 10**f_theta['f_noise_3us'], '.-', label=r'f_noise_3us')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'$n_\theta$ ', fontsize=15)
plt.grid()
legend = plt.legend( loc="lower left", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal infidelity convergence vs max_step
#
# n=78

# %%
f_ideal_78_3e4 = np.array([
-0.8788087913806248, -3.7530981001621195, -4.968023026496211, -5.9191030412597225 ,
-6.930806814043593 ,
])
f_ideal_78_1e4 = np.array([
-0.878807802058778, -3.753118565136611, -4.968157769769386, -5.9184071497035164 ,
-6.939974409343103 ,
])
f_ideal_78_1e5 = np.array([
-0.8788053413597259, -3.7530185205543067, -4.967642100778561, -5.917092935109884 ,
-6.933488932680155 ,
])

# %%
fig, ax = plt.subplots(figsize=(5,3))
plt.plot(params[:,0], 10**f_ideal_78_1e5, '.-', label=r'max_step=1e5(4mins)')

# plt.plot(params[:,0], 10**f_ideal_78_1e4, '.-', label=r'max_step=1e4(35s)')
# plt.plot(params[:,0], np.abs(10**f_ideal_78_1e5 - 10**f_ideal_78_1e4) , 'x--', label=r'difference')
plt.plot(params[:,0], 10**f_ideal_78_3e4, '.-', label=r'max_step=3e4(18s)')
plt.plot(params[:,0], np.abs(10**f_ideal_78_1e5 - 10**f_ideal_78_3e4) , 'x--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\theta$, Ideal, n=78', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Ideal infidelity convergence vs truncation

# %%
f_ideal_78_1e4 = np.array([
-0.49103758889040255, -0.878807802058778, -1.9092417873325929, -2.769419021803559 ,
-3.3418918618408293, -3.753118565136611, -4.101280831868235, -4.4578028925369875 ,
-4.714225911200767, -4.968157769769386, -5.148420029628917, -5.384018922239932 ,
-5.593162360625406, -5.9184071497035164, -6.21972852154908, -6.511368237375638 ,
-6.609064357355396, -6.939974409343103 ,
])
f_ideal_150_1e4 = np.array([
-0.49103811194296043, -0.878809640749037, -1.9092527117583074, -2.769442757124277 ,
-3.341935079170237, -3.7531812899675443, -4.10137356908053, -4.457938325423597 ,
-4.714415515689196, -4.968398103580361, -5.148718120845453, -5.384451815145302 ,
-5.5937026121904365, -5.918954965866413, -6.221016949882627, -6.513108151169383 ,
-6.608227470833687, -6.941394116298404 ,
])
f_ideal_157_1e4 = np.array([
-0.4769473403143527, -0.8906093465077031, -1.9392210194563675, -2.7908929852532065 ,
-3.36316342619703, -3.772207915995641, -4.1198006103558225, -4.476203100983783 ,
-4.732571903332249, -4.987519856192919, -5.1685206694075445, -5.405056186161227 ,
-5.615730005895958, -5.941577696793418, -6.243368038842867, -6.536471225832295 ,
-6.624357981014932, -6.96014098640153 ,
])
f_ideal_300_1e4 = np.array([
-0.4769477114328514, -0.8906105518219678, -1.9392298063390627, -2.790915715186603 ,
-3.3632103788047294, -3.7722830516693677, -4.1199155976810236, -4.47638589992227 ,
-4.73281339262754, -4.987844983739261, -5.1689088912905286, -5.405594503440736 ,
-5.6164792295095145, -5.9423118821968375, -6.2450635400620795, -6.5386011311536345 ,
-6.622786096002521, -6.961313301262822 ,
])
f_ideal_1000_1e4 = np.array([
-0.4768681221238249, -0.8896261247648674, -1.9402233144491279, -2.7926934786741326 ,
-3.3644910582061853, -3.7733456176313425, -4.120968255604761, -4.477468151636948 ,
-4.733968323838105, -4.989130403684351, -5.170416384445986, -5.407248580518891 ,
-5.618523112005368, -5.945250353649779, -6.246300475188349, -6.537934231032713 ,
-6.621721149868869, -6.943958747816108 ,
])
f_theta['f_78'] = np.round(f_ideal_78_1e4, 8)
f_theta['f_157'] = np.round(f_ideal_157_1e4, 8)
f_theta['f_1000'] = np.round(f_ideal_1000_1e4, 8)
df = pd.DataFrame(f_theta, columns=['tg', 'drive_amp_1', 'drive_amp_2', 'detune_1', 'detune_2', 'f_78', 'f_157', 'f_1000'])
# df.to_csv('data/data_xgate_theta_3ncut_mstep=1e-4.txt', sep=',', index=False, header=True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
# plt.plot(f_theta[['tg']], 10**f_ideal_78_1e4, '.-', label=r'truncation=78(50s)')
plt.plot(f_theta[['tg']], 10**f_ideal_157_1e4, '.-', label=r'truncation=157(90s)')

plt.plot(f_theta[['tg']], 10**f_ideal_1000_1e4, '.-', label=r'truncation=1000(21mins)')
plt.plot(f_theta[['tg']], np.abs(10**f_ideal_1000_1e4 - 10**f_ideal_157_1e4) , 'x--', label=r'difference')
# plt.plot(f_theta[['tg']], np.abs(10**f_ideal_1000_1e4 - 10**f_ideal_78_1e4) , 'x--', label=r'difference')
# plt.plot(f_theta[['tg']], 10**f_ideal_150_1e4, '.-', label=r'truncation=150(50s)')
# plt.plot(f_theta[['tg']], np.abs(10**f_ideal_150_1e4 - 10**f_ideal_78_1e4) , 'x--', label=r'difference')

plt.yscale('log')
plt.xlabel('Gate time $t_g$ (ns)')
plt.title(r'Infidelity, $n_\theta$, Ideal, max_step=1e-4 ', fontsize=15)
plt.grid()
legend = plt.legend( loc="best", fontsize=12)
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Find best truncation
#
# max_step=3e-4

# %%
f_ideal_55 = np.array([
-0.4952989209748051, -0.9750864069386653, -2.1762804560680187, -2.8841389201139527 ,
-3.422628246811922, -3.8434862818923343, -4.233575431176374, -4.677474870329673 ,
-5.012920766913601, -5.353581903081116, -5.611037854005285, -5.93131650740306 ,
-6.209646950444646, -6.553564294307515, -6.934702252410016, -7.36693863981132 ,
-7.052201779810175, -7.695129169449177 ,
])
f_ideal_59 = np.array([
-0.4880718965341387, -0.9783969455087297, -2.181562953360337, -2.8988572665533314 ,
-3.437147674633219, -3.8517008334512632, -4.240684415504272, -4.681826145048625 ,
-5.013313040449415, -5.352587776433708, -5.604066741623058, -5.921719461690158 ,
-6.207910633594867, -6.561361163743207, -6.935652428893715, -7.378872934990837 ,
-7.047966642088174, -7.678477654075753 ,
])
f_ideal_63 = np.array([
-0.4985683098014894, -0.9827626670196494, -2.2548237167441814, -2.9930651864258264 ,
-3.551821139654499, -3.967087797100846, -4.344709994002454, -4.761299118426912 ,
-5.063918563497289, -5.380174567496063, -5.617573672651362, -5.921721063303754 ,
-6.205059546648846, -6.5630167316657575, -6.929883861854128, -7.373570473945196 ,
-7.047897012782581, -7.647475537939448 ,
])
f_ideal_70 = np.array([
-0.4919617412656398, -0.9780390205702874, -2.2266761174919396, -2.9884207529783353 ,
-3.5512738966024755, -3.9663716392812587, -4.346405290078726, -4.764763707455171 ,
-5.067543965299129, -5.385403827059692, -5.621874669332259, -5.925050687996824 ,
-6.21003768110777, -6.571709770038175, -6.9282219400443985, -7.371259685650962 ,
-7.045808952762617, -7.627511932656508 ,
])
f_ideal_76 = np.array([
-0.49599857324312013, -0.8802068614432665, -1.8898135232801145, -2.76658631519469 ,
-3.3493887619714227, -3.7658386750106287, -4.117894861071901, -4.478870143948168 ,
-4.738140158968169, -4.995124594928574, -5.177792549997062, -5.415609848790415 ,
-5.626925840363245, -5.953800699360282, -6.254077912650524, -6.546792271591325 ,
-6.640790912942781, -6.967658017146375 ,
])
f_ideal_78 = np.array([
-0.4910401279060491, -0.8788087913806248, -1.9092459162631445, -2.7694128276542247 ,
-3.341884243798919, -3.7530981001621195, -4.101265966511826, -4.457766375638734 ,
-4.714158592362988, -4.968023026496211, -5.148294981427083, -5.383688856889358 ,
-5.592911697258704, -5.9191030412597225, -6.217924075791553, -6.508004132593557 ,
-6.612541926604733, -6.930806814043593 ,
])
f_ideal_100 = np.array([
-0.49529925025664634, -0.975087370443019, -2.176285980444016, -2.8841535790432493 ,
-3.4226588282662362, -3.843531184200982, -4.2336440021642385, -4.677575855869898 ,
-5.013049523545664, -5.353756199842104, -5.6112860429006455, -5.93162447206822 ,
-6.210072711449519, -6.553964703556435, -6.9349569736632475, -7.366471667124848 ,
-7.049942848320972, -7.684301935452057 ,
])
f_ideal_157 = np.array([
-0.4769510348817827, -0.8906153488846216, -1.939246848191887, -2.790873370655956 ,
-3.3631461930231796, -3.772191658186468, -4.119779608582934, -4.476160690563936 ,
-4.7324947819096455, -4.987352803229129, -5.1683638084418435, -5.40460290008453 ,
-5.615373829228771, -5.94258067188785, -6.2406314873662545, -6.531872251431755 ,
-6.629353889143676, -6.94700158804423 ,
])
f_ideal_500 = np.array([
-0.4768675209404182, -0.8896245836286782, -1.940226809840099, -2.7919084217410095 ,
-3.363639246003947, -3.77240122168517, -4.119876709167307, -4.476080627787024 ,
-4.7322718481350154, -4.986955240785758, -5.167946409697648, -5.403979403607491 ,
-5.614900843393097, -5.943264394436332, -6.240010397491758, -6.529790195540401 ,
-6.627806005151546, -6.935072288899299 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(f_theta['tg'], 10**f_ideal_500, 'D-', label=r'n_charge=500')
# plt.plot(f_theta['tg'], 10**f_ideal_157, 'v-', label=r'n_charge=157')
# plt.plot(f_theta['tg'], 10**f_ideal_100, 's-', label=r'n_charge=100')
plt.plot(f_theta['tg'], 10**f_ideal_78, '.-', label=r'n_charge=78')
plt.plot(f_theta['tg'], 10**f_ideal_76, '.-', label=r'n_charge=76')
plt.plot(f_theta['tg'], 10**f_ideal_70, '.-', label=r'n_charge=70')
# plt.plot(f_theta['tg'], 10**f_ideal_63, '.-', label=r'n_charge=63')
# plt.plot(f_theta['tg'], 10**f_ideal_59, '.-', label=r'n_charge=59')
# plt.plot(f_theta['tg'], 10**f_ideal_55, '.-', label=r'n_charge=55')
plt.title(r'X gate $n_\theta$ Ideal, max_step=3e-4')
plt.yscale('log')
plt.ylim(1e-8, 1e0)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Infidelity')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Check max_steps
#
# truncation = 500, no charge pick

# %%
f_1e6 = np.array([
-0.8896162115157531, -3.772849560387933, -4.987050189878212, -5.939595305180405 ,
-6.950824848765797 ,
])
f_1e5 = np.array([
-0.8896183802244116, -3.7729249196612433, -4.987184712411418, -5.939820459183566 ,
-6.951983634222558 ,
])
f_1e4 = np.array([
-0.8896202810196633, -3.773200969174526, -4.988596030259518, -5.943190503304305 ,
-6.96135645552231 ,
])
f_3e4 = np.array([
-0.8896245836286782, -3.77240122168517, -4.986955240785758, -5.943264394436332 ,
-6.935072288899299 ,
])
f_1e3 = np.array([
-0.889660225337849, -3.7654955645317676, -4.931589891271577, -5.599013203824828 ,
-5.829376467622418 ,
])
f_0 = np.array([
-0.889671022617285, -3.7672130524617193, -4.929447138269877, -5.58886678498183 ,
-5.804948598807993 ,
])
msteps = [1e-6, 1e-5, 1e-4, 3e-4, 1e-3]
f_ideal_truc500 = np.column_stack((f_1e6, f_1e5, f_1e4, f_3e4, f_1e3))
f_ideal_truc500
# Out:
# array([[-0.88961621, -0.88961838, -0.88962028, -0.88962458, -0.88966023],
#        [-3.77284956, -3.77292492, -3.77320097, -3.77240122, -3.76549556],
#        [-4.98705019, -4.98718471, -4.98859603, -4.98695524, -4.93158989],
#        [-5.93959531, -5.93982046, -5.9431905 , -5.94326439, -5.5990132 ],
#        [-6.95082485, -6.95198363, -6.96135646, -6.93507229, -5.82937647]])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(params[:,0], 10**f_1e6, 's-', label=r'max_step=1e-6')
plt.plot(params[:,0], 10**f_1e3, 's-', label=r'max_step=1e-3')
plt.plot(params[:,0], np.abs(10**f_1e6 - 10**f_1e3), '.--', label=r'difference')
# plt.plot(params[:,0], 10**f_3e4, 's-', label=r'max_step=3e-4')
# plt.plot(params[:,0], np.abs(10**f_1e6 - 10**f_3e4), '.--', label=r'difference')
# plt.plot(params[:,0], 10**f_1e4, 's-', label=r'max_step=1e-4')
# plt.plot(params[:,0], np.abs(10**f_1e6 - 10**f_1e4), '.--', label=r'difference')
plt.yscale('log')
plt.xlabel('Gate Time $t_g$ (ns)')
plt.grid()
plt.title(r'Infidelity: $n_\theta$, Ideal, Lowest 500 states')
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
fig, ax = plt.subplots(5, 1, figsize=(4, 8), sharex=True)
for i in range(5):
    ax[i].plot(msteps, 10**f_ideal_truc500[i], 'D-', label=fr'$t_g = {params[:,0][i]:.0f}$ns')
    ax[i].set_xscale('log')
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    # ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')
ax[4].set_xlabel('max_step')
ax[0].set_title(fr'Infidelity: $n_\theta$, ideal, lowest 500 states ')
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(params[:,0], 10**f_1e6, 'D-', label=r'max_step=1e-6 (10.2hours)')
# plt.plot(params[:,0], 10**f_1e5, 'v-', label=r'max_step=1e-5 (50 minutes)')
# plt.plot(params[:,0], 10**f_1e4, 'x-', label=r'max_step=1e-4 (4.5 minutes)')
plt.plot(params[:,0], 10**f_3e4, '+-', label=r'max_step=3e-4 (1.5 minutes)')
plt.plot(params[:,0], 10**f_1e3, 'x--', label=r'max_step=1e-3 (1.3 minute)')
# plt.plot(params[:,0], 10**f_0, '.--', label=r'max_step=0 (1 minute)')

plt.title(r'X gate $n_\theta$ Ideal, trucation=500')
plt.yscale('log')
plt.ylim(1e-7, 1e0)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.ylabel('Infidelity')
plt.grid()
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %% [markdown]
# ### Check truncation

# %%
f_theta_900 = np.array([
-0.476903128108458, -0.8896790648763959, -1.9414180711112312, -2.7917104650355107 ,
-3.3615629556409408, -3.76670794004569, -4.1048234622714865, -4.437418453807678 ,
-4.672443262776792, -4.87965007490315, -5.018296267214746, -5.172646997599651 ,
-5.272078257282874, -5.406238591742835, -5.487760379794714, -5.5065875431524764 ,
-5.550701182129182, -5.526733535099553 ,
])
f_theta_800 = np.array([
-0.4768992363452663, -0.8896673555328354, -1.9406763484324778, -2.7915189638838576 ,
-3.361289481068896, -3.7663642908392974, -4.107990954183725, -4.445209806184739 ,
-4.68248249782077, -4.8976924266252775, -5.034860526652693, -5.192055036289345 ,
-5.308201759663773, -5.45881792077373, -5.510564655945, -5.581430090284119 ,
-5.577383546966255, -5.588311232978919 ,
])
f_theta_700 = np.array([
-0.47689846834235705, -0.8896715184296968, -1.9406888506995372, -2.7917535450512303 ,
-3.3614688529894585, -3.767005570860691, -4.107959685735577, -4.450135764637316 ,
-4.685627698961644, -4.905614062181384, -5.04696767843294, -5.216399748488768 ,
-5.360053232487924, -5.501715724828387, -5.569698785245428, -5.621985216765386 ,
-5.617470589548146, -5.656845808367973 ,
])
f_theta_600 = np.array([
-0.47689378940831506, -0.8896531181941285, -1.9406050359148532, -2.795772902094325 ,
-3.361504069848514, -3.7675982151685723, -4.1103825752779075, -4.454822721262368 ,
-4.692197293951154, -4.922273881833251, -5.072605756396119, -5.245843322191953 ,
-5.385003203406441, -5.553945402542144, -5.6496952987013085, -5.720864890422338 ,
-5.700466888663011, -5.752246741687437 ,
])
n_truc_large = [ 300, 400, 500, 600, 700, 800, 900, 1000]

f_ideal_large = np.column_stack((
    f_theta['f_300'].to_numpy(), 
    f_theta['f_400'].to_numpy(), 
    f_theta['f_500'].to_numpy(), 
    f_theta_600, f_theta_700, f_theta_800, f_theta_900, 
    f_theta['f_1000'].to_numpy(), 
    ))[[1, 5, 9, 13, 17 ], ]

# %% [markdown]
# ### Ideal fidelity convergence
#
# max_step=0

# %%
f_ideal_181 = np.array([
-0.8894435183030804, -3.7740314663864702, -4.972461997150224, -5.79304130916251 ,
-6.234505290340139 ,
])
f_170us_181 = np.array([
-0.8892363422147926, -3.6630655038726117, -3.911777621846385, -3.8230675389802995 ,
-3.7317271419634994 ,
])
f_ideal_157 = np.array([
-0.8906454796863686, -3.7728852130070125, -5.041233712054058, -5.826554357869655 ,
-6.304700284172778 ,
])
f_170us_157 = np.array([
-0.8904604187449506, -3.6911349543826275, -3.984849674773383, -3.8141472886797683 ,
-3.716158794767101 ,
])
f_ideal_131 = np.array([
-0.8899526270578597, -3.770946298533558, -5.085064189588203, -5.88818635660766 ,
-6.372963710092098 ,
])
f_170us_131 = np.array([
-0.8896748560073189, -3.6739120135633607, -4.103107210095756, -3.8680271397941453 ,
-3.6676030066743746 ,
])

f_ideal_118 = np.array([
-0.8895514183022839, -3.7738659293347343, -5.077598594722927, -6.030417971044005 ,
-6.425523127106116 ,
])
f_170us_118 = np.array([
-0.8892518583327204, -3.666054584861276, -4.103579008527569, -3.8581596841628247 ,
-3.6296301204273584 ,
])

f_ideal_105 = np.array([
-0.8808101887749133, -3.7613829988020133, -5.030208177791011, -6.249308006502248 ,
-6.4852271253988185 ,
])
f_170us_105 = np.array([
-0.8804792039741156, -3.6484379347551963, -4.1122545970407565, -3.8536222714874406 ,
-3.634089367884747 ,
])
f_ideal_92 = np.array([
-0.9013855959648269, -3.7413446881487284, -4.963426257688915, -6.292924645231845 ,
-6.555420181452293 ,
])
f_170us_92 = np.array([
-0.9010364268166411, -3.6255850040440123, -4.1223566622673875, -3.846798074484321 ,
-3.620592884235752 ,
])
f_ideal_78 = np.array([
-0.8788633187240702, -3.7599186024639493, -4.961652206723905, -6.307173709173524 ,
-6.683187068075573 ,
])
f_170us_78 = np.array([
-0.8785264587790031, -3.626497486382378, -4.166947136261655, -3.850004150685549 ,
-3.60758325502953 ,
])
f_ideal_68 = np.array([
-0.9782311932401822, -3.9687225806042803, -5.420059410371868, -6.4127236717783935 ,
-6.724599355489097 ,
])
f_170us_68 = np.array([
-0.9777715666100574, -3.675802970005805, -3.8233011441497666, -3.703013377185887 ,
-3.6061348564729814 ,
])
f_ideal_55 = np.array([
-0.9751038167729129, -3.8447486648093503, -5.352699243716754, -6.457571640173486 ,
-6.95752184824705 ,
])
f_170us_55 = np.array([
-0.9746530896357324, -3.612175488855331, -3.8238394080624936, -3.7065891700442872 ,
-3.6035173186281364 ,
])
f_ideal_41 = np.array([
-0.9044241751797325, -3.685784054661029, -5.356750640149107, -6.287261205003941 ,
-7.339741782962481 ,
])
f_170us_41 = np.array([
-0.9040103621009893, -3.5095868285505496, -3.826083561415875, -3.6944653404126404 ,
-3.540968090555939 ,
])

n_truc = [41, 55, 68, 78, 92, 105, 118, 131, 157, 181]
f_170us = np.column_stack((f_170us_41, f_170us_55, f_170us_68, f_170us_78, 
                           f_170us_92, f_170us_105, f_170us_118, f_170us_131, 
                           f_170us_157, f_170us_181, ))
f_ideal = np.column_stack((f_ideal_41, f_ideal_55, f_ideal_68, f_ideal_78, 
                           f_ideal_92, f_ideal_105, f_ideal_118, f_ideal_131, 
                           f_ideal_157, f_ideal_181,  ))

# %%
f_ideal_3e4_100 = np.array([
-0.975087370443019, -3.843531184200982, -5.353756199842104, -6.553964703556435 ,
-7.684301935452057 ,
])
f_ideal_3e4_200 = np.array([
-0.8807583664544218, -3.7608945832065093, -4.983467385291614, -5.942940874132047 ,
-6.947402397241186 ,
])
f_ideal_3e4_300 = np.array([
-0.8906157015191669, -3.772242486397306, -4.987648860974033, -5.94370525593791 ,
-6.943343548407614 ,
])
f_ideal_3e4_400 = np.array([
-0.8895971182952138, -3.7727044856849745, -4.987539205236665, -5.943825374304322 ,
-6.938939813986679 ,
])
f_ideal_3e4_500 = np.array([
-0.8896245836286782, -3.77240122168517, -4.986955240785758, -5.943264394436332 ,
-6.935072288899299 ,
])
f_ideal_3e4_600 = np.array([
-0.8896294798534035, -3.772208639134615, -4.986657401013696, -5.943147339907898 ,
-6.931877271181984 ,
])
f_ideal_3e4_700 = np.array([
-0.8896291703510549, -3.772110798888699, -4.986503612945826, -5.943197413732836 ,
-6.929126066338575 ,
])
f_ideal_3e4_800 = np.array([
-0.8896286751712543, -3.7720672367887236, -4.986436846787878, -5.943487696034406 ,
-6.926156022339486 ,
])
f_ideal_3e4_900 = np.array([
-0.8896289093752379, -3.77205559292962, -4.98645591015109, -5.943907598053868 ,
-6.9236136748069725 ,
])
f_ideal_3e4_1000 = np.array([
-0.8896294989838538, -3.7717739353600197, -4.985327308523193, -5.9419097405082235 ,
-6.876490155400263 ,
])
n_truc_2 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
f_ideal_3e4 = np.column_stack((f_ideal_3e4_100, f_ideal_3e4_200, f_ideal_3e4_300, 
                               f_ideal_3e4_400, f_ideal_3e4_500, f_ideal_3e4_600,
                               f_ideal_3e4_700, f_ideal_3e4_800, f_ideal_3e4_900, 
                               f_ideal_3e4_1000, ))

f_ideal_3e4_78 = np.array([
-0.4910401279060491, -0.8788087913806248, -1.9092459162631445, -2.7694128276542247 ,
-3.341884243798919, -3.7530981001621195, -4.101265966511826, -4.457766375638734 ,
-4.714158592362988, -4.968023026496211, -5.148294981427083, -5.383688856889358 ,
-5.592911697258704, -5.9191030412597225, -6.217924075791553, -6.508004132593557 ,
-6.612541926604733, -6.930806814043593 ,
])[[1, 5, 9, 13, 17]]

f_ideal_1e4_78 = np.array([
-0.49103758889040255, -0.878807802058778, -1.9092417873325929, -2.769419021803559 ,
-3.3418918618408293, -3.753118565136611, -4.101280831868235, -4.4578028925369875 ,
-4.714225911200767, -4.968157769769386, -5.148420029628917, -5.384018922239932 ,
-5.593162360625406, -5.9184071497035164, -6.21972852154908, -6.511368237375638 ,
-6.609064357355396, -6.939974409343103 ,
])[[1, 5, 9, 13, 17]]

f_ideal_1e4_500 = np.array([
-0.8896202810196633, -3.773200969174526, -4.988596030259518, -5.943190503304305 ,
-6.96135645552231 ,
])
f_ideal_1e4_1000 = np.array([
-0.8896261247648674, -3.7733456176313425, -4.989130403684351, -5.945250353649779 ,
-6.943958747816108 ,
])

# %%
fig, ax = plt.subplots(figsize=(6,3))
plt.plot(f_theta['tg'], 10**f_theta['f_1000'], 's-', label=r'1000')
plt.plot(f_theta['tg'], 10**f_theta['f_78'], 's-', label=r'78')
plt.plot(f_theta['tg'], np.abs(10**f_theta['f_1000'] - 10**f_theta['f_78']), '.--', label=r'difference')
plt.yscale('log')
plt.ylim(1e-8, 2e-1)
plt.xlabel('Gate Time $t_g$ (ns)')
plt.grid()
plt.title(r'Old: max_step=0')
legend = plt.legend(    loc="best",    )
legend.get_frame().set_alpha(0.2)  # 0.5 makes the legend 50% transparent

# %%
f_170us_206_1e4 = np.array([
-0.8894731790580659, -3.5892795302392235 ,-3.8295710591483 , -3.7007806358278015,-3.5286973057810966 ,
])
# Out:
# array([-3.54096809, -3.60351732, -3.60613486, -3.60758326, -3.62059288,
#        -3.63408937, -3.62963012, -3.66760301, -3.71615879, -3.73172714])

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(n_truc, 10**f_ideal[i], '.-', color=colors[0], label=fr'max_step=0')  # Change label if needed
    ax[i].plot(n_truc_large, 10**f_ideal_large[i], '.-', color=colors[0])  # Change label if needed
    # ax.set_yscale('log')
    ax[i].plot(n_truc_2, 10**f_ideal_3e4[i], 'x-', color=colors[1], label=fr'max_step=3e-4')  # Change label if needed
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')
ax[4].set_xlabel('truncation')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta$ ideal ')
# axes[4].set_ylim(0, 1e-4)
plt.tight_layout()

# %%
truc_3e4 = np.array([55, 78, 105, 131, 157])
f_170us_3e4 = np.array([-3.5176308297943346 , -3.5119800529022025 ,-3.5111643193984126 , -3.511166900253059 , -3.511171382408034 , ])
truc_1e4 = np.array([55, 105, 157, 206])
f_170us_1e4 = np.array([ -3.528833513469994 ,-3.5286979319698335 , -3.5286973113799185 , -3.5286973057810966 ,])
f_170us_3e5 = np.array([ -3.5308716254070216 , -3.5307354032176392 , ])

f_55ns_170us_1e4 = np.array([ -3.8295710591483 ,])
f_80ns_170us_1e4 = np.array([ -3.7007806358278015,])

# %%
fig, ax = plt.subplots(5, 1, figsize=(5, 10), sharex=True)
for i in range(5):
    ax[i].plot(n_truc, 10**f_170us[i], '.-', color=colors[0], label=fr'max_step=1e-3')  # Change label if needed
ax[4].plot(truc_3e4, 10**f_170us_3e4, 'v-', color=colors[2], label=fr'max_step=3e-4')
ax[4].plot(truc_1e4, 10**f_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[2].plot(206, 10**f_55ns_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[3].plot(206, 10**f_80ns_170us_1e4, 'D-', color=colors[1], label=fr'max_step=1e-4')
ax[4].plot(truc_1e4[:-2], 10**f_170us_3e5, 'x-', color=colors[3], label=fr'max_step=3e-5')
for i in range(5):
    ax[i].grid()
    legend = ax[i].legend(loc="best")
    legend.get_frame().set_alpha(0.2)
    ax[i].set_ylabel(fr'$t_g = {params[:,0][i]:.0f}$ns')

ax[4].set_xlabel('truncation')
ax[0].set_title(fr'Infidelity convergence: X gate $n_\theta\ 170\mu s$ ')
plt.tight_layout()

# %%
msteps = [1e-5, 3e-5, 1e-4, 3e-4, 1e-3]
f_170us_78 = np.array([-3.843427934159842 , -3.8430591138960004 , -3.838885472207149 , 
                       -3.805396083473126 , -4.210992481377649 , ])
fig, ax = plt.subplots(figsize=(5,2))
plt.plot(msteps, 10**f_170us_78, 'D-')
plt.title(r'X gate $n_\theta$, tg=50ns, Noise=170μs, $n_{\rm hspace}$=78')
plt.xscale('log')
plt.xlabel('Max_step')
plt.ylabel('Infidelity')
plt.grid()

# %%
msteps = [55, 78, 105, 131, 157  ]
f_50ns_1e4 = np.array([-3.8687018902545915 , -3.838885472207149 , -3.8405685621160686 , -3.8411643729255545 , -3.841266631232785 ,  ])
fig, ax = plt.subplots(figsize=(5,2))
plt.plot(msteps, 10**f_50ns_1e4, 'D-')
plt.title(r'X gate $n_\theta$, tg=50ns, Noise=170μs, Max_step=1e-4')
# plt.xscale('log')
plt.xlabel('Truncation')
plt.ylabel('Infidelity')
plt.grid()
